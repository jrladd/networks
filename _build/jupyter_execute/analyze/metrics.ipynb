 'Citizen V Ii / Helmut', 'Charcoal / Charlie Bur'],
#  ['Hawk', 'Citizen V Ii / Helmut', 'Charcoal / Charlie Bur'],
#  ['Quicksilver / Pietro M',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Captain America', 'Citizen V Ii / Helmut', 'Charcoal / Charlie Bur'],
#  ['Thing / Benjamin J. Gr',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Invisible Woman / Sue',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Thor / Dr. Donald Blak',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Jarvis, Edwin',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Hercules [greek God]',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Black Widow / Natasha',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Bridge, George Washi', 'Citizen V Ii / Helmut', 'Charcoal / Charlie Bur'],
#  ['Ant-man Ii / Scott Har',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Black Knight V / Dane',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Nomad Iii / Jack Monro', 'Citizen V Ii / Helmut', 'Charcoal / Charlie Bur'],
#  ['Falcon / Sam Wilson',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Fixer Ii / Paul Norber', 'Citizen V Ii / Helmut', 'Charcoal / Charlie Bur'],
#  ['Moonstone Ii / Karla S', 'Citizen V Ii / Helmut', 'Charcoal / Charlie Bur'],
#  ['Power Man / Erik Joste', 'Citizen V Ii / Helmut', 'Charcoal / Charlie Bur'],
#  ['Beetle / Abner Ronald', 'Citizen V Ii / Helmut', 'Charcoal / Charlie Bur'],
#  ['Bulldozer / Henry Camp',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Wrecker Iii / Dirk Gar',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Piledriver Ii / Brian',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Screaming Mimi / Melis', 'Citizen V Ii / Helmut', 'Charcoal / Charlie Bur'],
#  ['Captain America', 'Diamondback Ii / Rache', 'Citizen V Ii / Helmut'],
#  ['Vision',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur'],
#  ['Kingpin / Wilson Fisk',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy'],
#  ['Jarvis, Edwin', 'Diamondback Ii / Rache', 'Citizen V Ii / Helmut'],
#  ['Ant-man / Dr. Henry J.',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur'],
#  ['Hercules [greek God]', 'Diamondback Ii / Rache', 'Citizen V Ii / Helmut'],
#  ['Black Widow / Natasha', 'Diamondback Ii / Rache', 'Citizen V Ii / Helmut'],
#  ['Red Skull / Johann Sch', 'Diamondback Ii / Rache', 'Citizen V Ii / Helmut'],
#  ['Usagent / Captain John',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Rosenthal, Bernie', 'Diamondback Ii / Rache', 'Citizen V Ii / Helmut'],
#  ['Jameson, Col. John', 'Diamondback Ii / Rache', 'Citizen V Ii / Helmut'],
#  ['Falcon / Sam Wilson', 'Diamondback Ii / Rache', 'Citizen V Ii / Helmut'],
#  ["Black Panther / T'chal",
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Iron Man / Tony Stark',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur'],
#  ['Justice Ii / Vance Ast',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Wasp / Janet Van Dyne',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Hawk',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Scarlet Witch / Wanda',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur'],
#  ['Quicksilver / Pietro M',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Captain America', 'Demolition Man / Denni', 'Diamondback Ii / Rache'],
#  ['She-hulk / Jennifer Wa',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Vision', 'Demolition Man / Denni', 'Diamondback Ii / Rache'],
#  ['Thing / Benjamin J. Gr',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Thor / Dr. Donald Blak',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Spider-woman Ii / Juli',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Crystal [inhuman]',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Jarvis, Edwin', 'Demolition Man / Denni', 'Diamondback Ii / Rache'],
#  ['Ant-man / Dr. Henry J.',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache'],
#  ['Hercules [greek God]', 'Demolition Man / Denni', 'Diamondback Ii / Rache'],
#  ['Black Widow / Natasha', 'Demolition Man / Denni', 'Diamondback Ii / Rache'],
#  ['Dr. Druid / Anthony Lu',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Starfox / Eros',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Quasar Iii / Wendell V',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Captain Marvel Ii / Mo',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Usagent / Captain John',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache'],
#  ['Ms. Marvel Ii / Sharon',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Black Knight V / Dane',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Nomad Iii / Jack Monro',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Falcon / Sam Wilson', 'Demolition Man / Denni', 'Diamondback Ii / Rache'],
#  ['Redwing',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Sersi / Sylvia',
#   'Demolition Man / Denni',
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Iron Man / Tony Stark',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur'],
#  ['Sub-mariner / Namor Ma',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Spider-man / Peter Parker',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Wasp / Janet Van Dyne',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Hawk',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Scarlet Witch / Wanda',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur'],
#  ['Captain America', "O'brien, Michael", 'Diamondback Ii / Rache'],
#  ['Wonder Man / Simon Wil',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur'],
#  ['Wolverine / Logan',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['She-hulk / Jennifer Wa',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Vision', "O'brien, Michael", 'Diamondback Ii / Rache'],
#  ['Thing / Benjamin J. Gr',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Thor / Dr. Donald Blak',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Dr. Strange / Stephen',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan'],
#  ['Jarvis, Edwin', "O'brien, Michael", 'Diamondback Ii / Rache'],
#  ['Ant-man / Dr. Henry J.', "O'brien, Michael", 'Diamondback Ii / Rache'],
#  ['Stankowicz, Fabian', "O'brien, Michael", 'Diamondback Ii / Rache'],
#  ['Hercules [greek God]', "O'brien, Michael", 'Diamondback Ii / Rache'],
#  ['Black Widow / Natasha', "O'brien, Michael", 'Diamondback Ii / Rache'],
#  ['Daredevil / Matt Murdo',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Starfox / Eros',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Fury, Col. Nicholas',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Quasar Iii / Wendell V',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P',
#   'Tigra / Greer Nelson'],
#  ['Captain Marvel Ii / Mo',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Jameson, Col. John', "O'brien, Michael", 'Diamondback Ii / Rache'],
#  ['Falcon / Sam Wilson', "O'brien, Michael", 'Diamondback Ii / Rache'],
#  ['Rage / Elvin Daryl Hal',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Sersi / Sylvia',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Carter, Peggy', "O'brien, Michael", 'Diamondback Ii / Rache'],
#  ['Iron Man / Tony Stark', 'Mandarin', "O'brien, Michael"],
#  ['Iron Man Iv / James R.',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Hawk', 'Mandarin', "O'brien, Michael"],
#  ['Scarlet Witch / Wanda', 'Mandarin', "O'brien, Michael"],
#  ['Captain America', 'Mandarin', "O'brien, Michael"],
#  ['Vision', 'Mandarin', "O'brien, Michael"],
#  ['Hogan, Virginia Pepp', 'Mandarin', "O'brien, Michael"],
#  ['Thor / Dr. Donald Blak', 'Mandarin', "O'brien, Michael"],
#  ['Spider-woman Ii / Juli',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Kingpin / Wilson Fisk',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache'],
#  ['Magneto / Magnus / Eric',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Jarvis, Edwin', 'Mandarin', "O'brien, Michael"],
#  ['Ant-man / Dr. Henry J.', 'Mandarin', "O'brien, Michael"],
#  ['Black Widow / Natasha', 'Mandarin', "O'brien, Michael"],
#  ['Dr. Doom / Victor Von',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Red Skull / Johann Sch',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache'],
#  ['Fury, Col. Nicholas', 'Mandarin', "O'brien, Michael"],
#  ['Usagent / Captain John',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache'],
#  ['Sunfire / Shiro Yoshid',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Wizard / Bentley Wittm',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ["Black Panther / T'chal",
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Iron Man / Tony Stark', 'Loki [asgardian]', 'Mandarin'],
#  ['Sub-mariner / Namor Ma',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael"],
#  ['Thunderball / Dr. Elio',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Spider-man / Peter Parker',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael"],
#  ['Wasp / Janet Van Dyne', 'Loki [asgardian]', 'Mandarin', "O'brien, Michael"],
#  ['Silver Surfer / Norrin',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Hawk', 'Loki [asgardian]', 'Mandarin'],
#  ['Scarlet Witch / Wanda', 'Loki [asgardian]', 'Mandarin'],
#  ['Captain America', 'Loki [asgardian]', 'Mandarin'],
#  ['Thunderstrike / Eric K',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Wonder Man / Simon Wil',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael"],
#  ['She-hulk / Jennifer Wa',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael"],
#  ['Vision', 'Loki [asgardian]', 'Mandarin'],
#  ['Mr. Fantastic / Reed R',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Thing / Benjamin J. Gr',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael"],
#  ['Invisible Woman / Sue',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Cyclops / Scott Summer',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Enchantress / Amora / He',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Fury, Col. Nicholas', 'Loki [asgardian]', 'Mandarin'],
#  ['Black Knight V / Dane',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Black Widow / Natasha', 'Loki [asgardian]', 'Mandarin'],
#  ['Thor / Dr. Donald Blak', 'Loki [asgardian]', 'Mandarin'],
#  ['Bulldozer / Henry Camp',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Wrecker Iii / Dirk Gar',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Piledriver Ii / Brian',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Hercules [greek God]', 'Loki [asgardian]', 'Mandarin', "O'brien, Michael"],
#  ['Ant-man / Dr. Henry J.', 'Loki [asgardian]', 'Mandarin'],
#  ['Human Torch / Johnny S',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Shadowcat / Katherine',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Dr. Strange / Stephen', 'Loki [asgardian]', 'Mandarin', "O'brien, Michael"],
#  ['Nightcrawler / Kurt Wa',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Quasar Iii / Wendell V',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael"],
#  ['Norriss, Sister Barb',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Watson-parker, Mary',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co'],
#  ['Mephisto',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan'],
#  ['Kingpin / Wilson Fisk', 'Loki [asgardian]', 'Mandarin'],
#  ['Dr. Doom / Victor Von', 'Loki [asgardian]', 'Mandarin'],
#  ['Odin [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Wizard / Bentley Wittm', 'Loki [asgardian]', 'Mandarin'],
#  ['Jarvis, Edwin', 'Loki [asgardian]', 'Mandarin'],
#  ['Magneto / Magnus / Eric', 'Loki [asgardian]', 'Mandarin'],
#  ['Red Skull / Johann Sch', 'Loki [asgardian]', 'Mandarin'],
#  ['Phoenix Iii / Rachel S',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Absorbing Man / Carl C',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Iron Man / Tony Stark', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Hulk / Dr. Robert Bruce Banner', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Hawk', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Scarlet Witch / Wanda', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Captain America', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Mr. Fantastic / Reed R', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Invisible Woman / Sue', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Heimdall [asgardian]', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Enchantress / Amora / He', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Thor / Dr. Donald Blak', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Hellcat / Patsy Walker',
#   'Hela [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Norriss, Sister Barb', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Wolfsbane / Rahne Sinc',
#   'Hela [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Warlock Iii',
#   'Hela [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Sunspot / Roberto Daco',
#   'Hela [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Cannonball Ii / Sam Gu',
#   'Hela [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Volstagg', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Hogun [asgardian]', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Fandral [asgardian]', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Vizier', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Odin [asgardian]', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Sif', 'Hela [asgardian]', 'Loki [asgardian]'],
#  ['Rictor / Julio Esteban',
#   'Hela [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
# ...
#  ['Cage, Luke / Carl Luca',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Hercules [greek God]', 'Thena', 'Hogun [asgardian]'],
#  ['Volstagg', 'Thena', 'Hogun [asgardian]'],
#  ['Fandral [asgardian]', 'Thena', 'Hogun [asgardian]'],
#  ['Odin [asgardian]', 'Thena', 'Hogun [asgardian]'],
#  ['Makkari / Mike Khary / I', 'Thena', 'Hogun [asgardian]'],
#  ['Sif', 'Thena', 'Hogun [asgardian]'],
#  ['Ant-man Ii / Scott Har',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Black Knight V / Dane', 'Thena', 'Hogun [asgardian]'],
#  ['High Evolutionary / He', 'Thena', 'Hogun [asgardian]'],
#  ['Iron Fist / Daniel Ran',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan'],
#  ['Sersi / Sylvia', 'Thena', 'Hogun [asgardian]'],
#  ['Forgotten One / Gilgam',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P',
#   'Tigra / Greer Nelson'],
#  ['Ghaur [deviant]',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Ikaris / Ike Harris [e', 'Thena', 'Hogun [asgardian]'],
#  ['Iron Man / Tony Stark',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]'],
#  ['Sub-mariner / Namor Ma', 'Human Torch Android / ', 'Thena'],
#  ['Namorita / Nita Prenti',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Wasp / Janet Van Dyne',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]'],
#  ['Mockingbird / Dr. Barb',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Hawk',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]'],
#  ['Scarlet Witch / Wanda',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]'],
#  ['Quicksilver / Pietro M', 'Human Torch Android / ', 'Thena'],
#  ['Captain America', 'Human Torch Android / ', 'Thena'],
#  ['Wonder Man / Simon Wil',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]'],
#  ['She-hulk / Jennifer Wa', 'Human Torch Android / ', 'Thena'],
#  ['Vision', 'Human Torch Android / ', 'Thena', 'Hogun [asgardian]'],
#  ['Mr. Fantastic / Reed R',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]'],
#  ['Thing / Benjamin J. Gr',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]'],
#  ['Invisible Woman / Sue',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]'],
#  ['Thor / Dr. Donald Blak', 'Human Torch Android / ', 'Thena'],
#  ['Human Torch / Johnny S',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]'],
#  ['Cage, Luke / Carl Luca', 'Human Torch Android / ', 'Thena'],
#  ['Jarvis, Edwin', 'Human Torch Android / ', 'Thena', 'Hogun [asgardian]'],
#  ['Ant-man / Dr. Henry J.',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]'],
#  ['Hercules [greek God]', 'Human Torch Android / ', 'Thena'],
#  ['Dr. Doom / Victor Von',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]'],
#  ['Pharaoh Rama-tut',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co'],
#  ['Quasar Iii / Wendell V',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]'],
#  ['Kincaid, Dr. Jane Fo',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]'],
#  ['Iron Fist / Daniel Ran', 'Human Torch Android / ', 'Thena'],
#  ['Red Skull / Johann Sch',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]'],
#  ['Sersi / Sylvia', 'Human Torch Android / ', 'Thena'],
#  ['Harkness, Agatha',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Ghaur [deviant]', 'Human Torch Android / ', 'Thena'],
#  ['Black Knight V / Dane', 'Human Torch Android / ', 'Thena'],
#  ['Usagent / Captain John',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin'],
#  ['Ant-man Ii / Scott Har', 'Human Torch Android / ', 'Thena'],
#  ['Sub-mariner / Namor Ma', 'Knight, Misty', 'Human Torch Android / '],
#  ['Namorita / Nita Prenti', 'Knight, Misty', 'Human Torch Android / '],
#  ['Spider-man / Peter Parker',
#   'Knight, Misty',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]'],
#  ['Captain America', 'Knight, Misty', 'Human Torch Android / '],
#  ['Wolverine / Logan',
#   'Knight, Misty',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael"],
#  ['She-hulk / Jennifer Wa', 'Knight, Misty', 'Human Torch Android / '],
#  ['Storm / Ororo Munroe S',
#   'Knight, Misty',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Mr. Fantastic / Reed R', 'Knight, Misty', 'Human Torch Android / '],
#  ['Thing / Benjamin J. Gr', 'Knight, Misty', 'Human Torch Android / '],
#  ['Invisible Woman / Sue', 'Knight, Misty', 'Human Torch Android / '],
#  ['Punisher Ii / Frank Ca',
#   'Knight, Misty',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate'],
#  ['Cyclops / Scott Summer',
#   'Knight, Misty',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]'],
#  ['Professor X / Charles',
#   'Knight, Misty',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Human Torch / Johnny S', 'Knight, Misty', 'Human Torch Android / '],
#  ['Colossus Ii / Peter Ra',
#   'Knight, Misty',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Cage, Luke / Carl Luca', 'Knight, Misty', 'Human Torch Android / '],
#  ['Daredevil / Matt Murdo',
#   'Knight, Misty',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]'],
#  ['Banshee / Sean Cassidy',
#   'Knight, Misty',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Nightcrawler / Kurt Wa',
#   'Knight, Misty',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]'],
#  ['Nelson, Franklin Fog',
#   'Knight, Misty',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Black Knight V / Dane', 'Knight, Misty', 'Human Torch Android / '],
#  ['Sunfire / Shiro Yoshid',
#   'Knight, Misty',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin'],
#  ['Mactaggert, Moira Ki',
#   'Knight, Misty',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Lilandra Neramani [s',
#   'Knight, Misty',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Iron Fist / Daniel Ran', 'Knight, Misty', 'Human Torch Android / '],
#  ['Wing, Colleen', 'Knight, Misty', 'Human Torch Android / '],
#  ['Sub-mariner / Namor Ma', 'Wing, Colleen', 'Human Torch Android / '],
#  ['Namorita / Nita Prenti', 'Wing, Colleen', 'Human Torch Android / '],
#  ['Wolverine / Logan',
#   'Wing, Colleen',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael"],
#  ['Storm / Ororo Munroe S',
#   'Wing, Colleen',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Cyclops / Scott Summer',
#   'Wing, Colleen',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]'],
#  ['Colossus Ii / Peter Ra',
#   'Wing, Colleen',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw'],
#  ['Cage, Luke / Carl Luca', 'Wing, Colleen', 'Human Torch Android / '],
#  ['Banshee / Sean Cassidy',
#   'Wing, Colleen',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Nightcrawler / Kurt Wa',
#   'Wing, Colleen',
#   'Human Torch Android / ',
#   'Thena',
#   'Hogun [asgardian]',
#   'Loki [asgardian]'],
#  ['Iron Fist / Daniel Ran', 'Wing, Colleen', 'Human Torch Android / '],
#  ['Wasp / Janet Van Dyne',
#   'Ikaris / Ike Harris [e',
#   'Hogun [asgardian]',
#   'Loki [asgardian]'],
#  ['Scarlet Witch / Wanda', 'Ikaris / Ike Harris [e', 'Hogun [asgardian]'],
#  ['Captain America', 'Ikaris / Ike Harris [e', 'Hogun [asgardian]'],
#  ['She-hulk / Jennifer Wa', 'Ikaris / Ike Harris [e', 'Hogun [asgardian]'],
#  ['Vision', 'Ikaris / Ike Harris [e', 'Hogun [asgardian]'],
#  ['Thor / Dr. Donald Blak', 'Ikaris / Ike Harris [e', 'Hogun [asgardian]'],
#  ['Hercules [greek God]', 'Ikaris / Ike Harris [e', 'Hogun [asgardian]'],
#  ['Volstagg', 'Ikaris / Ike Harris [e', 'Hogun [asgardian]'],
#  ['Fandral [asgardian]', 'Ikaris / Ike Harris [e', 'Hogun [asgardian]'],
#  ['Odin [asgardian]', 'Ikaris / Ike Harris [e', 'Hogun [asgardian]'],
#  ['Makkari / Mike Khary / I', 'Ikaris / Ike Harris [e', 'Hogun [asgardian]'],
#  ['Sif', 'Ikaris / Ike Harris [e', 'Hogun [asgardian]'],
#  ['Sersi / Sylvia', 'Ikaris / Ike Harris [e', 'Hogun [asgardian]'],
#  ['Forgotten One / Gilgam',
#   'Ikaris / Ike Harris [e',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P',
#   'Tigra / Greer Nelson'],
#  ['Ghaur [deviant]',
#   'Ikaris / Ike Harris [e',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Sub-mariner / Namor Ma', 'Zeus', 'Hogun [asgardian]'],
#  ['Wasp / Janet Van Dyne', 'Zeus', 'Hogun [asgardian]', 'Loki [asgardian]'],
#  ['Hawk', 'Zeus', 'Hogun [asgardian]', 'Loki [asgardian]'],
#  ['Scarlet Witch / Wanda', 'Zeus', 'Hogun [asgardian]'],
#  ['Quicksilver / Pietro M',
#   'Zeus',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut'],
#  ['Captain America', 'Zeus', 'Hogun [asgardian]'],
#  ['She-hulk / Jennifer Wa', 'Zeus', 'Hogun [asgardian]'],
#  ['Vision', 'Zeus', 'Hogun [asgardian]'],
#  ['Heimdall [asgardian]', 'Zeus', 'Hogun [asgardian]'],
#  ['Enchantress / Amora / He', 'Zeus', 'Hogun [asgardian]'],
#  ['Thor / Dr. Donald Blak', 'Zeus', 'Hogun [asgardian]'],
#  ['Ant-man / Dr. Henry J.', 'Zeus', 'Hogun [asgardian]', 'Loki [asgardian]'],
#  ['Hercules [greek God]', 'Zeus', 'Hogun [asgardian]'],
#  ['Black Widow / Natasha', 'Zeus', 'Hogun [asgardian]', 'Loki [asgardian]'],
#  ['Volstagg', 'Zeus', 'Hogun [asgardian]'],
#  ['Fandral [asgardian]', 'Zeus', 'Hogun [asgardian]'],
#  ['Odin [asgardian]', 'Zeus', 'Hogun [asgardian]'],
#  ['Dr. Druid / Anthony Lu',
#   'Zeus',
#   'Hogun [asgardian]',
#   'Loki [asgardian]',
#   'Mandarin',
#   "O'brien, Michael",
#   'Diamondback Ii / Rache',
#   'Citizen V Ii / Helmut',
#   'Charcoal / Charlie Bur',
#   'Klaw / Ulysses Klaw',
#   'Lizard / Dr. Curtis Co',
#   'Robertson, Randy',
#   'Cushing, Kate',
#   'Hobgoblin V / Jason Ph',
#   'Ghost Rider Iii / Dan',
#   'Beast / Henry &hank& P'],
#  ['Sif', 'Zeus', 'Hogun [asgardian]'],
#  ['Captain Marvel Ii / Mo', 'Zeus', 'Hogun [asgardian]'],
#  ['Balder [asgardian]', 'Zeus', 'Hogun [asgardian]'],
#  ['Black Knight V / Dane', 'Zeus', 'Hogun [asgardian]'],
#  ['Sersi / Sylvia', 'Zeus', 'Hogun [asgardian]'],
#  ...]
