# %% [markdown]
# # Metrics
#
# NetworkX includes a huge amount of algorithms and metrics. Here's a cheatsheet to the most common ones you'll need.
#
# ## Network Properties

# %%
# Import NetworkX and key data science libraries
import networkx as nx
import pandas as pd
import numpy as np
import altair as alt

# Import Marvel network data
marvel= pd.read_csv("../data/marvel-unimodal-edges.csv")
M = nx.from_pandas_edgelist(marvel, source="Source", target="Target", edge_attr=True)
print(M)
# Out:
# Graph with 327 nodes and 9891 edges

# %%
M.number_of_nodes() # Number of nodes
# Out:
# 327

# %%
M.number_of_edges() # Alternative method for number of edges
# Out:
# 9891

# %%
M.is_directed() # Is the graph directed?
# Out:
# False

# %% [markdown]
# ## Paths

# %%
nx.shortest_path(M, "Black Panther / T'chal", 	"Gambit / Remy Lebeau") # Shortest path as list
# Out:
# ["Black Panther / T'chal", 'Firestar / Angelica Jo', 'Gambit / Remy Lebeau']

# %%
nx.shortest_path_length(M, "Black Panther / T'chal", "Gambit / Remy Lebeau") #Shortest path length (Distance)
# Out:
# 2

# %%
nx.average_shortest_path_length(M) # Average shortest path length (Average distance)
# Out:
# 1.873004258831917

# %%
nx.diameter(M)
# Out:
# 3

# %% [markdown]
# ## Components

# %%
nx.is_connected(M) # Is the graph connected?
# Out:
# True

# %%
nx.number_connected_components(M) # How many components are there?
# Out:
# 1

# %%
# Find the largest connected component (as a node set)
components = [G for G in nx.connected_components(M)]
largest = max(components, key=len)

# %% [markdown]
# ## Centrality
#
# Below I show just one example, but there are a range of [centrality functions](https://networkx.org/documentation/stable/reference/algorithms/centrality.html) in NetworkX.

# %%
# Calculate betweenness centrality for every node
bc = nx.betweenness_centrality(M)

# %% [markdown]
# ## Triangles and Clustering

# %%
# Get number of triangles for every node
nx.triangles(M)

# n.b. Pay attention to the following note from the NetworkX docs:
# When computing triangles for the entire graph each triangle is counted three times, once at each node.
# Out:
# {"Black Panther / T'chal": 2837,
#  'Loki [asgardian]': 1055,
#  'Mantis / ? Brandt': 277,
#  'Iceman / Robert Bobby': 5320,
#  'Marvel Girl / Jean Grey': 5050,
#  'Cyclops / Scott Summer': 6474,
#  'Klaw / Ulysses Klaw': 1012,
#  'Human Torch / Johnny S': 6282,
#  'Richards, Franklin B': 2444,
#  'Wolverine / Logan': 7168,
#  'Firebird / Bonita Juar': 643,
#  'Mr. Fantastic / Reed R': 6191,
#  'Medusa / Medusalith Am': 1019,
#  'Dr. Strange / Stephen': 4522,
#  'Jack Of Hearts / Jack': 576,
#  'Mephisto': 916,
#  'Thanos': 2337,
#  'Swordsman / Jacques Du': 342,
#  'Collector / Taneleer T': 393,
#  'Lockjaw [inhuman]': 865,
#  'Sub-mariner / Namor Ma': 4197,
#  'Pharaoh Rama-tut': 2562,
#  'Ant-man Ii / Scott Har': 917,
#  'Lyja Lazerfist [skru': 399,
#  'Gorgon [inhuman]': 837,
#  'Nighthawk Ii / Kyle Ri': 422,
#  'Cage, Luke / Carl Luca': 1200,
#  'Colossus Ii / Peter Ra': 6169,
#  'Hellcat / Patsy Walker': 1278,
#  'Karnak [inhuman]': 873,
#  'Death': 756,
#  'Redwing': 214,
#  'Daredevil / Matt Murdo': 4276,
#  'Norriss, Sister Barb': 1244,
#  'Rage / Elvin Daryl Hal': 875,
#  'Starfox / Eros': 1686,
#  'Demolition Man / Denni': 349,
#  'Sersi / Sylvia': 1906,
#  'Spider-man / Peter Parker': 6533,
#  'Vision': 6672,
#  'Uatu': 2324,
#  'Binary / Carol Danvers': 2010,
#  'Gyrich, Henry Peter': 985,
#  'Nightcrawler / Kurt Wa': 3965,
#  'Angel / Warren Kenneth': 5562,
#  'Silver Surfer / Norrin': 3697,
#  'She-hulk / Jennifer Wa': 5868,
#  'Ghaur [deviant]': 155,
#  'Dr. Doom / Victor Von': 4084,
#  'Storm / Ororo Munroe S': 6220,
#  'Scarlet Witch / Wanda': 6216,
#  'Toad / Mortimer Toynbe': 537,
#  'Hulk / Dr. Robert Bruce Banner': 5984,
#  'Firestar / Angelica Jo': 2659,
#  'Wonder Man / Simon Wil': 5412,
#  'Drax / Arthur Douglas': 2307,
#  'Dugan, Timothy Aloyi': 825,
#  'Carter, Sharon': 152,
#  'Black Knight V / Dane': 4610,
#  'Sunfire / Shiro Yoshid': 953,
#  'Triton': 606,
#  'Ultron': 1099,
#  'Jones, Richard Milho': 1590,
#  'Iron Man / Tony Stark': 5983,
#  'Nelson, Franklin Fog': 425,
#  'Captain America': 7888,
#  'Jarvis, Edwin': 3437,
#  'Quasar Iii / Wendell V': 4047,
#  'Jameson, J. Jonah': 1628,
#  'Masters, Alicia Reis': 1333,
#  'Magneto / Magnus / Eric': 3138,
#  'Invisible Woman / Sue': 6242,
#  'Professor X / Charles': 6081,
#  'Iron Fist / Daniel Ran': 1049,
#  'Black Bolt / Blackanto': 849,
#  'Hawk': 5168,
#  'Sandman / William Bake': 1088,
#  'Falcon / Sam Wilson': 2034,
#  'Stingray / Dr. Walter': 575,
#  'Justice Ii / Vance Ast': 876,
#  'Hercules [greek God]': 5530,
#  'Usagent / Captain John': 2828,
#  'Captain Marvel Ii / Mo': 2628,
#  'Crystal [inhuman]': 3778,
#  'Tigra / Greer Nelson': 2055,
#  'Spider-woman Ii / Juli': 2654,
#  'Machine Man / X-51': 814,
#  'Mockingbird / Dr. Barb': 1399,
#  'Captain Marvel / Capta': 564,
#  'Wasp / Janet Van Dyne': 5937,
#  'Fury, Col. Nicholas': 2781,
#  'Thor / Dr. Donald Blak': 5939,
#  'Quicksilver / Pietro M': 5163,
#  'Captain Britain / Bria': 692,
#  'Shadowcat / Katherine': 2969,
#  'Black Widow / Natasha': 4685,
#  'Ant-man / Dr. Henry J.': 5128,
#  'Moon Knight / Marc Spe': 1736,
#  'Jocasta': 316,
#  'Moondragon / Heather D': 3402,
#  'Thing / Benjamin J. Gr': 6867,
#  'Beast / Henry &hank& P': 6660,
#  'Nova / Richard Rider': 3271,
#  'Wrecker Iii / Dirk Gar': 1027,
#  'Warlock Ii / Adam Warl': 2287,
#  'Piledriver Ii / Brian': 928,
#  'Thunderball / Dr. Elio': 1042,
#  'Dr. Octopus / Otto Oct': 998,
#  'Banner, Betty Ross T': 581,
#  'Avalanche / Dominic Pe': 571,
#  'Attuma': 243,
#  'Hela [asgardian]': 279,
#  'Doc Samson / Dr. Leona': 685,
#  'Guardian / James Macdo': 456,
#  'Northstar / Jean-paul': 2137,
#  'Dr. Druid / Anthony Lu': 2075,
#  'Watson-parker, Mary': 805,
#  'Mystique / Raven Darkh': 1067,
#  'Pyro / Allerdyce Johnn': 740,
#  'Destiny Ii / Irene Adl': 418,
#  'Mister Hyde / Calvin Z': 189,
#  'Ghost Rider Ii / Johnn': 279,
#  'Mole Man / Harvey Rupe': 544,
#  'Firelord / Pyreus Kril': 540,
#  'Leader / Sam Sterns': 136,
#  'Le Fey, Morgan': 141,
#  'Bulldozer / Henry Camp': 928,
#  'Forgotten One / Gilgam': 310,
#  'Balder [asgardian]': 358,
#  'Hogun [asgardian]': 539,
#  'Hellstorm / Daimon Hel': 341,
#  'Aurora / Jeanne-marie': 1466,
#  "O'brien, Michael": 437,
#  'Stankowicz, Fabian': 259,
#  'Screaming Mimi / Melis': 332,
#  'Moonstone Ii / Karla S': 556,
#  'Fixer Ii / Paul Norber': 399,
#  'Darkstar / Laynia Serg': 441,
#  'Vanguard / Nicolai Kry': 275,
#  'Gamora': 1577,
#  'Psylocke / Elisabeth B': 4245,
#  'Rogue  / ': 5545,
#  'Sasquatch / Walter Lan': 3138,
#  'Luna / Luna Maximoff [': 357,
#  'Whizzer Ii / Stanley S': 96,
#  'Dr. Spectrum / Joseph': 96,
#  'Kingpin / Wilson Fisk': 518,
#  'Clea': 171,
#  'Polaris / Lorna Dane': 3325,
#  'De La Fontaine, Cont': 174,
#  'Heimdall [asgardian]': 193,
#  'Red Skull / Johann Sch': 429,
#  'Thompson, Eugene Fla': 507,
#  'Wong': 412,
#  'Parker, May': 541,
#  'Green Goblin / Norman': 207,
#  'Night Thrasher / Duane': 252,
#  'Eternity / Adam Qadmon': 1623,
#  'Galactus / Galan': 3125,
#  'Triathlon / Delroy Gar': 334,
#  'Beetle / Abner Ronald': 659,
#  'Lilandra Neramani [s': 1290,
#  'Odin [asgardian]': 903,
#  'Hogan, Virginia Pepp': 113,
#  'Mad Dog / Colonel Buzz': 166,
#  'Kincaid, Dr. Jane Fo': 249,
#  'Wizard / Bentley Wittm': 309,
#  'Charcoal / Charlie Bur': 165,
#  'Blob / Fred J. Dukes': 1189,
#  'Cloak / Tyrone Johnson': 164,
#  'Thunderstrike / Eric K': 3331,
#  'Power Man / Erik Joste': 580,
#  'Human Torch Android / ': 468,
#  'Juggernaut / Cain Mark': 349,
#  'Absorbing Man / Carl C': 981,
#  'Volstagg': 466,
#  'Shaman / Michael Twoyo': 2187,
#  'Snowbird / Narya / Anne': 381,
#  'Dagger / Tandy Bowen': 273,
#  'Phoenix Iii / Rachel S': 892,
#  'Mandarin': 177,
#  'Fandral [asgardian]': 546,
#  'Ms. Marvel Ii / Sharon': 265,
#  'Pip / Prince Gofern': 1569,
#  'Enchantress / Amora / He': 1465,
#  'Jameson, Col. John': 328,
#  'Cooper, Dr. Valerie': 1411,
#  'Nova Ii / Frankie Raye': 1992,
#  'Darkhawk / Chris Powel': 1881,
#  'Nomad Iii / Jack Monro': 197,
#  'Robertson, Joe': 654,
#  'Gargoyle Ii / Isaac Ch': 549,
#  'Namorita / Nita Prenti': 2840,
#  'Iron Man Iv / James R.': 1520,
#  'Ross, Gen. Thaddeus': 384,
#  'Harkness, Agatha': 2391,
#  'Carter, Peggy': 387,
#  'Hyperion': 160,
#  'Living Lightning / Mig': 2888,
#  'Jones, Gabe': 304,
#  'Osborn, Liz Allan': 451,
#  'Leeds, Betty Brant': 508,
#  'Sif': 444,
#  'Dazzler Ii / Allison B': 970,
#  'Molecule Man / Owen Re': 731,
#  'Speedball / Robbie Bal': 2263,
#  'Lizard / Dr. Curtis Co': 778,
#  'Volcana / Marsha Rosen': 615,
#  'Lockheed': 796,
#  'Titania Ii / Mary Skee': 748,
#  'Boomer / Tabitha Smith': 1306,
#  'Summers, Nathan Chri': 1861,
#  'Summers, Madelyne Ma': 524,
#  'Mactaggert, Moira Ki': 1662,
#  'Cannonball Ii / Sam Gu': 2512,
#  'Tilby, Trish / Patrici': 423,
#  'Skids / Sally Blevins': 371,
#  'Wolfsbane / Rahne Sinc': 3135,
#  'Leech': 249,
#  'Mirage Ii / Danielle M': 907,
#  'Gambit / Remy Lebeau': 3766,
#  'Jubilee / Jubilation L': 1117,
#  'Strong Guy / Guido Car': 2793,
#  'Spiral': 328,
#  'Banshee / Sean Cassidy': 1321,
#  'Legion Ii / David Hall': 377,
#  'Havok / Alex Summers': 3894,
#  'Longshot': 450,
#  'Forge': 1666,
#  'Sabretooth / Victor Cr': 659,
#  'Maddicks, Arthur Art': 225,
#  'Warlock Iii': 1030,
#  'Rictor / Julio Esteban': 953,
#  'Sunspot / Roberto Daco': 1687,
#  'Firefist / Rusty Colli': 334,
#  'Bishop  / ': 1466,
#  'Daytripper / Amanda Se': 258,
#  'Wild Child / Kyle Gibn': 1274,
#  'Thunderbird Ii / James': 1105,
#  'Sauron / Dr. Karl Lyko': 267,
#  'Siryn / Theresa Rourke': 965,
#  'Shatterstar Ii / Gavee': 682,
#  'Marrow / Sarah': 424,
#  'Feral / Maria Callasan': 515,
#  'Callisto': 302,
#  'Mr. Sinister / Nathan': 395,
#  'Raza Longknife': 332,
#  'Spider-woman / Jessica': 371,
#  'Cypher / Doug Ramsey': 589,
#  "Deathbird [shi'ar]": 297,
#  'Hudson, Heather': 2525,
#  'Stryfe': 518,
#  'Iron Man Doppelgange': 1031,
#  'Puck / Eugene Milton J': 2347,
#  'Silhouette': 519,
#  'Cortez, Fabian': 189,
#  'Black King / Sebastian': 402,
#  'Magik / Illyana Rasput': 605,
#  'Zabu': 229,
#  'Domino Iii / Beatrice / ': 229,
#  'Caliban / ': 607,
#  'Apocalypse / En Sabah': 1043,
#  'Hunter, Stevie': 588,
#  'Corsair': 486,
#  "Ch'od": 377,
#  "Mam'selle Hepzibah": 378,
#  'Zero': 431,
#  'X-man / Nathan Grey': 403,
#  "Karma / Xi'an Coy Manh": 331,
#  'Mr. Fantastic Doppel': 1153,
#  'Beyonder': 482,
#  'Multiple Man / James A': 2008,
#  'Colossus Ii Doppelga': 325,
#  'Scanner Ii': 139,
#  'Ka-zar / Kevin Plunder': 418,
#  'White Queen / Emma Fro': 514,
#  'Magma / Amara Aquilla / ': 333,
#  'Thanos Doppelganger': 1688,
#  'Magus': 2249,
#  'Knight, Misty': 259,
#  'Wing, Colleen': 53,
#  'Puppet Master / Philli': 273,
#  'Maximus [inhuman]': 185,
#  'Punisher Ii / Frank Ca': 333,
#  'Zeus': 217,
#  'Box Iv / Madison Jeffr': 156,
#  'Thena': 159,
#  'Black Cat / Felicia Ha': 270,
#  'Gee / Alex Power': 123,
#  'Spider-man Clone / Ben': 111,
#  'Ulik': 128,
#  'Citizen V Ii / Helmut': 285,
#  'High Evolutionary / He': 439,
#  'Hobgoblin V / Jason Ph': 213,
#  'Ghost Rider Iii / Dan': 111,
#  'Cushing, Kate': 224,
#  'Katzenberg, Nick': 174,
#  'Vizier': 208,
#  'Tombstone / Lonnie Tho': 154,
#  'Mercado, Joy': 191,
#  'Hammerhead': 138,
#  'Arranger / ': 170,
#  'Osborn, Harry': 291,
#  'Cobra / Klaus Vorhees': 64,
#  'Leeds, Ned': 228,
#  'Watson, Anna': 249,
#  'Urich, Ben': 431,
#  'Robertson, Randy': 199,
#  'Page, Karen': 97,
#  'Grant, Gloria Glory': 295,
#  'Lubenski, Nate': 162,
#  'Ikaris / Ike Harris [e': 114,
#  'Rosenthal, Bernie': 133,
#  'Gladiator Ii': 214,
#  'Beta Ray Bill': 188,
#  'Bridge, George Washi': 92,
#  'Diamond Lil / Lillian': 81,
#  'Asp Ii / Cleo': 27,
#  'Black Mamba / Tanya Se': 27,
#  'Meggan': 187,
#  'Austin, Susan': 122,
#  'Diamondback Ii / Rache': 120,
#  'Makkari / Mike Khary / I': 195,
#  'Hodge, Cameron': 301,
#  'Skin / Angelo Espinosa': 72,
#  'Husk / Paige Guthrie': 93,
#  'Deadpool / Jack / Wade W': 61}

# %%
# Get clustering coefficients
# These can be added to a node dataframe as in the previous chapter
nx.clustering(M)
# Out:
# {"Black Panther / T'chal": 0.5617821782178218,
#  'Loki [asgardian]': 0.5579058699101005,
#  'Mantis / ? Brandt': 0.9233333333333333,
#  'Iceman / Robert Bobby': 0.40794417606011807,
#  'Marvel Girl / Jean Grey': 0.42312526183493926,
#  'Cyclops / Scott Summer': 0.3353361649228219,
#  'Klaw / Ulysses Klaw': 0.7071977638015374,
#  'Human Torch / Johnny S': 0.3390544041450777,
#  'Richards, Franklin B': 0.5838509316770186,
#  'Wolverine / Logan': 0.2975508509755085,
#  'Firebird / Bonita Juar': 0.914651493598862,
#  'Mr. Fantastic / Reed R': 0.3174383428190535,
#  'Medusa / Medusalith Am': 0.8318367346938775,
#  'Dr. Strange / Stephen': 0.4581560283687943,
#  'Jack Of Hearts / Jack': 0.7773279352226721,
#  'Mephisto': 0.5948051948051948,
#  'Thanos': 0.7782217782217782,
#  'Swordsman / Jacques Du': 0.9047619047619048,
#  'Collector / Taneleer T': 0.903448275862069,
#  'Lockjaw [inhuman]': 0.8737373737373737,
#  'Sub-mariner / Namor Ma': 0.41337535703732886,
#  'Pharaoh Rama-tut': 0.7176470588235294,
#  'Ant-man Ii / Scott Har': 0.7192156862745098,
#  'Lyja Lazerfist [skru': 0.8044354838709677,
#  'Gorgon [inhuman]': 0.8847780126849895,
#  'Nighthawk Ii / Kyle Ri': 0.8508064516129032,
#  'Cage, Luke / Carl Luca': 0.6345848757271285,
#  'Colossus Ii / Peter Ra': 0.3509500512003641,
#  'Hellcat / Patsy Walker': 0.6758328926493918,
#  'Karnak [inhuman]': 0.8818181818181818,
#  'Death': 0.8372093023255814,
#  'Redwing': 0.7133333333333334,
#  'Daredevil / Matt Murdo': 0.4095785440613027,
#  'Norriss, Sister Barb': 0.6797814207650273,
#  'Rage / Elvin Daryl Hal': 0.8094357076780758,
#  'Starfox / Eros': 0.6415525114155252,
#  'Demolition Man / Denni': 0.8022988505747126,
#  'Sersi / Sylvia': 0.5739235170129479,
#  'Spider-man / Peter Parker': 0.276201750306515,
#  'Vision': 0.29550890247143236,
#  'Uatu': 0.6997892201144233,
#  'Binary / Carol Danvers': 0.5499316005471956,
#  'Gyrich, Henry Peter': 0.6632996632996633,
#  'Nightcrawler / Kurt Wa': 0.39606432923783835,
#  'Angel / Warren Kenneth': 0.39180050718512255,
#  'Silver Surfer / Norrin': 0.5265631676399374,
#  'She-hulk / Jennifer Wa': 0.37250047609979053,
#  'Ghaur [deviant]': 0.8157894736842105,
#  'Dr. Doom / Victor Von': 0.5186031746031746,
#  'Storm / Ororo Munroe S': 0.3464216095795043,
#  'Scarlet Witch / Wanda': 0.33203354521660167,
#  'Toad / Mortimer Toynbe': 0.7638691322901849,
#  'Hulk / Dr. Robert Bruce Banner': 0.3633052030842086,
#  'Firestar / Angelica Jo': 0.6493284493284494,
#  'Wonder Man / Simon Wil': 0.4201863354037267,
#  'Drax / Arthur Douglas': 0.8313513513513513,
#  'Dugan, Timothy Aloyi': 0.7313829787234043,
#  'Carter, Sharon': 0.8,
#  'Black Knight V / Dane': 0.46707193515704154,
#  'Sunfire / Shiro Yoshid': 0.7474509803921568,
#  'Triton': 0.8620199146514936,
#  'Ultron': 0.8288084464555053,
#  'Jones, Richard Milho': 0.7191316146540027,
#  'Iron Man / Tony Stark': 0.2918109544944642,
#  'Nelson, Franklin Fog': 0.5448717948717948,
#  'Captain America': 0.23792718607667482,
#  'Jarvis, Edwin': 0.4098986285032797,
#  'Quasar Iii / Wendell V': 0.5221935483870968,
#  'Jameson, J. Jonah': 0.4670109007458405,
#  'Masters, Alicia Reis': 0.8064125831820932,
#  'Magneto / Magnus / Eric': 0.446944879646774,
#  'Invisible Woman / Sue': 0.33000264340470525,
#  'Professor X / Charles': 0.3572855464159812,
#  'Iron Fist / Daniel Ran': 0.6811688311688312,
#  'Black Bolt / Blackanto': 0.8974630021141649,
#  'Hawk': 0.35976331360946745,
#  'Sandman / William Bake': 0.7064935064935065,
#  'Falcon / Sam Wilson': 0.5834767641996558,
#  'Stingray / Dr. Walter': 0.817923186344239,
#  'Justice Ii / Vance Ast': 0.7448979591836735,
#  'Hercules [greek God]': 0.3804609563123495,
#  'Usagent / Captain John': 0.6610565684899485,
#  'Captain Marvel Ii / Mo': 0.5529139490847885,
#  'Crystal [inhuman]': 0.5865548827821767,
#  'Tigra / Greer Nelson': 0.6843156843156843,
#  'Spider-woman Ii / Juli': 0.6626716604244695,
#  'Machine Man / X-51': 0.9014396456256921,
#  'Mockingbird / Dr. Barb': 0.7398202009518773,
#  'Captain Marvel / Capta': 0.8468468468468469,
#  'Wasp / Janet Van Dyne': 0.33775173512344975,
#  'Fury, Col. Nicholas': 0.4903897019925939,
#  'Thor / Dr. Donald Blak': 0.284026781444285,
#  'Quicksilver / Pietro M': 0.4110341533317411,
#  'Captain Britain / Bria': 0.7315010570824524,
#  'Shadowcat / Katherine': 0.46918457648546147,
#  'Black Widow / Natasha': 0.43658559314136614,
#  'Ant-man / Dr. Henry J.': 0.38839657653563586,
#  'Moon Knight / Marc Spe': 0.7399829497016198,
#  'Jocasta': 0.9002849002849003,
#  'Moondragon / Heather D': 0.6476299257567104,
#  'Thing / Benjamin J. Gr': 0.3013031459786758,
#  'Beast / Henry &hank& P': 0.31850789096126253,
#  'Nova / Richard Rider': 0.6226917951646678,
#  'Wrecker Iii / Dirk Gar': 0.7176799440950384,
#  'Warlock Ii / Adam Warl': 0.8241441441441442,
#  'Piledriver Ii / Brian': 0.7891156462585034,
#  'Thunderball / Dr. Elio': 0.7016835016835017,
#  'Dr. Octopus / Otto Oct': 0.62531328320802,
#  'Banner, Betty Ross T': 0.8723723723723724,
#  'Avalanche / Dominic Pe': 0.7705802968960864,
#  'Attuma': 0.8804347826086957,
#  'Hela [asgardian]': 0.5284090909090909,
#  'Doc Samson / Dr. Leona': 0.8782051282051282,
#  'Guardian / James Macdo': 0.8636363636363636,
#  'Northstar / Jean-paul': 0.7911884487226953,
#  'Dr. Druid / Anthony Lu': 0.8350100603621731,
#  'Watson-parker, Mary': 0.4869933454325469,
#  'Mystique / Raven Darkh': 0.6454930429522081,
#  'Pyro / Allerdyce Johnn': 0.714975845410628,
#  'Destiny Ii / Irene Adl': 0.7916666666666666,
#  'Mister Hyde / Calvin Z': 0.6847826086956522,
#  'Ghost Rider Ii / Johnn': 0.7948717948717948,
#  'Mole Man / Harvey Rupe': 0.9142857142857143,
#  'Firelord / Pyreus Kril': 0.8571428571428571,
#  'Leader / Sam Sterns': 1.0,
#  'Le Fey, Morgan': 0.9215686274509803,
#  'Bulldozer / Henry Camp': 0.7891156462585034,
#  'Forgotten One / Gilgam': 0.8201058201058201,
#  'Balder [asgardian]': 0.678030303030303,
#  'Hogun [asgardian]': 0.5697674418604651,
#  'Hellstorm / Daimon Hel': 0.9021164021164021,
#  'Aurora / Jeanne-marie': 0.8282485875706215,
#  "O'brien, Michael": 0.7789661319073083,
#  'Stankowicz, Fabian': 0.8633333333333333,
#  'Screaming Mimi / Melis': 0.7632183908045977,
#  'Moonstone Ii / Karla S': 0.7128205128205128,
#  'Fixer Ii / Paul Norber': 0.7112299465240641,
#  'Darkstar / Laynia Serg': 0.8891129032258065,
#  'Vanguard / Nicolai Kry': 0.9166666666666666,
#  'Gamora': 0.9216832261835184,
#  'Psylocke / Elisabeth B': 0.4909784871616933,
#  'Rogue  / ': 0.3906029867568329,
#  'Sasquatch / Walter Lan': 0.7179135209334249,
#  'Luna / Luna Maximoff [': 0.8793103448275862,
#  'Whizzer Ii / Stanley S': 0.9142857142857143,
#  'Dr. Spectrum / Joseph': 0.9142857142857143,
#  'Kingpin / Wilson Fisk': 0.4592198581560284,
#  'Clea': 0.9,
#  'Polaris / Lorna Dane': 0.5446355446355446,
#  'De La Fontaine, Cont': 0.7532467532467533,
#  'Heimdall [asgardian]': 0.8354978354978355,
#  'Red Skull / Johann Sch': 0.6102418207681366,
#  'Thompson, Eugene Fla': 0.5888501742160279,
#  'Wong': 0.886021505376344,
#  'Parker, May': 0.5991140642303433,
#  'Green Goblin / Norman': 0.8181818181818182,
#  'Night Thrasher / Duane': 0.7753846153846153,
#  'Eternity / Adam Qadmon': 0.8868852459016393,
#  'Galactus / Galan': 0.6574794866400169,
#  'Triathlon / Delroy Gar': 0.8835978835978836,
#  'Beetle / Abner Ronald': 0.6656565656565656,
#  'Lilandra Neramani [s': 0.6398809523809523,
#  'Odin [asgardian]': 0.5863636363636363,
#  'Hogan, Virginia Pepp': 0.9416666666666667,
#  'Mad Dog / Colonel Buzz': 0.7904761904761904,
#  'Kincaid, Dr. Jane Fo': 0.6587301587301587,
#  'Wizard / Bentley Wittm': 0.7610837438423645,
#  'Charcoal / Charlie Bur': 0.7857142857142857,
#  'Blob / Fred J. Dukes': 0.6287678476996298,
#  'Cloak / Tyrone Johnson': 0.5942028985507246,
#  'Thunderstrike / Eric K': 0.6219193427931292,
#  'Power Man / Erik Joste': 0.6736353077816493,
#  'Human Torch Android / ': 0.7428571428571429,
#  'Juggernaut / Cain Mark': 0.8022988505747126,
#  'Absorbing Man / Carl C': 0.7398190045248869,
#  'Volstagg': 0.5682926829268292,
#  'Shaman / Michael Twoyo': 0.7881081081081082,
#  'Snowbird / Narya / Anne': 0.8758620689655172,
#  'Dagger / Tandy Bowen': 0.6724137931034483,
#  'Phoenix Iii / Rachel S': 0.623340321453529,
#  'Mandarin': 0.7662337662337663,
#  'Fandral [asgardian]': 0.5515151515151515,
#  'Ms. Marvel Ii / Sharon': 0.8153846153846154,
#  'Pip / Prince Gofern': 0.8864406779661017,
#  'Enchantress / Amora / He': 0.624467178175618,
#  'Jameson, Col. John': 0.5206349206349207,
#  'Cooper, Dr. Valerie': 0.5842650103519669,
#  'Nova Ii / Frankie Raye': 0.874451273046532,
#  'Darkhawk / Chris Powel': 0.7788819875776397,
#  'Nomad Iii / Jack Monro': 0.6061538461538462,
#  'Robertson, Joe': 0.5561224489795918,
#  'Gargoyle Ii / Isaac Ch': 0.8243243243243243,
#  'Namorita / Nita Prenti': 0.6638616175783076,
#  'Iron Man Iv / James R.': 0.7307692307692307,
#  'Ross, Gen. Thaddeus': 0.9458128078817734,
#  'Harkness, Agatha': 0.8171565276828435,
#  'Carter, Peggy': 0.6504201680672269,
#  'Hyperion': 0.8421052631578947,
#  'Living Lightning / Mig': 0.7901504787961696,
#  'Jones, Gabe': 0.8042328042328042,
#  'Osborn, Liz Allan': 0.6415362731152204,
#  'Leeds, Betty Brant': 0.6195121951219512,
#  'Sif': 0.631578947368421,
#  'Dazzler Ii / Allison B': 0.7315233785822021,
#  'Molecule Man / Owen Re': 0.9371794871794872,
#  'Speedball / Robbie Bal': 0.7734107997265892,
#  'Lizard / Dr. Curtis Co': 0.6897163120567376,
#  'Volcana / Marsha Rosen': 0.9761904761904762,
#  'Lockheed': 0.649795918367347,
#  'Titania Ii / Mary Skee': 0.8283499446290143,
#  'Boomer / Tabitha Smith': 0.6088578088578088,
#  'Summers, Nathan Chri': 0.5468704084631207,
#  'Summers, Madelyne Ma': 0.7867867867867868,
#  'Mactaggert, Moira Ki': 0.5534465534465535,
#  'Cannonball Ii / Sam Gu': 0.4190158465387823,
#  'Tilby, Trish / Patrici': 0.8011363636363636,
#  'Skids / Sally Blevins': 0.7479838709677419,
#  'Wolfsbane / Rahne Sinc': 0.4700149925037481,
#  'Leech': 0.6587301587301587,
#  'Mirage Ii / Danielle M': 0.5486993345432547,
#  'Gambit / Remy Lebeau': 0.518732782369146,
#  'Jubilee / Jubilation L': 0.6528345996493279,
#  'Strong Guy / Guido Car': 0.652875175315568,
#  'Spiral': 0.8078817733990148,
#  'Banshee / Sean Cassidy': 0.5630861040068201,
#  'Legion Ii / David Hall': 0.9285714285714286,
#  'Havok / Alex Summers': 0.5106215578284815,
#  'Longshot': 0.8522727272727273,
#  'Forge': 0.6339421613394216,
#  'Sabretooth / Victor Cr': 0.8448717948717949,
#  'Maddicks, Arthur Art': 0.6923076923076923,
#  'Warlock Iii': 0.6019871420222093,
#  'Rictor / Julio Esteban': 0.6915820029027576,
#  'Sunspot / Roberto Daco': 0.5079795242396868,
#  'Firefist / Rusty Colli': 0.6733870967741935,
#  'Bishop  / ': 0.6435469710272168,
#  'Daytripper / Amanda Se': 0.86,
#  'Wild Child / Kyle Gibn': 0.8272727272727273,
#  'Thunderbird Ii / James': 0.6458211572180012,
#  'Sauron / Dr. Karl Lyko': 0.89,
#  'Siryn / Theresa Rourke': 0.7002902757619739,
#  'Shatterstar Ii / Gavee': 0.7921022067363531,
#  'Marrow / Sarah': 0.803030303030303,
#  'Feral / Maria Callasan': 0.8174603174603174,
#  'Callisto': 0.8603988603988604,
#  'Mr. Sinister / Nathan': 0.9080459770114943,
#  'Raza Longknife': 0.8783068783068783,
#  'Spider-woman / Jessica': 0.8528735632183908,
#  'Cypher / Doug Ramsey': 0.7182926829268292,
#  "Deathbird [shi'ar]": 0.7857142857142857,
#  'Hudson, Heather': 0.7603131586871424,
#  'Stryfe': 0.9233511586452763,
#  'Iron Man Doppelgange': 0.996135265700483,
#  'Puck / Eugene Milton J': 0.7617656604998377,
#  'Silhouette': 0.8722689075630252,
#  'Cortez, Fabian': 0.9,
#  'Black King / Sebastian': 0.864516129032258,
#  'Magik / Illyana Rasput': 0.7378048780487805,
#  'Zabu': 0.7633333333333333,
#  'Domino Iii / Beatrice / ': 0.8297101449275363,
#  'Caliban / ': 0.7402439024390244,
#  'Apocalypse / En Sabah': 0.6772727272727272,
#  'Hunter, Stevie': 0.8364153627311522,
#  'Corsair': 0.8168067226890756,
#  "Ch'od": 0.8666666666666667,
#  "Mam'selle Hepzibah": 0.8689655172413793,
#  'Zero': 0.9268817204301075,
#  'X-man / Nathan Grey': 0.8666666666666667,
#  "Karma / Xi'an Coy Manh": 0.8152709359605911,
#  'Mr. Fantastic Doppel': 0.9804421768707483,
#  'Beyonder': 0.765079365079365,
#  'Multiple Man / James A': 0.7045614035087719,
#  'Colossus Ii Doppelga': 1.0,
#  'Scanner Ii': 0.8128654970760234,
#  'Ka-zar / Kevin Plunder': 0.7916666666666666,
#  'White Queen / Emma Fro': 0.658974358974359,
#  'Magma / Amara Aquilla / ': 0.8809523809523809,
#  'Thanos Doppelganger': 0.9224043715846995,
#  'Magus': 0.8798904538341158,
#  'Knight, Misty': 0.7378917378917379,
#  'Wing, Colleen': 0.803030303030303,
#  'Puppet Master / Philli': 0.91,
#  'Maximus [inhuman]': 0.9736842105263158,
#  'Punisher Ii / Frank Ca': 0.47368421052631576,
#  'Zeus': 0.7862318840579711,
#  'Box Iv / Madison Jeffr': 0.8210526315789474,
#  'Thena': 0.6883116883116883,
#  'Black Cat / Felicia Ha': 0.6650246305418719,
#  'Gee / Alex Power': 0.5324675324675324,
#  'Spider-man Clone / Ben': 0.6491228070175439,
#  'Ulik': 0.7485380116959064,
#  'Citizen V Ii / Helmut': 0.6129032258064516,
#  'High Evolutionary / He': 0.5353658536585366,
#  'Hobgoblin V / Jason Ph': 0.6553846153846153,
#  'Ghost Rider Iii / Dan': 0.6491228070175439,
#  'Cushing, Kate': 0.8853754940711462,
#  'Katzenberg, Nick': 0.9157894736842105,
#  'Vizier': 0.8221343873517787,
#  'Tombstone / Lonnie Tho': 0.7333333333333333,
#  'Mercado, Joy': 0.9095238095238095,
#  'Hammerhead': 0.8070175438596491,
#  'Arranger / ': 0.8947368421052632,
#  'Osborn, Harry': 0.7698412698412699,
#  'Cobra / Klaus Vorhees': 0.5333333333333333,
#  'Leeds, Ned': 0.8260869565217391,
#  'Watson, Anna': 0.7661538461538462,
#  'Urich, Ben': 0.6471471471471472,
#  'Robertson, Randy': 0.8614718614718615,
#  'Page, Karen': 0.8083333333333333,
#  'Grant, Gloria Glory': 0.7804232804232805,
#  'Lubenski, Nate': 0.9473684210526315,
#  'Ikaris / Ike Harris [e': 0.8382352941176471,
#  'Rosenthal, Bernie': 0.6333333333333333,
#  'Gladiator Ii': 0.8458498023715415,
#  'Beta Ray Bill': 0.6811594202898551,
#  'Bridge, George Washi': 0.39826839826839827,
#  'Diamond Lil / Lillian': 0.8901098901098901,
#  'Asp Ii / Cleo': 0.9642857142857143,
#  'Black Mamba / Tanya Se': 0.9642857142857143,
#  'Meggan': 0.8904761904761904,
#  'Austin, Susan': 0.8970588235294118,
#  'Diamondback Ii / Rache': 0.631578947368421,
#  'Makkari / Mike Khary / I': 0.6,
#  'Hodge, Cameron': 0.8575498575498576,
#  'Skin / Angelo Espinosa': 0.7912087912087912,
#  'Husk / Paige Guthrie': 0.775,
#  'Deadpool / Jack / Wade W': 0.782051282051282}

# %%
# Find the average clustering coefficient
nx.average_clustering(M)
# Out:
# 0.7047201786696375

# %% [markdown]
# ## Bridges

# %%
# List a network's bridges
list(nx.bridges(M))
# Out:
# []

# %%
# Test if a network has any bridges
nx.has_bridges(M)
# Out:
# False

# %%
# List a network's local bridges
list(nx.local_bridges(M))
# Out:
# [('Death', 'Deadpool / Jack / Wade W', 3)]

# %% [markdown]
# ## Neighbors

# %%
# Find a node's neighbors
list(nx.neighbors(M, 'Death'))
# Out:
# ["Black Panther / T'chal",
#  'Iron Man / Tony Stark',
#  'Sub-mariner / Namor Ma',
#  'Nova / Richard Rider',
#  'Hulk / Dr. Robert Bruce Banner',
#  'Spider-man / Peter Parker',
#  'Wasp / Janet Van Dyne',
#  'Galactus / Galan',
#  'Silver Surfer / Norrin',
#  'Hawk',
#  'Scarlet Witch / Wanda',
#  'Uatu',
#  'Captain America',
#  'Thunderstrike / Eric K',
#  'Wonder Man / Simon Wil',
#  'Wolverine / Logan',
#  'She-hulk / Jennifer Wa',
#  'Vision',
#  'Storm / Ororo Munroe S',
#  'Eternity / Adam Qadmon',
#  'Quasar Iii / Wendell V',
#  'Black Widow / Natasha',
#  'Firelord / Pyreus Kril',
#  'Thor / Dr. Donald Blak',
#  'Richards, Franklin B',
#  'Deadpool / Jack / Wade W',
#  'Mephisto',
#  'Dr. Doom / Victor Von',
#  'Thing / Benjamin J. Gr',
#  'Gamora',
#  'Drax / Arthur Douglas',
#  'Nova Ii / Frankie Raye',
#  'Ant-man / Dr. Henry J.',
#  'Moondragon / Heather D',
#  'Pip / Prince Gofern',
#  'Thanos',
#  'Collector / Taneleer T',
#  'Captain Marvel / Capta',
#  'Warlock Ii / Adam Warl',
#  'Dr. Strange / Stephen',
#  'Starfox / Eros',
#  'Invisible Woman / Sue',
#  'Cyclops / Scott Summer']

# %%
# Find common neighbors of a node pair
list(nx.common_neighbors(M, 'Death', 'Thanos'))
# Out:
# ["Black Panther / T'chal",
#  'Iron Man / Tony Stark',
#  'Sub-mariner / Namor Ma',
#  'Nova / Richard Rider',
#  'Hulk / Dr. Robert Bruce Banner',
#  'Spider-man / Peter Parker',
#  'Galactus / Galan',
#  'Silver Surfer / Norrin',
#  'Hawk',
#  'Scarlet Witch / Wanda',
#  'Uatu',
#  'Captain America',
#  'Thunderstrike / Eric K',
#  'Wonder Man / Simon Wil',
#  'Wolverine / Logan',
#  'She-hulk / Jennifer Wa',
#  'Vision',
#  'Storm / Ororo Munroe S',
#  'Eternity / Adam Qadmon',
#  'Quasar Iii / Wendell V',
#  'Black Widow / Natasha',
#  'Firelord / Pyreus Kril',
#  'Thor / Dr. Donald Blak',
#  'Mephisto',
#  'Dr. Doom / Victor Von',
#  'Thing / Benjamin J. Gr',
#  'Gamora',
#  'Drax / Arthur Douglas',
#  'Nova Ii / Frankie Raye',
#  'Ant-man / Dr. Henry J.',
#  'Moondragon / Heather D',
#  'Pip / Prince Gofern',
#  'Captain Marvel / Capta',
#  'Warlock Ii / Adam Warl',
#  'Dr. Strange / Stephen',
#  'Starfox / Eros',
#  'Invisible Woman / Sue',
#  'Cyclops / Scott Summer']

# %% [markdown]
# ## Cycles/Loops

# %%
# Get a list of the basis of all cycle in the graph
# All larger cycles are based on these cycles, many of which are triangles
nx.cycle_basis(M)
# Out:
# [['Mystique / Raven Darkh', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Blob / Fred J. Dukes', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Pyro / Allerdyce Johnn', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Avalanche / Dominic Pe', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Marvel Girl / Jean Grey', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Angel / Warren Kenneth', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Jubilee / Jubilation L', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Beast / Henry &hank& P', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Cyclops / Scott Summer', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Iceman / Robert Bobby', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Tilby, Trish / Patrici', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Cannonball Ii / Sam Gu', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Banshee / Sean Cassidy', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Apocalypse / En Sabah', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Firefist / Rusty Colli', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Skids / Sally Blevins', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Caliban / ', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Boomer / Tabitha Smith', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Hodge, Cameron', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Leech', 'Maddicks, Arthur Art', 'Rictor / Julio Esteban'],
#  ['Wolverine / Logan',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Storm / Ororo Munroe S',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Jubilee / Jubilation L', 'Skin / Angelo Espinosa', 'Maddicks, Arthur Art'],
#  ['Professor X / Charles',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Colossus Ii / Peter Ra',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Cannonball Ii / Sam Gu', 'Skin / Angelo Espinosa', 'Maddicks, Arthur Art'],
#  ['Banshee / Sean Cassidy', 'Skin / Angelo Espinosa', 'Maddicks, Arthur Art'],
#  ['Gambit / Remy Lebeau',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Bishop  / ',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['White Queen / Emma Fro', 'Skin / Angelo Espinosa', 'Maddicks, Arthur Art'],
#  ['Husk / Paige Guthrie', 'Skin / Angelo Espinosa', 'Maddicks, Arthur Art'],
#  ['Leech', 'Skin / Angelo Espinosa', 'Maddicks, Arthur Art'],
#  ['Blob / Fred J. Dukes',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art'],
#  ['Rogue  / ',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Wolverine / Logan', 'Marrow / Sarah', 'Skin / Angelo Espinosa'],
#  ['Psylocke / Elisabeth B',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Marvel Girl / Jean Grey',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art'],
#  ['Storm / Ororo Munroe S', 'Marrow / Sarah', 'Skin / Angelo Espinosa'],
#  ['Angel / Warren Kenneth',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art'],
#  ['Jubilee / Jubilation L', 'Marrow / Sarah', 'Skin / Angelo Espinosa'],
#  ['Beast / Henry &hank& P',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art'],
#  ['Cyclops / Scott Summer',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art'],
#  ['Professor X / Charles', 'Marrow / Sarah', 'Skin / Angelo Espinosa'],
#  ['Iceman / Robert Bobby',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art'],
#  ['Colossus Ii / Peter Ra', 'Marrow / Sarah', 'Skin / Angelo Espinosa'],
#  ['Summers, Nathan Chri',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Polaris / Lorna Dane',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Tilby, Trish / Patrici',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art'],
#  ['Cannonball Ii / Sam Gu', 'Marrow / Sarah', 'Skin / Angelo Espinosa'],
#  ['Banshee / Sean Cassidy', 'Marrow / Sarah', 'Skin / Angelo Espinosa'],
#  ['Gambit / Remy Lebeau', 'Marrow / Sarah', 'Skin / Angelo Espinosa'],
#  ['Bishop  / ', 'Marrow / Sarah', 'Skin / Angelo Espinosa'],
#  ['Apocalypse / En Sabah',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art'],
#  ['Mactaggert, Moira Ki',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Rogue  / ', 'Callisto', 'Marrow / Sarah'],
#  ['Wolverine / Logan', 'Callisto', 'Marrow / Sarah'],
#  ['Psylocke / Elisabeth B', 'Callisto', 'Marrow / Sarah'],
#  ['Marvel Girl / Jean Grey', 'Callisto', 'Marrow / Sarah'],
#  ['Storm / Ororo Munroe S', 'Callisto', 'Marrow / Sarah'],
#  ['Angel / Warren Kenneth', 'Callisto', 'Marrow / Sarah'],
#  ['Beast / Henry &hank& P', 'Callisto', 'Marrow / Sarah'],
#  ['Cyclops / Scott Summer', 'Callisto', 'Marrow / Sarah'],
#  ['Cooper, Dr. Valerie',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Professor X / Charles', 'Callisto', 'Marrow / Sarah'],
#  ['Colossus Ii / Peter Ra', 'Callisto', 'Marrow / Sarah'],
#  ['Magneto / Magnus / Eric', 'Callisto', 'Marrow / Sarah'],
#  ['Cannonball Ii / Sam Gu', 'Callisto', 'Marrow / Sarah'],
#  ['Mirage Ii / Danielle M',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Banshee / Sean Cassidy', 'Callisto', 'Marrow / Sarah'],
#  ['Nightcrawler / Kurt Wa', 'Callisto', 'Marrow / Sarah'],
#  ['Forge',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Bishop  / ', 'Callisto', 'Marrow / Sarah'],
#  ['Shadowcat / Katherine', 'Callisto', 'Marrow / Sarah'],
#  ['Mactaggert, Moira Ki', 'Callisto', 'Marrow / Sarah'],
#  ['Caliban / ',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art'],
#  ['Rogue  / ', 'Lockheed', 'Callisto'],
#  ['Spider-man / Peter Parker', 'Lockheed', 'Callisto', 'Marrow / Sarah'],
#  ['Wolverine / Logan', 'Lockheed', 'Callisto'],
#  ['Psylocke / Elisabeth B', 'Lockheed', 'Callisto'],
#  ['Marvel Girl / Jean Grey', 'Lockheed', 'Callisto'],
#  ['Storm / Ororo Munroe S', 'Lockheed', 'Callisto'],
#  ['Angel / Warren Kenneth', 'Lockheed', 'Callisto'],
#  ['Cyclops / Scott Summer', 'Lockheed', 'Callisto'],
#  ['Professor X / Charles', 'Lockheed', 'Callisto'],
#  ['Havok / Alex Summers',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Dazzler Ii / Allison B', 'Lockheed', 'Callisto'],
#  ['Colossus Ii / Peter Ra', 'Lockheed', 'Callisto'],
#  ['Wolfsbane / Rahne Sinc',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Warlock Iii',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Sunspot / Roberto Daco',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Magik / Illyana Rasput', 'Lockheed', 'Callisto'],
#  ['Magneto / Magnus / Eric', 'Lockheed', 'Callisto'],
#  ['Cannonball Ii / Sam Gu', 'Lockheed', 'Callisto'],
#  ['Mirage Ii / Danielle M', 'Lockheed', 'Callisto'],
#  ['Daytripper / Amanda Se', 'Lockheed', 'Callisto'],
#  ['Nightcrawler / Kurt Wa', 'Lockheed', 'Callisto'],
#  ['Phoenix Iii / Rachel S', 'Lockheed', 'Callisto'],
#  ['Shadowcat / Katherine', 'Lockheed', 'Callisto'],
#  ['Mactaggert, Moira Ki', 'Lockheed', 'Callisto'],
#  ['Rogue  / ', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Spider-man / Peter Parker', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Captain America', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Wolverine / Logan', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Storm / Ororo Munroe S', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Professor X / Charles', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Colossus Ii / Peter Ra', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Wolfsbane / Rahne Sinc', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Warlock Iii', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Sunspot / Roberto Daco', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Magik / Illyana Rasput', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Magneto / Magnus / Eric', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Cannonball Ii / Sam Gu', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Mirage Ii / Danielle M', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Nightcrawler / Kurt Wa', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Phoenix Iii / Rachel S', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Shadowcat / Katherine', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Mactaggert, Moira Ki', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Cypher / Doug Ramsey', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['White Queen / Emma Fro',
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa'],
#  ['Black King / Sebastian', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Lilandra Neramani [s', 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ['Thunderbird Ii / James',
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Hunter, Stevie',
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Siryn / Theresa Rourke',
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Rogue  / ', "Karma / Xi'an Coy Manh", 'Magma / Amara Aquilla / '],
#  ['Wolverine / Logan', "Karma / Xi'an Coy Manh", 'Magma / Amara Aquilla / '],
#  ['Storm / Ororo Munroe S',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Professor X / Charles',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Beyonder', "Karma / Xi'an Coy Manh", 'Magma / Amara Aquilla / '],
#  ['Colossus Ii / Peter Ra',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Wolfsbane / Rahne Sinc',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Warlock Iii', "Karma / Xi'an Coy Manh", 'Magma / Amara Aquilla / '],
#  ['Sunspot / Roberto Daco',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Magik / Illyana Rasput',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Magneto / Magnus / Eric',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Cannonball Ii / Sam Gu',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Mirage Ii / Danielle M',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Nightcrawler / Kurt Wa',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Phoenix Iii / Rachel S',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Shadowcat / Katherine',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Mactaggert, Moira Ki',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Lilandra Neramani [s',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Thunderbird Ii / James',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Hunter, Stevie', "Karma / Xi'an Coy Manh", 'Magma / Amara Aquilla / '],
#  ['Cypher / Doug Ramsey',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Corsair', "Karma / Xi'an Coy Manh", 'Magma / Amara Aquilla / ', 'Lockheed'],
#  ["Mam'selle Hepzibah",
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Rogue  / ', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ['Wolverine / Logan', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ['Storm / Ororo Munroe S', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ['Mr. Fantastic / Reed R',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Thing / Benjamin J. Gr',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Cyclops / Scott Summer',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Professor X / Charles', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ['Colossus Ii / Peter Ra', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ['Wolfsbane / Rahne Sinc', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ['Sunspot / Roberto Daco', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ['Magik / Illyana Rasput', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ['Magneto / Magnus / Eric', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ['Cannonball Ii / Sam Gu', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ['Mirage Ii / Danielle M', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ['Banshee / Sean Cassidy',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto'],
#  ['Nightcrawler / Kurt Wa', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ['Phoenix Iii / Rachel S', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ['Shadowcat / Katherine', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ['Binary / Carol Danvers',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Lilandra Neramani [s', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ["Deathbird [shi'ar]",
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah'],
#  ['Cypher / Doug Ramsey', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ['Corsair', 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ["Ch'od", 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ["Mam'selle Hepzibah", 'Raza Longknife', "Karma / Xi'an Coy Manh"],
#  ['Wolverine / Logan', 'Gladiator Ii', 'Raza Longknife'],
#  ['Vision', 'Gladiator Ii', 'Raza Longknife'],
#  ['Psylocke / Elisabeth B',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Storm / Ororo Munroe S', 'Gladiator Ii', 'Raza Longknife'],
#  ['Mr. Fantastic / Reed R', 'Gladiator Ii', 'Raza Longknife'],
#  ['Thing / Benjamin J. Gr', 'Gladiator Ii', 'Raza Longknife'],
#  ['Beast / Henry &hank& P',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto'],
#  ['Cyclops / Scott Summer', 'Gladiator Ii', 'Raza Longknife'],
#  ['Professor X / Charles', 'Gladiator Ii', 'Raza Longknife'],
#  ['Human Torch / Johnny S',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Colossus Ii / Peter Ra', 'Gladiator Ii', 'Raza Longknife'],
#  ['Corsair', 'Gladiator Ii', 'Raza Longknife'],
#  ["Ch'od", 'Gladiator Ii', 'Raza Longknife'],
#  ['Lilandra Neramani [s', 'Gladiator Ii', 'Raza Longknife'],
#  ['Banshee / Sean Cassidy', 'Gladiator Ii', 'Raza Longknife'],
#  ['Gambit / Remy Lebeau',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah'],
#  ["Mam'selle Hepzibah", 'Gladiator Ii', 'Raza Longknife'],
#  ['Nightcrawler / Kurt Wa', 'Gladiator Ii', 'Raza Longknife'],
#  ["Deathbird [shi'ar]", 'Gladiator Ii', 'Raza Longknife'],
#  ['Iron Man Iv / James R.',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Rogue  / ', 'Invisible Woman / Sue', 'Gladiator Ii', 'Raza Longknife'],
#  ['Spider-man / Peter Parker',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Galactus / Galan',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Silver Surfer / Norrin', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['Scarlet Witch / Wanda', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['Quicksilver / Pietro M',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Captain America',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / '],
#  ['Wolverine / Logan', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['She-hulk / Jennifer Wa',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Vision', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['Psylocke / Elisabeth B', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['Marvel Girl / Jean Grey',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Storm / Ororo Munroe S', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['Mr. Fantastic / Reed R', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['Angel / Warren Kenneth',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Jubilee / Jubilation L',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah'],
#  ['Thing / Benjamin J. Gr', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['Nightcrawler / Kurt Wa', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['Beast / Henry &hank& P', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['Magneto / Magnus / Eric',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife'],
#  ['Polaris / Lorna Dane',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah'],
#  ['Phoenix Iii / Rachel S',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife'],
#  ['Lilandra Neramani [s', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['Gambit / Remy Lebeau', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['Dazzler Ii / Allison B',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Dr. Doom / Victor Von',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Iceman / Robert Bobby',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah'],
#  ['Forge',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto'],
#  ['Warlock Iii',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh"],
#  ['Sunspot / Roberto Daco',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife'],
#  ['Colossus Ii / Peter Ra', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['Shadowcat / Katherine',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife'],
#  ['Binary / Carol Danvers',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife'],
#  ['Hela [asgardian]',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Professor X / Charles', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['Summers, Nathan Chri',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah'],
#  ['Thor / Dr. Donald Blak',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['X-man / Nathan Grey',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah'],
#  ['Strong Guy / Guido Car',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Multiple Man / James A',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Sunfire / Shiro Yoshid',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah'],
#  ['Captain Britain / Bria',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Apocalypse / En Sabah',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah'],
#  ['Human Torch / Johnny S', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['Cyclops / Scott Summer', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['Cannonball Ii / Sam Gu',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife'],
#  ['Banshee / Sean Cassidy', 'Invisible Woman / Sue', 'Gladiator Ii'],
#  ['Wolfsbane / Rahne Sinc',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife'],
#  ['Loki [asgardian]',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Bishop  / ',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto'],
#  ['Havok / Alex Summers',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Beyonder',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh"],
#  ['Richards, Franklin B',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art'],
#  ['Iron Man / Tony Stark', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Iron Man Iv / James R.', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Rogue  / ', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Thunderball / Dr. Elio',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Spider-man / Peter Parker',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Wasp / Janet Van Dyne', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Galactus / Galan', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Silver Surfer / Norrin', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Hawk', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Captain America', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Wolverine / Logan', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['She-hulk / Jennifer Wa', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Storm / Ororo Munroe S', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Mr. Fantastic / Reed R', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Thing / Benjamin J. Gr', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Cyclops / Scott Summer', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Thor / Dr. Donald Blak', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Spider-woman Ii / Juli', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Professor X / Charles', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Ultron', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Human Torch / Johnny S', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Beyonder', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Dr. Octopus / Otto Oct', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Colossus Ii / Peter Ra', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Magneto / Magnus / Eric',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Dr. Doom / Victor Von', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Nightcrawler / Kurt Wa', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Klaw / Ulysses Klaw', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Pharaoh Rama-tut', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Captain Marvel Ii / Mo', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Piledriver Ii / Brian',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Bulldozer / Henry Camp',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Titania Ii / Mary Skee', 'Molecule Man / Owen Re', 'Invisible Woman / Sue'],
#  ['Wrecker Iii / Dirk Gar',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed'],
#  ['Iron Man Iv / James R.',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Rogue  / ', 'Volcana / Marsha Rosen', 'Molecule Man / Owen Re'],
#  ['Thunderball / Dr. Elio',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Spider-man / Peter Parker',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Wasp / Janet Van Dyne', 'Volcana / Marsha Rosen', 'Molecule Man / Owen Re'],
#  ['Galactus / Galan', 'Volcana / Marsha Rosen', 'Molecule Man / Owen Re'],
#  ['Hawk', 'Volcana / Marsha Rosen', 'Molecule Man / Owen Re'],
#  ['Captain America', 'Volcana / Marsha Rosen', 'Molecule Man / Owen Re'],
#  ['Wolverine / Logan', 'Volcana / Marsha Rosen', 'Molecule Man / Owen Re'],
#  ['She-hulk / Jennifer Wa',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Storm / Ororo Munroe S',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Mr. Fantastic / Reed R',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Thing / Benjamin J. Gr',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Cyclops / Scott Summer',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Enchantress / Amora / He',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Thor / Dr. Donald Blak',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Spider-woman Ii / Juli',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Professor X / Charles', 'Volcana / Marsha Rosen', 'Molecule Man / Owen Re'],
#  ['Ultron', 'Volcana / Marsha Rosen', 'Molecule Man / Owen Re'],
#  ['Human Torch / Johnny S',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Beyonder', 'Volcana / Marsha Rosen', 'Molecule Man / Owen Re'],
#  ['Dr. Octopus / Otto Oct',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Colossus Ii / Peter Ra',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Magneto / Magnus / Eric',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Dr. Doom / Victor Von', 'Volcana / Marsha Rosen', 'Molecule Man / Owen Re'],
#  ['Lizard / Dr. Curtis Co',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Klaw / Ulysses Klaw', 'Volcana / Marsha Rosen', 'Molecule Man / Owen Re'],
#  ['Nightcrawler / Kurt Wa',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Captain Marvel Ii / Mo',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Absorbing Man / Carl C',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Wrecker Iii / Dirk Gar',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Titania Ii / Mary Skee',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Piledriver Ii / Brian', 'Volcana / Marsha Rosen', 'Molecule Man / Owen Re'],
#  ['Bulldozer / Henry Camp',
#   'Volcana / Marsha Rosen',
#   'Molecule Man / Owen Re'],
#  ['Iron Man Iv / James R.',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Rogue  / ', 'Lizard / Dr. Curtis Co', 'Molecule Man / Owen Re'],
#  ['Thunderball / Dr. Elio',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Spider-man / Peter Parker',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Wasp / Janet Van Dyne', 'Lizard / Dr. Curtis Co', 'Molecule Man / Owen Re'],
#  ['Galactus / Galan', 'Lizard / Dr. Curtis Co', 'Molecule Man / Owen Re'],
#  ['Hawk', 'Lizard / Dr. Curtis Co', 'Molecule Man / Owen Re'],
#  ['Captain America', 'Lizard / Dr. Curtis Co', 'Molecule Man / Owen Re'],
#  ['Wolverine / Logan', 'Lizard / Dr. Curtis Co', 'Molecule Man / Owen Re'],
#  ['She-hulk / Jennifer Wa',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Storm / Ororo Munroe S',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Mr. Fantastic / Reed R',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Thing / Benjamin J. Gr',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Cyclops / Scott Summer',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Enchantress / Amora / He',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Thor / Dr. Donald Blak',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Spider-woman Ii / Juli',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Professor X / Charles', 'Lizard / Dr. Curtis Co', 'Molecule Man / Owen Re'],
#  ['Parker, May',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Robertson, Joe',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Leeds, Betty Brant',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Watson-parker, Mary',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Watson, Anna',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Ultron', 'Lizard / Dr. Curtis Co', 'Molecule Man / Owen Re'],
#  ['Jameson, J. Jonah',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Thompson, Eugene Fla',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Human Torch / Johnny S',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Dr. Octopus / Otto Oct',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Colossus Ii / Peter Ra',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Magneto / Magnus / Eric',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Osborn, Liz Allan',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Dr. Doom / Victor Von', 'Lizard / Dr. Curtis Co', 'Molecule Man / Owen Re'],
#  ['Wrecker Iii / Dirk Gar',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Bulldozer / Henry Camp',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Piledriver Ii / Brian', 'Lizard / Dr. Curtis Co', 'Molecule Man / Owen Re'],
#  ['Titania Ii / Mary Skee',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Captain Marvel Ii / Mo',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Pharaoh Rama-tut', 'Lizard / Dr. Curtis Co', 'Molecule Man / Owen Re'],
#  ['Klaw / Ulysses Klaw', 'Lizard / Dr. Curtis Co', 'Molecule Man / Owen Re'],
#  ['Absorbing Man / Carl C',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Nightcrawler / Kurt Wa',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Spider-man / Peter Parker', 'Robertson, Randy', 'Lizard / Dr. Curtis Co'],
#  ['Parker, May', 'Robertson, Randy', 'Lizard / Dr. Curtis Co'],
#  ['Robertson, Joe', 'Robertson, Randy', 'Lizard / Dr. Curtis Co'],
#  ['Leeds, Betty Brant', 'Robertson, Randy', 'Lizard / Dr. Curtis Co'],
#  ['Watson-parker, Mary', 'Robertson, Randy', 'Lizard / Dr. Curtis Co'],
#  ['Watson, Anna', 'Robertson, Randy', 'Lizard / Dr. Curtis Co'],
#  ['Jameson, J. Jonah', 'Robertson, Randy', 'Lizard / Dr. Curtis Co'],
#  ['Urich, Ben',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Thompson, Eugene Fla', 'Robertson, Randy', 'Lizard / Dr. Curtis Co'],
#  ['Grant, Gloria Glory', 'Robertson, Randy', 'Lizard / Dr. Curtis Co'],
#  ['Black Cat / Felicia Ha',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Osborn, Harry', 'Robertson, Randy', 'Lizard / Dr. Curtis Co'],
#  ['Green Goblin / Norman',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Osborn, Liz Allan', 'Robertson, Randy', 'Lizard / Dr. Curtis Co'],
#  ['Spider-man / Peter Parker', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Parker, May', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Robertson, Joe', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Leeds, Betty Brant', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Kingpin / Wilson Fisk', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Watson-parker, Mary', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Jameson, J. Jonah', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Urich, Ben', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Thompson, Eugene Fla', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Grant, Gloria Glory', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Tombstone / Lonnie Tho', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Osborn, Harry', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Osborn, Liz Allan', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Cushing, Kate', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Arranger / ', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Mercado, Joy', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Spider-man / Peter Parker', 'Hammerhead', 'Katzenberg, Nick'],
#  ['Parker, May', 'Hammerhead', 'Katzenberg, Nick'],
#  ['Robertson, Joe', 'Hammerhead', 'Katzenberg, Nick'],
#  ['Leeds, Betty Brant', 'Hammerhead', 'Katzenberg, Nick'],
#  ['Kingpin / Wilson Fisk', 'Hammerhead', 'Katzenberg, Nick'],
#  ['Watson-parker, Mary', 'Hammerhead', 'Katzenberg, Nick'],
#  ['Jameson, J. Jonah', 'Hammerhead', 'Katzenberg, Nick'],
#  ['Urich, Ben', 'Hammerhead', 'Katzenberg, Nick'],
#  ['Grant, Gloria Glory', 'Hammerhead', 'Katzenberg, Nick'],
#  ['Dr. Octopus / Otto Oct',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co'],
#  ['Tombstone / Lonnie Tho', 'Hammerhead', 'Katzenberg, Nick'],
#  ['Daredevil / Matt Murdo',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Leeds, Ned', 'Hammerhead', 'Katzenberg, Nick', 'Robertson, Randy'],
#  ['Hobgoblin V / Jason Ph', 'Hammerhead', 'Katzenberg, Nick'],
#  ['Cushing, Kate', 'Hammerhead', 'Katzenberg, Nick'],
#  ['Arranger / ', 'Hammerhead', 'Katzenberg, Nick'],
#  ['Iron Man / Tony Stark',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Wasp / Janet Van Dyne',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co'],
#  ['Hawk',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co'],
#  ['Scarlet Witch / Wanda',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Captain America',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co'],
#  ['Vision',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Cooper, Dr. Valerie',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto'],
#  ['Daredevil / Matt Murdo', 'Nomad Iii / Jack Monro', 'Hammerhead'],
#  ['Starfox / Eros',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Fury, Col. Nicholas',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Usagent / Captain John',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Screaming Mimi / Melis',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Power Man / Erik Joste',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Moonstone Ii / Karla S',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Falcon / Sam Wilson',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Beetle / Abner Ronald',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Fixer Ii / Paul Norber',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Citizen V Ii / Helmut',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Iron Man / Tony Stark', 'Charcoal / Charlie Bur', 'Nomad Iii / Jack Monro'],
#  ['Wasp / Janet Van Dyne', 'Charcoal / Charlie Bur', 'Nomad Iii / Jack Monro'],
#  ['Hawk', 'Charcoal / Charlie Bur', 'Nomad Iii / Jack Monro'],
#  ['Scarlet Witch / Wanda', 'Charcoal / Charlie Bur', 'Nomad Iii / Jack Monro'],
#  ['Captain America', 'Charcoal / Charlie Bur', 'Nomad Iii / Jack Monro'],
#  ['Wonder Man / Simon Wil',
#   'Charcoal / Charlie Bur',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Vision', 'Charcoal / Charlie Bur', 'Nomad Iii / Jack Monro'],
#  ['Cooper, Dr. Valerie', 'Charcoal / Charlie Bur', 'Nomad Iii / Jack Monro'],
#  ['Ant-man / Dr. Henry J.',
#   'Charcoal / Charlie Bur',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Bridge, George Washi',
#   'Charcoal / Charlie Bur',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue',
#   'Gladiator Ii',
#   'Raza Longknife',
#   "Karma / Xi'an Coy Manh",
#   'Magma / Amara Aquilla / ',
#   'Lockheed',
#   'Callisto',
#   'Marrow / Sarah',
#   'Skin / Angelo Espinosa',
#   'Maddicks, Arthur Art',
#   'Rictor / Julio Esteban'],
#  ['Klaw / Ulysses Klaw',
#   'Charcoal / Charlie Bur',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co'],
#  ['Binary / Carol Danvers',
#   'Charcoal / Charlie Bur',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Gyrich, Henry Peter', 'Charcoal / Charlie Bur', 'Nomad Iii / Jack Monro'],
#  ['Triathlon / Delroy Gar',
#   'Charcoal / Charlie Bur',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Fixer Ii / Paul Norber',
#   'Charcoal / Charlie Bur',
#   'Nomad Iii / Jack Monro'],
#  ['Citizen V Ii / Helmut', 'Charcoal / Charlie Bur', 'Nomad Iii / Jack Monro'],
#  ['Power Man / Erik Joste',
#   'Charcoal / Charlie Bur',
#   'Nomad Iii / Jack Monro'],
#  ['Moonstone Ii / Karla S',
#   'Charcoal / Charlie Bur',
#   'Nomad Iii / Jack Monro'],
#  ['Beetle / Abner Ronald', 'Charcoal / Charlie Bur', 'Nomad Iii / Jack Monro'],
#  ['Screaming Mimi / Melis',
#   'Charcoal / Charlie Bur',
#   'Nomad Iii / Jack Monro'],
#  ["Black Panther / T'chal",
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Iron Man / Tony Stark', 'Redwing', 'Nomad Iii / Jack Monro'],
#  ['Spider-man / Peter Parker',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead'],
#  ['Wasp / Janet Van Dyne', 'Redwing', 'Nomad Iii / Jack Monro'],
#  ['Hawk', 'Redwing', 'Nomad Iii / Jack Monro'],
#  ['Scarlet Witch / Wanda', 'Redwing', 'Nomad Iii / Jack Monro'],
#  ['Quicksilver / Pietro M',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Captain America', 'Redwing', 'Nomad Iii / Jack Monro'],
#  ['Vision', 'Redwing', 'Nomad Iii / Jack Monro'],
#  ['Beast / Henry &hank& P',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Carter, Sharon', 'Redwing', 'Nomad Iii / Jack Monro'],
#  ['Cage, Luke / Carl Luca',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Jarvis, Edwin',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Red Skull / Johann Sch', 'Redwing', 'Nomad Iii / Jack Monro'],
#  ['Fury, Col. Nicholas', 'Redwing', 'Nomad Iii / Jack Monro'],
#  ['Dugan, Timothy Aloyi',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Binary / Carol Danvers',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Falcon / Sam Wilson', 'Redwing', 'Nomad Iii / Jack Monro'],
#  ['Iron Fist / Daniel Ran',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Demolition Man / Denni', 'Redwing', 'Nomad Iii / Jack Monro'],
#  ['Iron Man / Tony Stark', 'Carter, Peggy', 'Redwing'],
#  ['Sub-mariner / Namor Ma',
#   'Carter, Peggy',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Wasp / Janet Van Dyne', 'Carter, Peggy', 'Redwing'],
#  ['Hawk', 'Carter, Peggy', 'Redwing'],
#  ['Quicksilver / Pietro M', 'Carter, Peggy', 'Redwing'],
#  ['Captain America', 'Carter, Peggy', 'Redwing'],
#  ['Thunderstrike / Eric K',
#   'Carter, Peggy',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Wonder Man / Simon Wil',
#   'Carter, Peggy',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['She-hulk / Jennifer Wa',
#   'Carter, Peggy',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co'],
#  ['Vision', 'Carter, Peggy', 'Redwing'],
#  ['Carter, Sharon', 'Carter, Peggy', 'Redwing'],
#  ['Thor / Dr. Donald Blak',
#   'Carter, Peggy',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co'],
#  ['Cobra / Klaus Vorhees', 'Carter, Peggy', 'Redwing'],
#  ['Jarvis, Edwin', 'Carter, Peggy', 'Redwing'],
#  ['Ant-man / Dr. Henry J.',
#   'Carter, Peggy',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Hercules [greek God]',
#   'Carter, Peggy',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Black Widow / Natasha',
#   'Carter, Peggy',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Daredevil / Matt Murdo',
#   'Carter, Peggy',
#   'Redwing',
#   'Nomad Iii / Jack Monro'],
#  ['Red Skull / Johann Sch', 'Carter, Peggy', 'Redwing'],
#  ['Fury, Col. Nicholas', 'Carter, Peggy', 'Redwing'],
#  ['Quasar Iii / Wendell V',
#   'Carter, Peggy',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Rosenthal, Bernie', 'Carter, Peggy', 'Redwing', 'Nomad Iii / Jack Monro'],
#  ['De La Fontaine, Cont', 'Carter, Peggy', 'Redwing'],
#  ['Jones, Gabe', 'Carter, Peggy', 'Redwing'],
#  ['Black Knight V / Dane',
#   'Carter, Peggy',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Falcon / Sam Wilson', 'Carter, Peggy', 'Redwing'],
#  ['Rage / Elvin Daryl Hal',
#   'Carter, Peggy',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Sersi / Sylvia',
#   'Carter, Peggy',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Iron Man / Tony Stark', "O'brien, Michael", 'Carter, Peggy'],
#  ['Sub-mariner / Namor Ma', "O'brien, Michael", 'Carter, Peggy'],
# ...
#  ['Thor / Dr. Donald Blak', 'Zeus', 'Balder [asgardian]'],
#  ['Ant-man / Dr. Henry J.',
#   'Zeus',
#   'Balder [asgardian]',
#   'Kincaid, Dr. Jane Fo'],
#  ['Hercules [greek God]', 'Zeus', 'Balder [asgardian]'],
#  ['Black Widow / Natasha',
#   'Zeus',
#   'Balder [asgardian]',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Volstagg', 'Zeus', 'Balder [asgardian]'],
#  ['Hogun [asgardian]', 'Zeus', 'Balder [asgardian]'],
#  ['Fandral [asgardian]', 'Zeus', 'Balder [asgardian]'],
#  ['Odin [asgardian]', 'Zeus', 'Balder [asgardian]'],
#  ['Dr. Druid / Anthony Lu',
#   'Zeus',
#   'Balder [asgardian]',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Sif', 'Zeus', 'Balder [asgardian]'],
#  ['Captain Marvel Ii / Mo', 'Zeus', 'Balder [asgardian]'],
#  ['Black Knight V / Dane', 'Zeus', 'Balder [asgardian]'],
#  ['Sersi / Sylvia',
#   'Zeus',
#   'Balder [asgardian]',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Silver Surfer / Norrin',
#   'Beta Ray Bill',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Scarlet Witch / Wanda', 'Beta Ray Bill', 'Kincaid, Dr. Jane Fo'],
#  ['Vision',
#   'Beta Ray Bill',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing'],
#  ['Mr. Fantastic / Reed R',
#   'Beta Ray Bill',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co'],
#  ['Heimdall [asgardian]', 'Beta Ray Bill', 'Kincaid, Dr. Jane Fo'],
#  ['Enchantress / Amora / He', 'Beta Ray Bill', 'Kincaid, Dr. Jane Fo'],
#  ['Loki [asgardian]', 'Beta Ray Bill', 'Kincaid, Dr. Jane Fo'],
#  ['Thor / Dr. Donald Blak', 'Beta Ray Bill', 'Kincaid, Dr. Jane Fo'],
#  ['Human Torch / Johnny S',
#   'Beta Ray Bill',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co'],
#  ['Hercules [greek God]', 'Beta Ray Bill', 'Kincaid, Dr. Jane Fo'],
#  ['Gee / Alex Power',
#   'Beta Ray Bill',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Volstagg', 'Beta Ray Bill', 'Kincaid, Dr. Jane Fo'],
#  ['Hogun [asgardian]', 'Beta Ray Bill', 'Kincaid, Dr. Jane Fo'],
#  ['Fandral [asgardian]', 'Beta Ray Bill', 'Kincaid, Dr. Jane Fo'],
#  ['Odin [asgardian]', 'Beta Ray Bill', 'Kincaid, Dr. Jane Fo'],
#  ['Richards, Franklin B',
#   'Beta Ray Bill',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Hela [asgardian]', 'Beta Ray Bill', 'Kincaid, Dr. Jane Fo'],
#  ['Starfox / Eros',
#   'Beta Ray Bill',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro'],
#  ['Sif', 'Beta Ray Bill', 'Kincaid, Dr. Jane Fo'],
#  ['Quasar Iii / Wendell V',
#   'Beta Ray Bill',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Captain Marvel Ii / Mo',
#   'Beta Ray Bill',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co'],
#  ['High Evolutionary / He', 'Beta Ray Bill', 'Kincaid, Dr. Jane Fo'],
#  ['Iron Man / Tony Stark', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Galactus / Galan',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co'],
#  ['Silver Surfer / Norrin',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Scarlet Witch / Wanda', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Captain America', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Thunderstrike / Eric K',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Vision', 'Sif', 'Kincaid, Dr. Jane Fo', 'Cobra / Klaus Vorhees', 'Redwing'],
#  ['Heimdall [asgardian]', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Enchantress / Amora / He', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Loki [asgardian]', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Thor / Dr. Donald Blak', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Dr. Strange / Stephen',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Jarvis, Edwin', 'Sif', 'Kincaid, Dr. Jane Fo', 'Cobra / Klaus Vorhees'],
#  ['Hercules [greek God]', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Volstagg', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Hogun [asgardian]', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Fandral [asgardian]', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Vizier', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Odin [asgardian]', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Hela [asgardian]', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Firelord / Pyreus Kril',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Mephisto',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Makkari / Mike Khary / I',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Starfox / Eros',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro'],
#  ['Black Knight V / Dane', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Captain Marvel Ii / Mo',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co'],
#  ['High Evolutionary / He', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Wrecker Iii / Dirk Gar',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co'],
#  ['Sersi / Sylvia',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Absorbing Man / Carl C', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Wasp / Janet Van Dyne',
#   'Ikaris / Ike Harris [e',
#   'Sif',
#   'Kincaid, Dr. Jane Fo'],
#  ['Scarlet Witch / Wanda', 'Ikaris / Ike Harris [e', 'Sif'],
#  ['Captain America', 'Ikaris / Ike Harris [e', 'Sif'],
#  ['She-hulk / Jennifer Wa',
#   'Ikaris / Ike Harris [e',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co'],
#  ['Vision', 'Ikaris / Ike Harris [e', 'Sif'],
#  ['Thor / Dr. Donald Blak', 'Ikaris / Ike Harris [e', 'Sif'],
#  ['Hercules [greek God]', 'Ikaris / Ike Harris [e', 'Sif'],
#  ['Volstagg', 'Ikaris / Ike Harris [e', 'Sif'],
#  ['Hogun [asgardian]', 'Ikaris / Ike Harris [e', 'Sif'],
#  ['Fandral [asgardian]', 'Ikaris / Ike Harris [e', 'Sif'],
#  ['Odin [asgardian]', 'Ikaris / Ike Harris [e', 'Sif'],
#  ['Makkari / Mike Khary / I', 'Ikaris / Ike Harris [e', 'Sif'],
#  ['Sersi / Sylvia', 'Ikaris / Ike Harris [e', 'Sif'],
#  ['Forgotten One / Gilgam',
#   'Ikaris / Ike Harris [e',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Ghaur [deviant]',
#   'Ikaris / Ike Harris [e',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Thena', 'Ikaris / Ike Harris [e', 'Sif'],
#  ['Sub-mariner / Namor Ma',
#   'Thena',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Quicksilver / Pietro M', 'Thena', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Captain America', 'Thena', 'Sif'],
#  ['She-hulk / Jennifer Wa',
#   'Thena',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co'],
#  ['Thor / Dr. Donald Blak', 'Thena', 'Sif'],
#  ['Cage, Luke / Carl Luca',
#   'Thena',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing'],
#  ['Hercules [greek God]', 'Thena', 'Sif'],
#  ['Volstagg', 'Thena', 'Sif'],
#  ['Hogun [asgardian]', 'Thena', 'Sif'],
#  ['Fandral [asgardian]', 'Thena', 'Sif'],
#  ['Odin [asgardian]', 'Thena', 'Sif'],
#  ['Human Torch Android / ', 'Thena', 'Sif', 'Kincaid, Dr. Jane Fo'],
#  ['Makkari / Mike Khary / I', 'Thena', 'Sif'],
#  ['Ant-man Ii / Scott Har',
#   'Thena',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Black Knight V / Dane', 'Thena', 'Sif'],
#  ['High Evolutionary / He', 'Thena', 'Sif'],
#  ['Iron Fist / Daniel Ran',
#   'Thena',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing'],
#  ['Sersi / Sylvia', 'Thena', 'Sif'],
#  ['Forgotten One / Gilgam',
#   'Thena',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Ghaur [deviant]',
#   'Thena',
#   'Sif',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Spider-man / Peter Parker',
#   'Vizier',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees'],
#  ['Captain America', 'Vizier', 'Kincaid, Dr. Jane Fo'],
#  ['Thunderstrike / Eric K',
#   'Vizier',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Heimdall [asgardian]', 'Vizier', 'Kincaid, Dr. Jane Fo'],
#  ['Enchantress / Amora / He', 'Vizier', 'Kincaid, Dr. Jane Fo'],
#  ['Loki [asgardian]', 'Vizier', 'Kincaid, Dr. Jane Fo'],
#  ['Thor / Dr. Donald Blak', 'Vizier', 'Kincaid, Dr. Jane Fo'],
#  ['Jarvis, Edwin', 'Vizier', 'Kincaid, Dr. Jane Fo', 'Cobra / Klaus Vorhees'],
#  ['Hercules [greek God]', 'Vizier', 'Kincaid, Dr. Jane Fo'],
#  ['Volstagg', 'Vizier', 'Kincaid, Dr. Jane Fo'],
#  ['Hogun [asgardian]', 'Vizier', 'Kincaid, Dr. Jane Fo'],
#  ['Fandral [asgardian]', 'Vizier', 'Kincaid, Dr. Jane Fo'],
#  ['Mephisto',
#   'Vizier',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['High Evolutionary / He', 'Vizier', 'Kincaid, Dr. Jane Fo'],
#  ['Absorbing Man / Carl C', 'Vizier', 'Kincaid, Dr. Jane Fo'],
#  ['Odin [asgardian]', 'Vizier', 'Kincaid, Dr. Jane Fo'],
#  ['Hela [asgardian]', 'Vizier', 'Kincaid, Dr. Jane Fo'],
#  ['Daredevil / Matt Murdo',
#   'Vizier',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees'],
#  ['Iron Man / Tony Stark', 'Fandral [asgardian]', 'Kincaid, Dr. Jane Fo'],
#  ['Sub-mariner / Namor Ma',
#   'Fandral [asgardian]',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Fandral [asgardian]',
#   'Kincaid, Dr. Jane Fo'],
#  ['Spider-man / Peter Parker',
#   'Fandral [asgardian]',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees'],
#  ['Silver Surfer / Norrin',
#   'Fandral [asgardian]',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re'],
#  ['Scarlet Witch / Wanda', 'Fandral [asgardian]', 'Kincaid, Dr. Jane Fo'],
#  ['Captain America', 'Fandral [asgardian]', 'Kincaid, Dr. Jane Fo'],
#  ['Thunderstrike / Eric K',
#   'Fandral [asgardian]',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['She-hulk / Jennifer Wa',
#   'Fandral [asgardian]',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co'],
#  ['Vision',
#   'Fandral [asgardian]',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing'],
#  ['Heimdall [asgardian]', 'Fandral [asgardian]', 'Kincaid, Dr. Jane Fo'],
#  ['Enchantress / Amora / He', 'Fandral [asgardian]', 'Kincaid, Dr. Jane Fo'],
#  ['Loki [asgardian]', 'Fandral [asgardian]', 'Kincaid, Dr. Jane Fo'],
#  ['Thor / Dr. Donald Blak', 'Fandral [asgardian]', 'Kincaid, Dr. Jane Fo'],
#  ['Wolfsbane / Rahne Sinc',
#   'Fandral [asgardian]',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ['Warlock Iii',
#   'Fandral [asgardian]',
#   'Kincaid, Dr. Jane Fo',
#   'Cobra / Klaus Vorhees',
#   'Redwing',
#   'Nomad Iii / Jack Monro',
#   'Hammerhead',
#   'Katzenberg, Nick',
#   'Robertson, Randy',
#   'Lizard / Dr. Curtis Co',
#   'Molecule Man / Owen Re',
#   'Invisible Woman / Sue'],
#  ...]
