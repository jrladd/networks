# %% [markdown]
# # Metrics
#
# NetworkX includes a huge amount of algorithms and metrics. Here's a cheatsheet to the most common ones you'll need.
#
# ## Network Properties

# %%
# Import NetworkX and key data science libraries
import networkx as nx
import pandas as pd
import numpy as np
import altair as alt

# Import Marvel network data
marvel= pd.read_csv("../data/marvel-unimodal-edges.csv")
M = nx.from_pandas_edgelist(marvel, source="Source", target="Target", edge_attr=True)
print(M)
# Out:
# Graph with 327 nodes and 9891 edges

# %%
M.number_of_nodes() # Number of nodes
# Out:
# 327

# %%
M.number_of_edges() # Alternative method for number of edges
# Out:
# 9891

# %%
M.is_directed() # Is the graph directed?
# Out:
# False

# %% [markdown]
# ## Paths

# %%
nx.shortest_path(M, "Black Panther / T'chal", 	"Gambit / Remy Lebeau") # Shortest path as list
# Out:
# ["Black Panther / T'chal", 'Firestar / Angelica Jo', 'Gambit / Remy Lebeau']

# %%
nx.shortest_path_length(M, "Black Panther / T'chal", "Gambit / Remy Lebeau") #Shortest path length (Distance)
# Out:
# 2

# %%
nx.average_shortest_path_length(M) # Average shortest path length (Average distance)
# Out:
# 1.873004258831917

# %%
nx.diameter(M)
# Out:
# 3

# %% [markdown]
# ## Components

# %%
nx.is_connected(M) # Is the graph connected?
# Out:
# True

# %%
nx.number_connected_components(M) # How many components are there?
# Out:
# 1

# %%
# Find the largest connected component (as a node set)
components = [G for G in nx.connected_components(M)]
largest = max(components, key=len)

# %% [markdown]
# ## Centrality
#
# Below I show just one example, but there are a range of [centrality functions](https://networkx.org/documentation/stable/reference/algorithms/centrality.html) in NetworkX.
#
# [n.b. I'll create a separate chapter on centrality soon.]

# %%
# Calculate betweenness centrality for every node
bc = nx.betweenness_centrality(M)

# %% [markdown]
# ## Triangles and Clustering

# %%
# Get number of triangles for every node
nx.triangles(M)

# n.b. Pay attention to the following note from the NetworkX docs:
# When computing triangles for the entire graph each triangle is counted three times, once at each node.
# Out:
# {"Black Panther / T'chal": 2837,
#  'Loki [asgardian]': 1055,
#  'Mantis / ? Brandt': 277,
#  'Iceman / Robert Bobby': 5320,
#  'Marvel Girl / Jean Grey': 5050,
#  'Cyclops / Scott Summer': 6474,
#  'Klaw / Ulysses Klaw': 1012,
#  'Human Torch / Johnny S': 6282,
#  'Richards, Franklin B': 2444,
#  'Wolverine / Logan': 7168,
#  'Firebird / Bonita Juar': 643,
#  'Mr. Fantastic / Reed R': 6191,
#  'Medusa / Medusalith Am': 1019,
#  'Dr. Strange / Stephen': 4522,
#  'Jack Of Hearts / Jack': 576,
#  'Mephisto': 916,
#  'Thanos': 2337,
#  'Swordsman / Jacques Du': 342,
#  'Collector / Taneleer T': 393,
#  'Lockjaw [inhuman]': 865,
#  'Sub-mariner / Namor Ma': 4197,
#  'Pharaoh Rama-tut': 2562,
#  'Ant-man Ii / Scott Har': 917,
#  'Lyja Lazerfist [skru': 399,
#  'Gorgon [inhuman]': 837,
#  'Nighthawk Ii / Kyle Ri': 422,
#  'Cage, Luke / Carl Luca': 1200,
#  'Colossus Ii / Peter Ra': 6169,
#  'Hellcat / Patsy Walker': 1278,
#  'Karnak [inhuman]': 873,
#  'Death': 756,
#  'Redwing': 214,
#  'Daredevil / Matt Murdo': 4276,
#  'Norriss, Sister Barb': 1244,
#  'Rage / Elvin Daryl Hal': 875,
#  'Starfox / Eros': 1686,
#  'Demolition Man / Denni': 349,
#  'Sersi / Sylvia': 1906,
#  'Spider-man / Peter Parker': 6533,
#  'Vision': 6672,
#  'Uatu': 2324,
#  'Binary / Carol Danvers': 2010,
#  'Gyrich, Henry Peter': 985,
#  'Nightcrawler / Kurt Wa': 3965,
#  'Angel / Warren Kenneth': 5562,
#  'Silver Surfer / Norrin': 3697,
#  'She-hulk / Jennifer Wa': 5868,
#  'Ghaur [deviant]': 155,
#  'Dr. Doom / Victor Von': 4084,
#  'Storm / Ororo Munroe S': 6220,
#  'Scarlet Witch / Wanda': 6216,
#  'Toad / Mortimer Toynbe': 537,
#  'Hulk / Dr. Robert Bruce Banner': 5984,
#  'Firestar / Angelica Jo': 2659,
#  'Wonder Man / Simon Wil': 5412,
#  'Drax / Arthur Douglas': 2307,
#  'Dugan, Timothy Aloyi': 825,
#  'Carter, Sharon': 152,
#  'Black Knight V / Dane': 4610,
#  'Sunfire / Shiro Yoshid': 953,
#  'Triton': 606,
#  'Ultron': 1099,
#  'Jones, Richard Milho': 1590,
#  'Iron Man / Tony Stark': 5983,
#  'Nelson, Franklin Fog': 425,
#  'Captain America': 7888,
#  'Jarvis, Edwin': 3437,
#  'Quasar Iii / Wendell V': 4047,
#  'Jameson, J. Jonah': 1628,
#  'Masters, Alicia Reis': 1333,
#  'Magneto / Magnus / Eric': 3138,
#  'Invisible Woman / Sue': 6242,
#  'Professor X / Charles': 6081,
#  'Iron Fist / Daniel Ran': 1049,
#  'Black Bolt / Blackanto': 849,
#  'Hawk': 5168,
#  'Sandman / William Bake': 1088,
#  'Falcon / Sam Wilson': 2034,
#  'Stingray / Dr. Walter': 575,
#  'Justice Ii / Vance Ast': 876,
#  'Hercules [greek God]': 5530,
#  'Usagent / Captain John': 2828,
#  'Captain Marvel Ii / Mo': 2628,
#  'Crystal [inhuman]': 3778,
#  'Tigra / Greer Nelson': 2055,
#  'Spider-woman Ii / Juli': 2654,
#  'Machine Man / X-51': 814,
#  'Mockingbird / Dr. Barb': 1399,
#  'Captain Marvel / Capta': 564,
#  'Wasp / Janet Van Dyne': 5937,
#  'Fury, Col. Nicholas': 2781,
#  'Thor / Dr. Donald Blak': 5939,
#  'Quicksilver / Pietro M': 5163,
#  'Captain Britain / Bria': 692,
#  'Shadowcat / Katherine': 2969,
#  'Black Widow / Natasha': 4685,
#  'Ant-man / Dr. Henry J.': 5128,
#  'Moon Knight / Marc Spe': 1736,
#  'Jocasta': 316,
#  'Moondragon / Heather D': 3402,
#  'Thing / Benjamin J. Gr': 6867,
#  'Beast / Henry &hank& P': 6660,
#  'Nova / Richard Rider': 3271,
#  'Wrecker Iii / Dirk Gar': 1027,
#  'Warlock Ii / Adam Warl': 2287,
#  'Piledriver Ii / Brian': 928,
#  'Thunderball / Dr. Elio': 1042,
#  'Dr. Octopus / Otto Oct': 998,
#  'Banner, Betty Ross T': 581,
#  'Avalanche / Dominic Pe': 571,
#  'Attuma': 243,
#  'Hela [asgardian]': 279,
#  'Doc Samson / Dr. Leona': 685,
#  'Guardian / James Macdo': 456,
#  'Northstar / Jean-paul': 2137,
#  'Dr. Druid / Anthony Lu': 2075,
#  'Watson-parker, Mary': 805,
#  'Mystique / Raven Darkh': 1067,
#  'Pyro / Allerdyce Johnn': 740,
#  'Destiny Ii / Irene Adl': 418,
#  'Mister Hyde / Calvin Z': 189,
#  'Ghost Rider Ii / Johnn': 279,
#  'Mole Man / Harvey Rupe': 544,
#  'Firelord / Pyreus Kril': 540,
#  'Leader / Sam Sterns': 136,
#  'Le Fey, Morgan': 141,
#  'Bulldozer / Henry Camp': 928,
#  'Forgotten One / Gilgam': 310,
#  'Balder [asgardian]': 358,
#  'Hogun [asgardian]': 539,
#  'Hellstorm / Daimon Hel': 341,
#  'Aurora / Jeanne-marie': 1466,
#  "O'brien, Michael": 437,
#  'Stankowicz, Fabian': 259,
#  'Screaming Mimi / Melis': 332,
#  'Moonstone Ii / Karla S': 556,
#  'Fixer Ii / Paul Norber': 399,
#  'Darkstar / Laynia Serg': 441,
#  'Vanguard / Nicolai Kry': 275,
#  'Gamora': 1577,
#  'Psylocke / Elisabeth B': 4245,
#  'Rogue  / ': 5545,
#  'Sasquatch / Walter Lan': 3138,
#  'Luna / Luna Maximoff [': 357,
#  'Whizzer Ii / Stanley S': 96,
#  'Dr. Spectrum / Joseph': 96,
#  'Kingpin / Wilson Fisk': 518,
#  'Clea': 171,
#  'Polaris / Lorna Dane': 3325,
#  'De La Fontaine, Cont': 174,
#  'Heimdall [asgardian]': 193,
#  'Red Skull / Johann Sch': 429,
#  'Thompson, Eugene Fla': 507,
#  'Wong': 412,
#  'Parker, May': 541,
#  'Green Goblin / Norman': 207,
#  'Night Thrasher / Duane': 252,
#  'Eternity / Adam Qadmon': 1623,
#  'Galactus / Galan': 3125,
#  'Triathlon / Delroy Gar': 334,
#  'Beetle / Abner Ronald': 659,
#  'Lilandra Neramani [s': 1290,
#  'Odin [asgardian]': 903,
#  'Hogan, Virginia Pepp': 113,
#  'Mad Dog / Colonel Buzz': 166,
#  'Kincaid, Dr. Jane Fo': 249,
#  'Wizard / Bentley Wittm': 309,
#  'Charcoal / Charlie Bur': 165,
#  'Blob / Fred J. Dukes': 1189,
#  'Cloak / Tyrone Johnson': 164,
#  'Thunderstrike / Eric K': 3331,
#  'Power Man / Erik Joste': 580,
#  'Human Torch Android / ': 468,
#  'Juggernaut / Cain Mark': 349,
#  'Absorbing Man / Carl C': 981,
#  'Volstagg': 466,
#  'Shaman / Michael Twoyo': 2187,
#  'Snowbird / Narya / Anne': 381,
#  'Dagger / Tandy Bowen': 273,
#  'Phoenix Iii / Rachel S': 892,
#  'Mandarin': 177,
#  'Fandral [asgardian]': 546,
#  'Ms. Marvel Ii / Sharon': 265,
#  'Pip / Prince Gofern': 1569,
#  'Enchantress / Amora / He': 1465,
#  'Jameson, Col. John': 328,
#  'Cooper, Dr. Valerie': 1411,
#  'Nova Ii / Frankie Raye': 1992,
#  'Darkhawk / Chris Powel': 1881,
#  'Nomad Iii / Jack Monro': 197,
#  'Robertson, Joe': 654,
#  'Gargoyle Ii / Isaac Ch': 549,
#  'Namorita / Nita Prenti': 2840,
#  'Iron Man Iv / James R.': 1520,
#  'Ross, Gen. Thaddeus': 384,
#  'Harkness, Agatha': 2391,
#  'Carter, Peggy': 387,
#  'Hyperion': 160,
#  'Living Lightning / Mig': 2888,
#  'Jones, Gabe': 304,
#  'Osborn, Liz Allan': 451,
#  'Leeds, Betty Brant': 508,
#  'Sif': 444,
#  'Dazzler Ii / Allison B': 970,
#  'Molecule Man / Owen Re': 731,
#  'Speedball / Robbie Bal': 2263,
#  'Lizard / Dr. Curtis Co': 778,
#  'Volcana / Marsha Rosen': 615,
#  'Lockheed': 796,
#  'Titania Ii / Mary Skee': 748,
#  'Boomer / Tabitha Smith': 1306,
#  'Summers, Nathan Chri': 1861,
#  'Summers, Madelyne Ma': 524,
#  'Mactaggert, Moira Ki': 1662,
#  'Cannonball Ii / Sam Gu': 2512,
#  'Tilby, Trish / Patrici': 423,
#  'Skids / Sally Blevins': 371,
#  'Wolfsbane / Rahne Sinc': 3135,
#  'Leech': 249,
#  'Mirage Ii / Danielle M': 907,
#  'Gambit / Remy Lebeau': 3766,
#  'Jubilee / Jubilation L': 1117,
#  'Strong Guy / Guido Car': 2793,
#  'Spiral': 328,
#  'Banshee / Sean Cassidy': 1321,
#  'Legion Ii / David Hall': 377,
#  'Havok / Alex Summers': 3894,
#  'Longshot': 450,
#  'Forge': 1666,
#  'Sabretooth / Victor Cr': 659,
#  'Maddicks, Arthur Art': 225,
#  'Warlock Iii': 1030,
#  'Rictor / Julio Esteban': 953,
#  'Sunspot / Roberto Daco': 1687,
#  'Firefist / Rusty Colli': 334,
#  'Bishop  / ': 1466,
#  'Daytripper / Amanda Se': 258,
#  'Wild Child / Kyle Gibn': 1274,
#  'Thunderbird Ii / James': 1105,
#  'Sauron / Dr. Karl Lyko': 267,
#  'Siryn / Theresa Rourke': 965,
#  'Shatterstar Ii / Gavee': 682,
#  'Marrow / Sarah': 424,
#  'Feral / Maria Callasan': 515,
#  'Callisto': 302,
#  'Mr. Sinister / Nathan': 395,
#  'Raza Longknife': 332,
#  'Spider-woman / Jessica': 371,
#  'Cypher / Doug Ramsey': 589,
#  "Deathbird [shi'ar]": 297,
#  'Hudson, Heather': 2525,
#  'Stryfe': 518,
#  'Iron Man Doppelgange': 1031,
#  'Puck / Eugene Milton J': 2347,
#  'Silhouette': 519,
#  'Cortez, Fabian': 189,
#  'Black King / Sebastian': 402,
#  'Magik / Illyana Rasput': 605,
#  'Zabu': 229,
#  'Domino Iii / Beatrice / ': 229,
#  'Caliban / ': 607,
#  'Apocalypse / En Sabah': 1043,
#  'Hunter, Stevie': 588,
#  'Corsair': 486,
#  "Ch'od": 377,
#  "Mam'selle Hepzibah": 378,
#  'Zero': 431,
#  'X-man / Nathan Grey': 403,
#  "Karma / Xi'an Coy Manh": 331,
#  'Mr. Fantastic Doppel': 1153,
#  'Beyonder': 482,
#  'Multiple Man / James A': 2008,
#  'Colossus Ii Doppelga': 325,
#  'Scanner Ii': 139,
#  'Ka-zar / Kevin Plunder': 418,
#  'White Queen / Emma Fro': 514,
#  'Magma / Amara Aquilla / ': 333,
#  'Thanos Doppelganger': 1688,
#  'Magus': 2249,
#  'Knight, Misty': 259,
#  'Wing, Colleen': 53,
#  'Puppet Master / Philli': 273,
#  'Maximus [inhuman]': 185,
#  'Punisher Ii / Frank Ca': 333,
#  'Zeus': 217,
#  'Box Iv / Madison Jeffr': 156,
#  'Thena': 159,
#  'Black Cat / Felicia Ha': 270,
#  'Gee / Alex Power': 123,
#  'Spider-man Clone / Ben': 111,
#  'Ulik': 128,
#  'Citizen V Ii / Helmut': 285,
#  'High Evolutionary / He': 439,
#  'Hobgoblin V / Jason Ph': 213,
#  'Ghost Rider Iii / Dan': 111,
#  'Cushing, Kate': 224,
#  'Katzenberg, Nick': 174,
#  'Vizier': 208,
#  'Tombstone / Lonnie Tho': 154,
#  'Mercado, Joy': 191,
#  'Hammerhead': 138,
#  'Arranger / ': 170,
#  'Osborn, Harry': 291,
#  'Cobra / Klaus Vorhees': 64,
#  'Leeds, Ned': 228,
#  'Watson, Anna': 249,
#  'Urich, Ben': 431,
#  'Robertson, Randy': 199,
#  'Page, Karen': 97,
#  'Grant, Gloria Glory': 295,
#  'Lubenski, Nate': 162,
#  'Ikaris / Ike Harris [e': 114,
#  'Rosenthal, Bernie': 133,
#  'Gladiator Ii': 214,
#  'Beta Ray Bill': 188,
#  'Bridge, George Washi': 92,
#  'Diamond Lil / Lillian': 81,
#  'Asp Ii / Cleo': 27,
#  'Black Mamba / Tanya Se': 27,
#  'Meggan': 187,
#  'Austin, Susan': 122,
#  'Diamondback Ii / Rache': 120,
#  'Makkari / Mike Khary / I': 195,
#  'Hodge, Cameron': 301,
#  'Skin / Angelo Espinosa': 72,
#  'Husk / Paige Guthrie': 93,
#  'Deadpool / Jack / Wade W': 61}

# %%
# Get clustering coefficients
# These can be added to a node dataframe as in the previous chapter
nx.clustering(M)
# Out:
# {"Black Panther / T'chal": 0.5617821782178218,
#  'Loki [asgardian]': 0.5579058699101005,
#  'Mantis / ? Brandt': 0.9233333333333333,
#  'Iceman / Robert Bobby': 0.40794417606011807,
#  'Marvel Girl / Jean Grey': 0.42312526183493926,
#  'Cyclops / Scott Summer': 0.3353361649228219,
#  'Klaw / Ulysses Klaw': 0.7071977638015374,
#  'Human Torch / Johnny S': 0.3390544041450777,
#  'Richards, Franklin B': 0.5838509316770186,
#  'Wolverine / Logan': 0.2975508509755085,
#  'Firebird / Bonita Juar': 0.914651493598862,
#  'Mr. Fantastic / Reed R': 0.3174383428190535,
#  'Medusa / Medusalith Am': 0.8318367346938775,
#  'Dr. Strange / Stephen': 0.4581560283687943,
#  'Jack Of Hearts / Jack': 0.7773279352226721,
#  'Mephisto': 0.5948051948051948,
#  'Thanos': 0.7782217782217782,
#  'Swordsman / Jacques Du': 0.9047619047619048,
#  'Collector / Taneleer T': 0.903448275862069,
#  'Lockjaw [inhuman]': 0.8737373737373737,
#  'Sub-mariner / Namor Ma': 0.41337535703732886,
#  'Pharaoh Rama-tut': 0.7176470588235294,
#  'Ant-man Ii / Scott Har': 0.7192156862745098,
#  'Lyja Lazerfist [skru': 0.8044354838709677,
#  'Gorgon [inhuman]': 0.8847780126849895,
#  'Nighthawk Ii / Kyle Ri': 0.8508064516129032,
#  'Cage, Luke / Carl Luca': 0.6345848757271285,
#  'Colossus Ii / Peter Ra': 0.3509500512003641,
#  'Hellcat / Patsy Walker': 0.6758328926493918,
#  'Karnak [inhuman]': 0.8818181818181818,
#  'Death': 0.8372093023255814,
#  'Redwing': 0.7133333333333334,
#  'Daredevil / Matt Murdo': 0.4095785440613027,
#  'Norriss, Sister Barb': 0.6797814207650273,
#  'Rage / Elvin Daryl Hal': 0.8094357076780758,
#  'Starfox / Eros': 0.6415525114155252,
#  'Demolition Man / Denni': 0.8022988505747126,
#  'Sersi / Sylvia': 0.5739235170129479,
#  'Spider-man / Peter Parker': 0.276201750306515,
#  'Vision': 0.29550890247143236,
#  'Uatu': 0.6997892201144233,
#  'Binary / Carol Danvers': 0.5499316005471956,
#  'Gyrich, Henry Peter': 0.6632996632996633,
#  'Nightcrawler / Kurt Wa': 0.39606432923783835,
#  'Angel / Warren Kenneth': 0.39180050718512255,
#  'Silver Surfer / Norrin': 0.5265631676399374,
#  'She-hulk / Jennifer Wa': 0.37250047609979053,
#  'Ghaur [deviant]': 0.8157894736842105,
#  'Dr. Doom / Victor Von': 0.5186031746031746,
#  'Storm / Ororo Munroe S': 0.3464216095795043,
#  'Scarlet Witch / Wanda': 0.33203354521660167,
#  'Toad / Mortimer Toynbe': 0.7638691322901849,
#  'Hulk / Dr. Robert Bruce Banner': 0.3633052030842086,
#  'Firestar / Angelica Jo': 0.6493284493284494,
#  'Wonder Man / Simon Wil': 0.4201863354037267,
#  'Drax / Arthur Douglas': 0.8313513513513513,
#  'Dugan, Timothy Aloyi': 0.7313829787234043,
#  'Carter, Sharon': 0.8,
#  'Black Knight V / Dane': 0.46707193515704154,
#  'Sunfire / Shiro Yoshid': 0.7474509803921568,
#  'Triton': 0.8620199146514936,
#  'Ultron': 0.8288084464555053,
#  'Jones, Richard Milho': 0.7191316146540027,
#  'Iron Man / Tony Stark': 0.2918109544944642,
#  'Nelson, Franklin Fog': 0.5448717948717948,
#  'Captain America': 0.23792718607667482,
#  'Jarvis, Edwin': 0.4098986285032797,
#  'Quasar Iii / Wendell V': 0.5221935483870968,
#  'Jameson, J. Jonah': 0.4670109007458405,
#  'Masters, Alicia Reis': 0.8064125831820932,
#  'Magneto / Magnus / Eric': 0.446944879646774,
#  'Invisible Woman / Sue': 0.33000264340470525,
#  'Professor X / Charles': 0.3572855464159812,
#  'Iron Fist / Daniel Ran': 0.6811688311688312,
#  'Black Bolt / Blackanto': 0.8974630021141649,
#  'Hawk': 0.35976331360946745,
#  'Sandman / William Bake': 0.7064935064935065,
#  'Falcon / Sam Wilson': 0.5834767641996558,
#  'Stingray / Dr. Walter': 0.817923186344239,
#  'Justice Ii / Vance Ast': 0.7448979591836735,
#  'Hercules [greek God]': 0.3804609563123495,
#  'Usagent / Captain John': 0.6610565684899485,
#  'Captain Marvel Ii / Mo': 0.5529139490847885,
#  'Crystal [inhuman]': 0.5865548827821767,
#  'Tigra / Greer Nelson': 0.6843156843156843,
#  'Spider-woman Ii / Juli': 0.6626716604244695,
#  'Machine Man / X-51': 0.9014396456256921,
#  'Mockingbird / Dr. Barb': 0.7398202009518773,
#  'Captain Marvel / Capta': 0.8468468468468469,
#  'Wasp / Janet Van Dyne': 0.33775173512344975,
#  'Fury, Col. Nicholas': 0.4903897019925939,
#  'Thor / Dr. Donald Blak': 0.284026781444285,
#  'Quicksilver / Pietro M': 0.4110341533317411,
#  'Captain Britain / Bria': 0.7315010570824524,
#  'Shadowcat / Katherine': 0.46918457648546147,
#  'Black Widow / Natasha': 0.43658559314136614,
#  'Ant-man / Dr. Henry J.': 0.38839657653563586,
#  'Moon Knight / Marc Spe': 0.7399829497016198,
#  'Jocasta': 0.9002849002849003,
#  'Moondragon / Heather D': 0.6476299257567104,
#  'Thing / Benjamin J. Gr': 0.3013031459786758,
#  'Beast / Henry &hank& P': 0.31850789096126253,
#  'Nova / Richard Rider': 0.6226917951646678,
#  'Wrecker Iii / Dirk Gar': 0.7176799440950384,
#  'Warlock Ii / Adam Warl': 0.8241441441441442,
#  'Piledriver Ii / Brian': 0.7891156462585034,
#  'Thunderball / Dr. Elio': 0.7016835016835017,
#  'Dr. Octopus / Otto Oct': 0.62531328320802,
#  'Banner, Betty Ross T': 0.8723723723723724,
#  'Avalanche / Dominic Pe': 0.7705802968960864,
#  'Attuma': 0.8804347826086957,
#  'Hela [asgardian]': 0.5284090909090909,
#  'Doc Samson / Dr. Leona': 0.8782051282051282,
#  'Guardian / James Macdo': 0.8636363636363636,
#  'Northstar / Jean-paul': 0.7911884487226953,
#  'Dr. Druid / Anthony Lu': 0.8350100603621731,
#  'Watson-parker, Mary': 0.4869933454325469,
#  'Mystique / Raven Darkh': 0.6454930429522081,
#  'Pyro / Allerdyce Johnn': 0.714975845410628,
#  'Destiny Ii / Irene Adl': 0.7916666666666666,
#  'Mister Hyde / Calvin Z': 0.6847826086956522,
#  'Ghost Rider Ii / Johnn': 0.7948717948717948,
#  'Mole Man / Harvey Rupe': 0.9142857142857143,
#  'Firelord / Pyreus Kril': 0.8571428571428571,
#  'Leader / Sam Sterns': 1.0,
#  'Le Fey, Morgan': 0.9215686274509803,
#  'Bulldozer / Henry Camp': 0.7891156462585034,
#  'Forgotten One / Gilgam': 0.8201058201058201,
#  'Balder [asgardian]': 0.678030303030303,
#  'Hogun [asgardian]': 0.5697674418604651,
#  'Hellstorm / Daimon Hel': 0.9021164021164021,
#  'Aurora / Jeanne-marie': 0.8282485875706215,
#  "O'brien, Michael": 0.7789661319073083,
#  'Stankowicz, Fabian': 0.8633333333333333,
#  'Screaming Mimi / Melis': 0.7632183908045977,
#  'Moonstone Ii / Karla S': 0.7128205128205128,
#  'Fixer Ii / Paul Norber': 0.7112299465240641,
#  'Darkstar / Laynia Serg': 0.8891129032258065,
#  'Vanguard / Nicolai Kry': 0.9166666666666666,
#  'Gamora': 0.9216832261835184,
#  'Psylocke / Elisabeth B': 0.4909784871616933,
#  'Rogue  / ': 0.3906029867568329,
#  'Sasquatch / Walter Lan': 0.7179135209334249,
#  'Luna / Luna Maximoff [': 0.8793103448275862,
#  'Whizzer Ii / Stanley S': 0.9142857142857143,
#  'Dr. Spectrum / Joseph': 0.9142857142857143,
#  'Kingpin / Wilson Fisk': 0.4592198581560284,
#  'Clea': 0.9,
#  'Polaris / Lorna Dane': 0.5446355446355446,
#  'De La Fontaine, Cont': 0.7532467532467533,
#  'Heimdall [asgardian]': 0.8354978354978355,
#  'Red Skull / Johann Sch': 0.6102418207681366,
#  'Thompson, Eugene Fla': 0.5888501742160279,
#  'Wong': 0.886021505376344,
#  'Parker, May': 0.5991140642303433,
#  'Green Goblin / Norman': 0.8181818181818182,
#  'Night Thrasher / Duane': 0.7753846153846153,
#  'Eternity / Adam Qadmon': 0.8868852459016393,
#  'Galactus / Galan': 0.6574794866400169,
#  'Triathlon / Delroy Gar': 0.8835978835978836,
#  'Beetle / Abner Ronald': 0.6656565656565656,
#  'Lilandra Neramani [s': 0.6398809523809523,
#  'Odin [asgardian]': 0.5863636363636363,
#  'Hogan, Virginia Pepp': 0.9416666666666667,
#  'Mad Dog / Colonel Buzz': 0.7904761904761904,
#  'Kincaid, Dr. Jane Fo': 0.6587301587301587,
#  'Wizard / Bentley Wittm': 0.7610837438423645,
#  'Charcoal / Charlie Bur': 0.7857142857142857,
#  'Blob / Fred J. Dukes': 0.6287678476996298,
#  'Cloak / Tyrone Johnson': 0.5942028985507246,
#  'Thunderstrike / Eric K': 0.6219193427931292,
#  'Power Man / Erik Joste': 0.6736353077816493,
#  'Human Torch Android / ': 0.7428571428571429,
#  'Juggernaut / Cain Mark': 0.8022988505747126,
#  'Absorbing Man / Carl C': 0.7398190045248869,
#  'Volstagg': 0.5682926829268292,
#  'Shaman / Michael Twoyo': 0.7881081081081082,
#  'Snowbird / Narya / Anne': 0.8758620689655172,
#  'Dagger / Tandy Bowen': 0.6724137931034483,
#  'Phoenix Iii / Rachel S': 0.623340321453529,
#  'Mandarin': 0.7662337662337663,
#  'Fandral [asgardian]': 0.5515151515151515,
#  'Ms. Marvel Ii / Sharon': 0.8153846153846154,
#  'Pip / Prince Gofern': 0.8864406779661017,
#  'Enchantress / Amora / He': 0.624467178175618,
#  'Jameson, Col. John': 0.5206349206349207,
#  'Cooper, Dr. Valerie': 0.5842650103519669,
#  'Nova Ii / Frankie Raye': 0.874451273046532,
#  'Darkhawk / Chris Powel': 0.7788819875776397,
#  'Nomad Iii / Jack Monro': 0.6061538461538462,
#  'Robertson, Joe': 0.5561224489795918,
#  'Gargoyle Ii / Isaac Ch': 0.8243243243243243,
#  'Namorita / Nita Prenti': 0.6638616175783076,
#  'Iron Man Iv / James R.': 0.7307692307692307,
#  'Ross, Gen. Thaddeus': 0.9458128078817734,
#  'Harkness, Agatha': 0.8171565276828435,
#  'Carter, Peggy': 0.6504201680672269,
#  'Hyperion': 0.8421052631578947,
#  'Living Lightning / Mig': 0.7901504787961696,
#  'Jones, Gabe': 0.8042328042328042,
#  'Osborn, Liz Allan': 0.6415362731152204,
#  'Leeds, Betty Brant': 0.6195121951219512,
#  'Sif': 0.631578947368421,
#  'Dazzler Ii / Allison B': 0.7315233785822021,
#  'Molecule Man / Owen Re': 0.9371794871794872,
#  'Speedball / Robbie Bal': 0.7734107997265892,
#  'Lizard / Dr. Curtis Co': 0.6897163120567376,
#  'Volcana / Marsha Rosen': 0.9761904761904762,
#  'Lockheed': 0.649795918367347,
#  'Titania Ii / Mary Skee': 0.8283499446290143,
#  'Boomer / Tabitha Smith': 0.6088578088578088,
#  'Summers, Nathan Chri': 0.5468704084631207,
#  'Summers, Madelyne Ma': 0.7867867867867868,
#  'Mactaggert, Moira Ki': 0.5534465534465535,
#  'Cannonball Ii / Sam Gu': 0.4190158465387823,
#  'Tilby, Trish / Patrici': 0.8011363636363636,
#  'Skids / Sally Blevins': 0.7479838709677419,
#  'Wolfsbane / Rahne Sinc': 0.4700149925037481,
#  'Leech': 0.6587301587301587,
#  'Mirage Ii / Danielle M': 0.5486993345432547,
#  'Gambit / Remy Lebeau': 0.518732782369146,
#  'Jubilee / Jubilation L': 0.6528345996493279,
#  'Strong Guy / Guido Car': 0.652875175315568,
#  'Spiral': 0.8078817733990148,
#  'Banshee / Sean Cassidy': 0.5630861040068201,
#  'Legion Ii / David Hall': 0.9285714285714286,
#  'Havok / Alex Summers': 0.5106215578284815,
#  'Longshot': 0.8522727272727273,
#  'Forge': 0.6339421613394216,
#  'Sabretooth / Victor Cr': 0.8448717948717949,
#  'Maddicks, Arthur Art': 0.6923076923076923,
#  'Warlock Iii': 0.6019871420222093,
#  'Rictor / Julio Esteban': 0.6915820029027576,
#  'Sunspot / Roberto Daco': 0.5079795242396868,
#  'Firefist / Rusty Colli': 0.6733870967741935,
#  'Bishop  / ': 0.6435469710272168,
#  'Daytripper / Amanda Se': 0.86,
#  'Wild Child / Kyle Gibn': 0.8272727272727273,
#  'Thunderbird Ii / James': 0.6458211572180012,
#  'Sauron / Dr. Karl Lyko': 0.89,
#  'Siryn / Theresa Rourke': 0.7002902757619739,
#  'Shatterstar Ii / Gavee': 0.7921022067363531,
#  'Marrow / Sarah': 0.803030303030303,
#  'Feral / Maria Callasan': 0.8174603174603174,
#  'Callisto': 0.8603988603988604,
#  'Mr. Sinister / Nathan': 0.9080459770114943,
#  'Raza Longknife': 0.8783068783068783,
#  'Spider-woman / Jessica': 0.8528735632183908,
#  'Cypher / Doug Ramsey': 0.7182926829268292,
#  "Deathbird [shi'ar]": 0.7857142857142857,
#  'Hudson, Heather': 0.7603131586871424,
#  'Stryfe': 0.9233511586452763,
#  'Iron Man Doppelgange': 0.996135265700483,
#  'Puck / Eugene Milton J': 0.7617656604998377,
#  'Silhouette': 0.8722689075630252,
#  'Cortez, Fabian': 0.9,
#  'Black King / Sebastian': 0.864516129032258,
#  'Magik / Illyana Rasput': 0.7378048780487805,
#  'Zabu': 0.7633333333333333,
#  'Domino Iii / Beatrice / ': 0.8297101449275363,
#  'Caliban / ': 0.7402439024390244,
#  'Apocalypse / En Sabah': 0.6772727272727272,
#  'Hunter, Stevie': 0.8364153627311522,
#  'Corsair': 0.8168067226890756,
#  "Ch'od": 0.8666666666666667,
#  "Mam'selle Hepzibah": 0.8689655172413793,
#  'Zero': 0.9268817204301075,
#  'X-man / Nathan Grey': 0.8666666666666667,
#  "Karma / Xi'an Coy Manh": 0.8152709359605911,
#  'Mr. Fantastic Doppel': 0.9804421768707483,
#  'Beyonder': 0.765079365079365,
#  'Multiple Man / James A': 0.7045614035087719,
#  'Colossus Ii Doppelga': 1.0,
#  'Scanner Ii': 0.8128654970760234,
#  'Ka-zar / Kevin Plunder': 0.7916666666666666,
#  'White Queen / Emma Fro': 0.658974358974359,
#  'Magma / Amara Aquilla / ': 0.8809523809523809,
#  'Thanos Doppelganger': 0.9224043715846995,
#  'Magus': 0.8798904538341158,
#  'Knight, Misty': 0.7378917378917379,
#  'Wing, Colleen': 0.803030303030303,
#  'Puppet Master / Philli': 0.91,
#  'Maximus [inhuman]': 0.9736842105263158,
#  'Punisher Ii / Frank Ca': 0.47368421052631576,
#  'Zeus': 0.7862318840579711,
#  'Box Iv / Madison Jeffr': 0.8210526315789474,
#  'Thena': 0.6883116883116883,
#  'Black Cat / Felicia Ha': 0.6650246305418719,
#  'Gee / Alex Power': 0.5324675324675324,
#  'Spider-man Clone / Ben': 0.6491228070175439,
#  'Ulik': 0.7485380116959064,
#  'Citizen V Ii / Helmut': 0.6129032258064516,
#  'High Evolutionary / He': 0.5353658536585366,
#  'Hobgoblin V / Jason Ph': 0.6553846153846153,
#  'Ghost Rider Iii / Dan': 0.6491228070175439,
#  'Cushing, Kate': 0.8853754940711462,
#  'Katzenberg, Nick': 0.9157894736842105,
#  'Vizier': 0.8221343873517787,
#  'Tombstone / Lonnie Tho': 0.7333333333333333,
#  'Mercado, Joy': 0.9095238095238095,
#  'Hammerhead': 0.8070175438596491,
#  'Arranger / ': 0.8947368421052632,
#  'Osborn, Harry': 0.7698412698412699,
#  'Cobra / Klaus Vorhees': 0.5333333333333333,
#  'Leeds, Ned': 0.8260869565217391,
#  'Watson, Anna': 0.7661538461538462,
#  'Urich, Ben': 0.6471471471471472,
#  'Robertson, Randy': 0.8614718614718615,
#  'Page, Karen': 0.8083333333333333,
#  'Grant, Gloria Glory': 0.7804232804232805,
#  'Lubenski, Nate': 0.9473684210526315,
#  'Ikaris / Ike Harris [e': 0.8382352941176471,
#  'Rosenthal, Bernie': 0.6333333333333333,
#  'Gladiator Ii': 0.8458498023715415,
#  'Beta Ray Bill': 0.6811594202898551,
#  'Bridge, George Washi': 0.39826839826839827,
#  'Diamond Lil / Lillian': 0.8901098901098901,
#  'Asp Ii / Cleo': 0.9642857142857143,
#  'Black Mamba / Tanya Se': 0.9642857142857143,
#  'Meggan': 0.8904761904761904,
#  'Austin, Susan': 0.8970588235294118,
#  'Diamondback Ii / Rache': 0.631578947368421,
#  'Makkari / Mike Khary / I': 0.6,
#  'Hodge, Cameron': 0.8575498575498576,
#  'Skin / Angelo Espinosa': 0.7912087912087912,
#  'Husk / Paige Guthrie': 0.775,
#  'Deadpool / Jack / Wade W': 0.782051282051282}

# %%
# Find the average clustering coefficient
nx.average_clustering(M)
# Out:
# 0.7047201786696375

# %% [markdown]
# ## Bridges

# %%
# List a network's bridges
list(nx.bridges(M))
# Out:
# []

# %%
# Test if a network has any bridges
nx.has_bridges(M)
# Out:
# False

# %%
# List a network's local bridges
list(nx.local_bridges(M))
# Out:
# [('Death', 'Deadpool / Jack / Wade W', 3)]

# %% [markdown]
# ## Neighbors

# %%
# Find a node's neighbors
list(nx.neighbors(M, 'Death'))
# Out:
# ["Black Panther / T'chal",
#  'Iron Man / Tony Stark',
#  'Sub-mariner / Namor Ma',
#  'Nova / Richard Rider',
#  'Hulk / Dr. Robert Bruce Banner',
#  'Spider-man / Peter Parker',
#  'Wasp / Janet Van Dyne',
#  'Galactus / Galan',
#  'Silver Surfer / Norrin',
#  'Hawk',
#  'Scarlet Witch / Wanda',
#  'Uatu',
#  'Captain America',
#  'Thunderstrike / Eric K',
#  'Wonder Man / Simon Wil',
#  'Wolverine / Logan',
#  'She-hulk / Jennifer Wa',
#  'Vision',
#  'Storm / Ororo Munroe S',
#  'Eternity / Adam Qadmon',
#  'Quasar Iii / Wendell V',
#  'Black Widow / Natasha',
#  'Firelord / Pyreus Kril',
#  'Thor / Dr. Donald Blak',
#  'Richards, Franklin B',
#  'Deadpool / Jack / Wade W',
#  'Mephisto',
#  'Dr. Doom / Victor Von',
#  'Thing / Benjamin J. Gr',
#  'Gamora',
#  'Drax / Arthur Douglas',
#  'Nova Ii / Frankie Raye',
#  'Ant-man / Dr. Henry J.',
#  'Moondragon / Heather D',
#  'Pip / Prince Gofern',
#  'Thanos',
#  'Collector / Taneleer T',
#  'Captain Marvel / Capta',
#  'Warlock Ii / Adam Warl',
#  'Dr. Strange / Stephen',
#  'Starfox / Eros',
#  'Invisible Woman / Sue',
#  'Cyclops / Scott Summer']

# %%
# Find common neighbors of a node pair
list(nx.common_neighbors(M, 'Death', 'Thanos'))
# Out:
# ["Black Panther / T'chal",
#  'Iron Man / Tony Stark',
#  'Sub-mariner / Namor Ma',
#  'Nova / Richard Rider',
#  'Hulk / Dr. Robert Bruce Banner',
#  'Spider-man / Peter Parker',
#  'Galactus / Galan',
#  'Silver Surfer / Norrin',
#  'Hawk',
#  'Scarlet Witch / Wanda',
#  'Uatu',
#  'Captain America',
#  'Thunderstrike / Eric K',
#  'Wonder Man / Simon Wil',
#  'Wolverine / Logan',
#  'She-hulk / Jennifer Wa',
#  'Vision',
#  'Storm / Ororo Munroe S',
#  'Eternity / Adam Qadmon',
#  'Quasar Iii / Wendell V',
#  'Black Widow / Natasha',
#  'Firelord / Pyreus Kril',
#  'Thor / Dr. Donald Blak',
#  'Mephisto',
#  'Dr. Doom / Victor Von',
#  'Thing / Benjamin J. Gr',
#  'Gamora',
#  'Drax / Arthur Douglas',
#  'Nova Ii / Frankie Raye',
#  'Ant-man / Dr. Henry J.',
#  'Moondragon / Heather D',
#  'Pip / Prince Gofern',
#  'Captain Marvel / Capta',
#  'Warlock Ii / Adam Warl',
#  'Dr. Strange / Stephen',
#  'Starfox / Eros',
#  'Invisible Woman / Sue',
#  'Cyclops / Scott Summer']

# %% [markdown]
# ## Cycles/Loops

# %%
# Get a list of the basis of all cycle in the graph
# All larger cycles are based on these cycles, many of which are triangles
nx.cycle_basis(M)
# Out:
# [['Spider-man / Peter Parker', 'Mercado, Joy', 'Arranger / '],
#  ['Parker, May', 'Mercado, Joy', 'Arranger / '],
#  ['Robertson, Joe', 'Mercado, Joy', 'Arranger / '],
#  ['Leeds, Betty Brant', 'Mercado, Joy', 'Arranger / '],
#  ['Kingpin / Wilson Fisk', 'Mercado, Joy', 'Arranger / '],
#  ['Watson-parker, Mary', 'Mercado, Joy', 'Arranger / '],
#  ['Jameson, J. Jonah', 'Mercado, Joy', 'Arranger / '],
#  ['Urich, Ben', 'Mercado, Joy', 'Arranger / '],
#  ['Thompson, Eugene Fla', 'Mercado, Joy', 'Arranger / '],
#  ['Grant, Gloria Glory', 'Mercado, Joy', 'Arranger / '],
#  ['Tombstone / Lonnie Tho', 'Mercado, Joy', 'Arranger / '],
#  ['Hobgoblin V / Jason Ph', 'Mercado, Joy', 'Arranger / '],
#  ['Cushing, Kate', 'Mercado, Joy', 'Arranger / '],
#  ['Robertson, Randy', 'Mercado, Joy', 'Arranger / '],
#  ['Katzenberg, Nick', 'Mercado, Joy', 'Arranger / '],
#  ['Spider-man / Peter Parker', 'Lubenski, Nate', 'Mercado, Joy'],
#  ['Parker, May', 'Lubenski, Nate', 'Mercado, Joy'],
#  ['Robertson, Joe', 'Lubenski, Nate', 'Mercado, Joy'],
#  ['Leeds, Betty Brant', 'Lubenski, Nate', 'Mercado, Joy'],
#  ['Kingpin / Wilson Fisk', 'Lubenski, Nate', 'Mercado, Joy'],
#  ['Watson-parker, Mary', 'Lubenski, Nate', 'Mercado, Joy'],
#  ['Watson, Anna', 'Lubenski, Nate', 'Mercado, Joy'],
#  ['Jameson, J. Jonah', 'Lubenski, Nate', 'Mercado, Joy'],
#  ['Urich, Ben', 'Lubenski, Nate', 'Mercado, Joy'],
#  ['Thompson, Eugene Fla', 'Lubenski, Nate', 'Mercado, Joy'],
#  ['Grant, Gloria Glory', 'Lubenski, Nate', 'Mercado, Joy'],
#  ['Black Cat / Felicia Ha', 'Lubenski, Nate', 'Mercado, Joy'],
#  ['Osborn, Harry', 'Lubenski, Nate', 'Mercado, Joy'],
#  ['Osborn, Liz Allan', 'Lubenski, Nate', 'Mercado, Joy'],
#  ['Katzenberg, Nick', 'Lubenski, Nate', 'Mercado, Joy'],
#  ['Cushing, Kate', 'Lubenski, Nate', 'Mercado, Joy'],
#  ['Leeds, Ned', 'Lubenski, Nate', 'Mercado, Joy', 'Arranger / '],
#  ['Spider-man / Peter Parker', 'Dr. Octopus / Otto Oct', 'Lubenski, Nate'],
#  ['Parker, May', 'Dr. Octopus / Otto Oct', 'Lubenski, Nate'],
#  ['Robertson, Joe', 'Dr. Octopus / Otto Oct', 'Lubenski, Nate'],
#  ['Leeds, Betty Brant', 'Dr. Octopus / Otto Oct', 'Lubenski, Nate'],
#  ['Kingpin / Wilson Fisk', 'Dr. Octopus / Otto Oct', 'Lubenski, Nate'],
#  ['Watson-parker, Mary', 'Dr. Octopus / Otto Oct', 'Lubenski, Nate'],
#  ['Watson, Anna', 'Dr. Octopus / Otto Oct', 'Lubenski, Nate'],
#  ['Jameson, J. Jonah', 'Dr. Octopus / Otto Oct', 'Lubenski, Nate'],
#  ['Urich, Ben', 'Dr. Octopus / Otto Oct', 'Lubenski, Nate'],
#  ['Thompson, Eugene Fla', 'Dr. Octopus / Otto Oct', 'Lubenski, Nate'],
#  ['Grant, Gloria Glory', 'Dr. Octopus / Otto Oct', 'Lubenski, Nate'],
#  ['Osborn, Liz Allan', 'Dr. Octopus / Otto Oct', 'Lubenski, Nate'],
#  ['Hobgoblin V / Jason Ph',
#   'Dr. Octopus / Otto Oct',
#   'Lubenski, Nate',
#   'Mercado, Joy'],
#  ['Osborn, Harry', 'Dr. Octopus / Otto Oct', 'Lubenski, Nate'],
#  ['Leeds, Ned', 'Dr. Octopus / Otto Oct', 'Lubenski, Nate'],
#  ['Black Cat / Felicia Ha', 'Dr. Octopus / Otto Oct', 'Lubenski, Nate'],
#  ['Hammerhead',
#   'Dr. Octopus / Otto Oct',
#   'Lubenski, Nate',
#   'Mercado, Joy',
#   'Arranger / '],
#  ['Daredevil / Matt Murdo',
#   'Dr. Octopus / Otto Oct',
#   'Lubenski, Nate',
#   'Mercado, Joy',
#   'Arranger / '],
#  ['Iron Man / Tony Stark', 'Colossus Ii / Peter Ra', 'Dr. Octopus / Otto Oct'],
#  ['Iron Man Iv / James R.',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Rogue  / ', 'Colossus Ii / Peter Ra', 'Dr. Octopus / Otto Oct'],
#  ['Thunderball / Dr. Elio',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Spider-man / Peter Parker',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Wasp / Janet Van Dyne', 'Colossus Ii / Peter Ra', 'Dr. Octopus / Otto Oct'],
#  ['Galactus / Galan', 'Colossus Ii / Peter Ra', 'Dr. Octopus / Otto Oct'],
#  ['Hawk', 'Colossus Ii / Peter Ra', 'Dr. Octopus / Otto Oct'],
#  ['Captain America', 'Colossus Ii / Peter Ra', 'Dr. Octopus / Otto Oct'],
#  ['Wolverine / Logan', 'Colossus Ii / Peter Ra', 'Dr. Octopus / Otto Oct'],
#  ['She-hulk / Jennifer Wa',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Storm / Ororo Munroe S',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Mr. Fantastic / Reed R',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Thing / Benjamin J. Gr',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Invisible Woman / Sue', 'Colossus Ii / Peter Ra', 'Dr. Octopus / Otto Oct'],
#  ['Cyclops / Scott Summer',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Enchantress / Amora / He',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Thor / Dr. Donald Blak',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Spider-woman Ii / Juli',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Professor X / Charles', 'Colossus Ii / Peter Ra', 'Dr. Octopus / Otto Oct'],
#  ['Ultron', 'Colossus Ii / Peter Ra', 'Dr. Octopus / Otto Oct'],
#  ['Human Torch / Johnny S',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Magneto / Magnus / Eric',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Wrecker Iii / Dirk Gar',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Titania Ii / Mary Skee',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Volcana / Marsha Rosen',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Molecule Man / Owen Re',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Absorbing Man / Carl C',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Pharaoh Rama-tut', 'Colossus Ii / Peter Ra', 'Dr. Octopus / Otto Oct'],
#  ['Daredevil / Matt Murdo',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Dr. Doom / Victor Von', 'Colossus Ii / Peter Ra', 'Dr. Octopus / Otto Oct'],
#  ['Nightcrawler / Kurt Wa',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Lizard / Dr. Curtis Co',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Bulldozer / Henry Camp',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Klaw / Ulysses Klaw', 'Colossus Ii / Peter Ra', 'Dr. Octopus / Otto Oct'],
#  ['Piledriver Ii / Brian', 'Colossus Ii / Peter Ra', 'Dr. Octopus / Otto Oct'],
#  ['Captain Marvel Ii / Mo',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Iron Man / Tony Stark', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Rogue  / ', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Nova / Richard Rider', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Namorita / Nita Prenti', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Spider-man / Peter Parker',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Galactus / Galan', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Silver Surfer / Norrin', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Scarlet Witch / Wanda', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Uatu', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Captain America', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Thunderstrike / Eric K', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Wonder Man / Simon Wil', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Wolverine / Logan', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['She-hulk / Jennifer Wa', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Vision', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Psylocke / Elisabeth B', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Marvel Girl / Jean Grey', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Storm / Ororo Munroe S', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Eternity / Adam Qadmon', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Angel / Warren Kenneth', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Thing / Benjamin J. Gr', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Invisible Woman / Sue', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Beast / Henry &hank& P', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Cyclops / Scott Summer', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Dr. Strange / Stephen', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Warlock Ii / Adam Warl', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Professor X / Charles', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Iceman / Robert Bobby', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Moondragon / Heather D', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Human Torch / Johnny S', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Havok / Alex Summers', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Polaris / Lorna Dane', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Ant-man / Dr. Henry J.', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Hercules [greek God]', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Black Widow / Natasha', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Drax / Arthur Douglas', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Dr. Druid / Anthony Lu', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Quasar Iii / Wendell V', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Nova Ii / Frankie Raye', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Black Knight V / Dane', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Gamora', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Gambit / Remy Lebeau', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Pharaoh Rama-tut', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Magus', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Thanos Doppelganger', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Harkness, Agatha', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Sasquatch / Walter Lan', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Hudson, Heather', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Strong Guy / Guido Car', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Thanos', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Dr. Doom / Victor Von', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Living Lightning / Mig', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Starfox / Eros', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Shaman / Michael Twoyo', 'Pip / Prince Gofern', 'Colossus Ii / Peter Ra'],
#  ['Iron Man / Tony Stark', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Sub-mariner / Namor Ma',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Spider-man / Peter Parker',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Wasp / Janet Van Dyne',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Galactus / Galan', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Silver Surfer / Norrin', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Hawk',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Captain America', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Thunderstrike / Eric K', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Wolverine / Logan', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['She-hulk / Jennifer Wa', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Vision', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Mr. Fantastic / Reed R',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Death', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Invisible Woman / Sue', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Cyclops / Scott Summer', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Thor / Dr. Donald Blak',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Dr. Strange / Stephen', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Warlock Ii / Adam Warl', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Jarvis, Edwin',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Ant-man / Dr. Henry J.', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Hercules [greek God]', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Drax / Arthur Douglas', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Dr. Doom / Victor Von', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Black Knight V / Dane', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Starfox / Eros', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Nova Ii / Frankie Raye', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Thanos', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Captain Marvel Ii / Mo',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Mephisto', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Quasar Iii / Wendell V', 'Firelord / Pyreus Kril', 'Pip / Prince Gofern'],
#  ['Iron Man / Tony Stark', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Galactus / Galan', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Silver Surfer / Norrin', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Scarlet Witch / Wanda',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Captain America', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Thunderstrike / Eric K', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Vision', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Enchantress / Amora / He',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Thor / Dr. Donald Blak', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Dr. Strange / Stephen', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Jarvis, Edwin', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Hercules [greek God]', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Odin [asgardian]', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Mephisto', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Starfox / Eros', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Black Knight V / Dane', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Captain Marvel Ii / Mo', 'Sif', 'Firelord / Pyreus Kril'],
#  ['High Evolutionary / He',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Wrecker Iii / Dirk Gar',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Balder [asgardian]', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Absorbing Man / Carl C',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Captain America', 'Austin, Susan', 'Sif'],
#  ['Thunderstrike / Eric K', 'Austin, Susan', 'Sif'],
#  ['Enchantress / Amora / He', 'Austin, Susan', 'Sif'],
#  ['Loki [asgardian]', 'Austin, Susan', 'Sif'],
#  ['Thor / Dr. Donald Blak', 'Austin, Susan', 'Sif'],
#  ['Dr. Strange / Stephen', 'Austin, Susan', 'Sif'],
#  ['Hercules [greek God]', 'Austin, Susan', 'Sif'],
#  ['Volstagg', 'Austin, Susan', 'Sif'],
#  ['Hogun [asgardian]', 'Austin, Susan', 'Sif'],
#  ['Fandral [asgardian]', 'Austin, Susan', 'Sif'],
#  ['Vizier', 'Austin, Susan', 'Sif'],
#  ['Odin [asgardian]', 'Austin, Susan', 'Sif'],
#  ['Mephisto', 'Austin, Susan', 'Sif'],
#  ['Balder [asgardian]', 'Austin, Susan', 'Sif'],
#  ['Ulik', 'Austin, Susan', 'Sif'],
#  ['High Evolutionary / He', 'Austin, Susan', 'Sif'],
#  ['Sub-mariner / Namor Ma', 'Zeus', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Wasp / Janet Van Dyne', 'Zeus', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Hawk', 'Zeus', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Scarlet Witch / Wanda', 'Zeus', 'Sif'],
#  ['Quicksilver / Pietro M',
#   'Zeus',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Captain America', 'Zeus', 'Sif'],
#  ['She-hulk / Jennifer Wa', 'Zeus', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Vision', 'Zeus', 'Sif'],
#  ['Heimdall [asgardian]', 'Zeus', 'Sif'],
#  ['Enchantress / Amora / He', 'Zeus', 'Sif'],
#  ['Thor / Dr. Donald Blak', 'Zeus', 'Sif'],
#  ['Ant-man / Dr. Henry J.', 'Zeus', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Hercules [greek God]', 'Zeus', 'Sif'],
#  ['Black Widow / Natasha',
#   'Zeus',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Volstagg', 'Zeus', 'Sif'],
#  ['Hogun [asgardian]', 'Zeus', 'Sif'],
#  ['Fandral [asgardian]', 'Zeus', 'Sif'],
#  ['Odin [asgardian]', 'Zeus', 'Sif'],
#  ['Dr. Druid / Anthony Lu',
#   'Zeus',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Captain Marvel Ii / Mo', 'Zeus', 'Sif'],
#  ['Balder [asgardian]', 'Zeus', 'Sif'],
#  ['Black Knight V / Dane', 'Zeus', 'Sif'],
#  ['Sersi / Sylvia', 'Zeus', 'Sif'],
#  ['Thunderball / Dr. Elio',
#   'Ulik',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Thunderstrike / Eric K', 'Ulik', 'Sif'],
#  ['Heimdall [asgardian]', 'Ulik', 'Sif'],
#  ['Enchantress / Amora / He', 'Ulik', 'Sif'],
#  ['Loki [asgardian]', 'Ulik', 'Sif'],
#  ['Thor / Dr. Donald Blak', 'Ulik', 'Sif'],
#  ['Hercules [greek God]', 'Ulik', 'Sif'],
#  ['Volstagg', 'Ulik', 'Sif'],
#  ['Hogun [asgardian]', 'Ulik', 'Sif'],
#  ['Fandral [asgardian]', 'Ulik', 'Sif'],
#  ['Vizier', 'Ulik', 'Sif'],
#  ['Odin [asgardian]', 'Ulik', 'Sif'],
#  ['Kincaid, Dr. Jane Fo', 'Ulik', 'Sif'],
#  ['Balder [asgardian]', 'Ulik', 'Sif'],
#  ['Wrecker Iii / Dirk Gar', 'Ulik', 'Sif'],
#  ['Bulldozer / Henry Camp',
#   'Ulik',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Piledriver Ii / Brian',
#   'Ulik',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ["Black Panther / T'chal",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Iron Man / Tony Stark', 'Sersi / Sylvia', 'Sif'],
#  ['Sub-mariner / Namor Ma', 'Sersi / Sylvia', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Firestar / Angelica Jo',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Namorita / Nita Prenti',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril'],
#  ['Spider-man / Peter Parker',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril'],
#  ['Tigra / Greer Nelson',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Wasp / Janet Van Dyne', 'Sersi / Sylvia', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Galactus / Galan', 'Sersi / Sylvia', 'Sif'],
#  ['Mockingbird / Dr. Barb',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Hawk', 'Sersi / Sylvia', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Scarlet Witch / Wanda', 'Sersi / Sylvia', 'Sif'],
#  ['Quicksilver / Pietro M',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Uatu',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Captain America', 'Sersi / Sylvia', 'Sif'],
#  ['Thunderstrike / Eric K', 'Sersi / Sylvia', 'Sif'],
#  ['Wonder Man / Simon Wil',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Wolverine / Logan', 'Sersi / Sylvia', 'Sif', 'Firelord / Pyreus Kril'],
#  ['She-hulk / Jennifer Wa', 'Sersi / Sylvia', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Vision', 'Sersi / Sylvia', 'Sif'],
#  ['Marvel Girl / Jean Grey',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Storm / Ororo Munroe S',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Mr. Fantastic / Reed R', 'Sersi / Sylvia', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Thing / Benjamin J. Gr',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Invisible Woman / Sue', 'Sersi / Sylvia', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Beast / Henry &hank& P',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Cyclops / Scott Summer', 'Sersi / Sylvia', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Thor / Dr. Donald Blak', 'Sersi / Sylvia', 'Sif'],
#  ['Spider-woman Ii / Juli',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Dr. Strange / Stephen', 'Sersi / Sylvia', 'Sif'],
#  ['Crystal [inhuman]',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Machine Man / X-51',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Moondragon / Heather D',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Human Torch / Johnny S',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Cage, Luke / Carl Luca',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Jarvis, Edwin', 'Sersi / Sylvia', 'Sif'],
#  ['Ant-man / Dr. Henry J.', 'Sersi / Sylvia', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Hercules [greek God]', 'Sersi / Sylvia', 'Sif'],
#  ['Black Widow / Natasha',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Sandman / William Bake',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Volstagg', 'Sersi / Sylvia', 'Sif'],
#  ['Hogun [asgardian]', 'Sersi / Sylvia', 'Sif'],
#  ['Fandral [asgardian]', 'Sersi / Sylvia', 'Sif'],
#  ['Odin [asgardian]', 'Sersi / Sylvia', 'Sif'],
#  ['Dr. Druid / Anthony Lu',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Makkari / Mike Khary / I', 'Sersi / Sylvia', 'Sif'],
#  ['Starfox / Eros', 'Sersi / Sylvia', 'Sif'],
#  ['Quasar Iii / Wendell V', 'Sersi / Sylvia', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Captain Marvel Ii / Mo', 'Sersi / Sylvia', 'Sif'],
#  ['Usagent / Captain John',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Nova Ii / Frankie Raye', 'Sersi / Sylvia', 'Sif', 'Firelord / Pyreus Kril'],
#  ['Binary / Carol Danvers',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Black Knight V / Dane', 'Sersi / Sylvia', 'Sif'],
#  ['Pharaoh Rama-tut',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Shaman / Michael Twoyo',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Hudson, Heather',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Sasquatch / Walter Lan',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Iron Fist / Daniel Ran',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Living Lightning / Mig',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Thena', 'Sersi / Sylvia', 'Sif'],
#  ['Ikaris / Ike Harris [e', 'Sersi / Sylvia', 'Sif'],
#  ['Northstar / Jean-paul',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Puck / Eugene Milton J',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Sub-mariner / Namor Ma', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Captain America', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Wolverine / Logan', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['She-hulk / Jennifer Wa', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Vision', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Hercules [greek God]', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Quasar Iii / Wendell V', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Shaman / Michael Twoyo', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Hudson, Heather', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Sasquatch / Walter Lan', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Stingray / Dr. Walter', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Diamond Lil / Lillian', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Guardian / James Macdo',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Wild Child / Kyle Gibn',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Northstar / Jean-paul', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Snowbird / Narya / Anne',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Puck / Eugene Milton J', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Iron Man / Tony Stark',
#   'Attuma',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Sub-mariner / Namor Ma', 'Attuma', 'Box Iv / Madison Jeffr'],
#  ['Namorita / Nita Prenti',
#   'Attuma',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Attuma',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Wasp / Janet Van Dyne',
#   'Attuma',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Hawk', 'Attuma', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Scarlet Witch / Wanda',
#   'Attuma',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Quicksilver / Pietro M',
#   'Attuma',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Captain America', 'Attuma', 'Box Iv / Madison Jeffr'],
#  ['Wonder Man / Simon Wil',
#   'Attuma',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Vision', 'Attuma', 'Box Iv / Madison Jeffr'],
#  ['Thing / Benjamin J. Gr',
#   'Attuma',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Beast / Henry &hank& P',
#   'Attuma',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Dr. Strange / Stephen',
#   'Attuma',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Ant-man / Dr. Henry J.',
#   'Attuma',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Dr. Doom / Victor Von',
#   'Attuma',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril'],
#  ['Black Knight V / Dane',
#   'Attuma',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Shaman / Michael Twoyo', 'Attuma', 'Box Iv / Madison Jeffr'],
#  ['Hudson, Heather', 'Attuma', 'Box Iv / Madison Jeffr'],
#  ['Aurora / Jeanne-marie', 'Attuma', 'Box Iv / Madison Jeffr'],
#  ['Puck / Eugene Milton J', 'Attuma', 'Box Iv / Madison Jeffr'],
#  ['Northstar / Jean-paul', 'Attuma', 'Box Iv / Madison Jeffr'],
#  ['Snowbird / Narya / Anne', 'Attuma', 'Box Iv / Madison Jeffr'],
#  ['Iron Man / Tony Stark', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Sub-mariner / Namor Ma', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Spider-man / Peter Parker', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Wasp / Janet Van Dyne', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Hawk', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Scarlet Witch / Wanda', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Captain America', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Wonder Man / Simon Wil', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Wolverine / Logan', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['She-hulk / Jennifer Wa', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Vision', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Thing / Benjamin J. Gr', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Thor / Dr. Donald Blak', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Dr. Strange / Stephen', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Jarvis, Edwin', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Ant-man / Dr. Henry J.', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Stankowicz, Fabian', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Hercules [greek God]', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Black Widow / Natasha', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Daredevil / Matt Murdo',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Starfox / Eros', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Fury, Col. Nicholas',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Quasar Iii / Wendell V', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Captain Marvel Ii / Mo', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Jameson, Col. John', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Falcon / Sam Wilson', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Rage / Elvin Daryl Hal', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Carter, Peggy', "O'brien, Michael", 'Sersi / Sylvia'],
#  ['Iron Man / Tony Stark', 'Vanguard / Nicolai Kry', "O'brien, Michael"],
#  ['Sub-mariner / Namor Ma', 'Vanguard / Nicolai Kry', "O'brien, Michael"],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia'],
#  ['Spider-man / Peter Parker', 'Vanguard / Nicolai Kry', "O'brien, Michael"],
#  ['Wasp / Janet Van Dyne', 'Vanguard / Nicolai Kry', "O'brien, Michael"],
#  ['Scarlet Witch / Wanda', 'Vanguard / Nicolai Kry', "O'brien, Michael"],
#  ['Captain America', 'Vanguard / Nicolai Kry', "O'brien, Michael"],
#  ['Wonder Man / Simon Wil', 'Vanguard / Nicolai Kry', "O'brien, Michael"],
#  ['Wolverine / Logan', 'Vanguard / Nicolai Kry', "O'brien, Michael"],
#  ['Vision', 'Vanguard / Nicolai Kry', "O'brien, Michael"],
#  ['Storm / Ororo Munroe S',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia'],
#  ['Mr. Fantastic / Reed R',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia'],
#  ['Thing / Benjamin J. Gr', 'Vanguard / Nicolai Kry', "O'brien, Michael"],
#  ['Invisible Woman / Sue',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia'],
#  ['Beast / Henry &hank& P',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia'],
#  ['Thor / Dr. Donald Blak', 'Vanguard / Nicolai Kry', "O'brien, Michael"],
#  ['Dr. Strange / Stephen', 'Vanguard / Nicolai Kry', "O'brien, Michael"],
#  ['Human Torch / Johnny S',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia'],
#  ['Black Widow / Natasha', 'Vanguard / Nicolai Kry', "O'brien, Michael"],
#  ['Daredevil / Matt Murdo', 'Vanguard / Nicolai Kry', "O'brien, Michael"],
#  ['Jack Of Hearts / Jack', 'Vanguard / Nicolai Kry', "O'brien, Michael"],
#  ['Captain Britain / Bria',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Jones, Richard Milho',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Iron Man / Tony Stark', 'Darkstar / Laynia Serg', 'Vanguard / Nicolai Kry'],
#  ['Rogue  / ',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Sub-mariner / Namor Ma',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry'],
#  ['Spider-man / Peter Parker',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry'],
#  ['Wasp / Janet Van Dyne', 'Darkstar / Laynia Serg', 'Vanguard / Nicolai Kry'],
#  ['Hawk',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael"],
#  ['Scarlet Witch / Wanda', 'Darkstar / Laynia Serg', 'Vanguard / Nicolai Kry'],
#  ['Captain America', 'Darkstar / Laynia Serg', 'Vanguard / Nicolai Kry'],
#  ['Wonder Man / Simon Wil',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry'],
#  ['Wolverine / Logan', 'Darkstar / Laynia Serg', 'Vanguard / Nicolai Kry'],
#  ['Vision', 'Darkstar / Laynia Serg', 'Vanguard / Nicolai Kry'],
#  ['Storm / Ororo Munroe S',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry'],
#  ['Mr. Fantastic / Reed R',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry'],
#  ['Angel / Warren Kenneth',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Thing / Benjamin J. Gr',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry'],
#  ['Invisible Woman / Sue', 'Darkstar / Laynia Serg', 'Vanguard / Nicolai Kry'],
#  ['Beast / Henry &hank& P',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry'],
#  ['Thor / Dr. Donald Blak',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry'],
#  ['Iceman / Robert Bobby',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Human Torch / Johnny S',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry'],
#  ['Magneto / Magnus / Eric',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Ant-man / Dr. Henry J.',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael"],
#  ['Hercules [greek God]',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael"],
#  ['Black Widow / Natasha', 'Darkstar / Laynia Serg', 'Vanguard / Nicolai Kry'],
#  ['Daredevil / Matt Murdo',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry'],
#  ['Jack Of Hearts / Jack', 'Darkstar / Laynia Serg', 'Vanguard / Nicolai Kry'],
#  ['Captain Britain / Bria',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry'],
#  ['Jones, Richard Milho', 'Darkstar / Laynia Serg', 'Vanguard / Nicolai Kry'],
#  ['Sunfire / Shiro Yoshid',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Iron Man / Tony Stark', 'Ghost Rider Ii / Johnn', 'Darkstar / Laynia Serg'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg'],
#  ['Spider-man / Peter Parker',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg'],
#  ['Wasp / Janet Van Dyne', 'Ghost Rider Ii / Johnn', 'Darkstar / Laynia Serg'],
#  ['Scarlet Witch / Wanda', 'Ghost Rider Ii / Johnn', 'Darkstar / Laynia Serg'],
#  ['Captain America', 'Ghost Rider Ii / Johnn', 'Darkstar / Laynia Serg'],
#  ['Vision', 'Ghost Rider Ii / Johnn', 'Darkstar / Laynia Serg'],
#  ['Mr. Fantastic / Reed R',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg'],
#  ['Angel / Warren Kenneth',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg'],
#  ['Thing / Benjamin J. Gr',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg'],
#  ['Invisible Woman / Sue', 'Ghost Rider Ii / Johnn', 'Darkstar / Laynia Serg'],
#  ['Beast / Henry &hank& P',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg'],
#  ['Thor / Dr. Donald Blak',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg'],
#  ['Dr. Strange / Stephen',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry'],
#  ['Norriss, Sister Barb',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Iceman / Robert Bobby', 'Ghost Rider Ii / Johnn', 'Darkstar / Laynia Serg'],
#  ['Gargoyle Ii / Isaac Ch',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Human Torch / Johnny S',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg'],
#  ['Hobgoblin V / Jason Ph',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Hercules [greek God]', 'Ghost Rider Ii / Johnn', 'Darkstar / Laynia Serg'],
#  ['Daredevil / Matt Murdo',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg'],
#  ['Black Widow / Natasha', 'Ghost Rider Ii / Johnn', 'Darkstar / Laynia Serg'],
#  ['Ant-man / Dr. Henry J.',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg'],
#  ['Iron Man / Tony Stark', 'Hellstorm / Daimon Hel', 'Ghost Rider Ii / Johnn'],
#  ['Sub-mariner / Namor Ma',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn'],
#  ['Spider-man / Peter Parker',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn'],
#  ['Tigra / Greer Nelson',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia'],
#  ['Mockingbird / Dr. Barb',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia'],
#  ['Silver Surfer / Norrin',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif'],
#  ['Hawk',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg'],
#  ['Scarlet Witch / Wanda', 'Hellstorm / Daimon Hel', 'Ghost Rider Ii / Johnn'],
#  ['Captain America', 'Hellstorm / Daimon Hel', 'Ghost Rider Ii / Johnn'],
#  ['Wonder Man / Simon Wil',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg'],
#  ['Vision', 'Hellstorm / Daimon Hel', 'Ghost Rider Ii / Johnn'],
#  ['Mr. Fantastic / Reed R',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn'],
#  ['Thing / Benjamin J. Gr',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn'],
#  ['Beast / Henry &hank& P',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn'],
#  ['Dr. Strange / Stephen', 'Hellstorm / Daimon Hel', 'Ghost Rider Ii / Johnn'],
#  ['Hellcat / Patsy Walker',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Norriss, Sister Barb', 'Hellstorm / Daimon Hel', 'Ghost Rider Ii / Johnn'],
#  ['Gargoyle Ii / Isaac Ch',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn'],
#  ['Human Torch / Johnny S',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn'],
#  ['Cage, Luke / Carl Luca',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia'],
#  ['Ant-man / Dr. Henry J.',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn'],
#  ['Clea',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Daredevil / Matt Murdo',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn'],
#  ['Mephisto',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif'],
#  ['Iron Man / Tony Stark', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Sub-mariner / Namor Ma', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Hulk / Dr. Robert Bruce Banner', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Spider-man / Peter Parker', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Silver Surfer / Norrin', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Hawk', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Scarlet Witch / Wanda', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Captain America', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Wonder Man / Simon Wil', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Vision', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Eternity / Adam Qadmon',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Mr. Fantastic / Reed R', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Thing / Benjamin J. Gr', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Invisible Woman / Sue',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn'],
#  ['Beast / Henry &hank& P', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Thor / Dr. Donald Blak',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn'],
#  ['Dr. Strange / Stephen', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Hellcat / Patsy Walker', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Nighthawk Ii / Kyle Ri', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Norriss, Sister Barb', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Jameson, J. Jonah',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Gargoyle Ii / Isaac Ch', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Human Torch / Johnny S', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Cage, Luke / Carl Luca', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Ant-man / Dr. Henry J.', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Mephisto', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Fury, Col. Nicholas',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael"],
#  ['Clea', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Daredevil / Matt Murdo', 'Wong', 'Hellstorm / Daimon Hel'],
#  ['Iron Man / Tony Stark', 'Banner, Betty Ross T', 'Wong'],
#  ['Sub-mariner / Namor Ma', 'Banner, Betty Ross T', 'Wong'],
#  ['Hulk / Dr. Robert Bruce Banner', 'Banner, Betty Ross T', 'Wong'],
#  ['Spider-man / Peter Parker', 'Banner, Betty Ross T', 'Wong'],
#  ['Tigra / Greer Nelson',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel'],
#  ['Wasp / Janet Van Dyne',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn'],
#  ['Silver Surfer / Norrin', 'Banner, Betty Ross T', 'Wong'],
#  ['Hawk', 'Banner, Betty Ross T', 'Wong'],
#  ['Scarlet Witch / Wanda', 'Banner, Betty Ross T', 'Wong'],
#  ['Quicksilver / Pietro M',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia'],
#  ['Captain America', 'Banner, Betty Ross T', 'Wong'],
#  ['Wonder Man / Simon Wil', 'Banner, Betty Ross T', 'Wong'],
#  ['Wolverine / Logan',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg'],
#  ['She-hulk / Jennifer Wa',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael"],
#  ['Vision', 'Banner, Betty Ross T', 'Wong'],
#  ['Mr. Fantastic / Reed R', 'Banner, Betty Ross T', 'Wong'],
#  ['Thing / Benjamin J. Gr', 'Banner, Betty Ross T', 'Wong'],
#  ['Invisible Woman / Sue', 'Banner, Betty Ross T', 'Wong'],
#  ['Cyclops / Scott Summer',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia'],
#  ['Thor / Dr. Donald Blak', 'Banner, Betty Ross T', 'Wong'],
#  ['Dr. Strange / Stephen', 'Banner, Betty Ross T', 'Wong'],
#  ['Norriss, Sister Barb', 'Banner, Betty Ross T', 'Wong'],
#  ['Captain Marvel Ii / Mo',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael"],
#  ['Ant-man / Dr. Henry J.', 'Banner, Betty Ross T', 'Wong'],
#  ['Hercules [greek God]',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn'],
#  ['Doc Samson / Dr. Leona',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Human Torch / Johnny S', 'Banner, Betty Ross T', 'Wong'],
#  ['Crystal [inhuman]',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia'],
#  ['Sasquatch / Walter Lan',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia'],
#  ['Jameson, J. Jonah', 'Banner, Betty Ross T', 'Wong'],
#  ['Jones, Richard Milho',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg'],
#  ['Fury, Col. Nicholas', 'Banner, Betty Ross T', 'Wong'],
#  ['Iron Man / Tony Stark', 'Leader / Sam Sterns', 'Banner, Betty Ross T'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Leader / Sam Sterns',
#   'Banner, Betty Ross T'],
#  ['Spider-man / Peter Parker', 'Leader / Sam Sterns', 'Banner, Betty Ross T'],
#  ['Wasp / Janet Van Dyne', 'Leader / Sam Sterns', 'Banner, Betty Ross T'],
#  ['Hawk', 'Leader / Sam Sterns', 'Banner, Betty Ross T'],
#  ['Captain America', 'Leader / Sam Sterns', 'Banner, Betty Ross T'],
#  ['She-hulk / Jennifer Wa', 'Leader / Sam Sterns', 'Banner, Betty Ross T'],
#  ['Mr. Fantastic / Reed R', 'Leader / Sam Sterns', 'Banner, Betty Ross T'],
#  ['Thing / Benjamin J. Gr', 'Leader / Sam Sterns', 'Banner, Betty Ross T'],
#  ['Invisible Woman / Sue', 'Leader / Sam Sterns', 'Banner, Betty Ross T'],
#  ['Thor / Dr. Donald Blak', 'Leader / Sam Sterns', 'Banner, Betty Ross T'],
#  ['Dr. Strange / Stephen', 'Leader / Sam Sterns', 'Banner, Betty Ross T'],
#  ['Ross, Gen. Thaddeus', 'Leader / Sam Sterns', 'Banner, Betty Ross T'],
#  ['Human Torch / Johnny S', 'Leader / Sam Sterns', 'Banner, Betty Ross T'],
#  ['Jones, Richard Milho', 'Leader / Sam Sterns', 'Banner, Betty Ross T'],
#  ['Doc Samson / Dr. Leona', 'Leader / Sam Sterns', 'Banner, Betty Ross T'],
#  ['Iron Man / Tony Stark', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Sub-mariner / Namor Ma', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Ross, Gen. Thaddeus',
#   'Banner, Betty Ross T'],
#  ['Spider-man / Peter Parker', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Wasp / Janet Van Dyne', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Silver Surfer / Norrin', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Hawk', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Scarlet Witch / Wanda', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Quicksilver / Pietro M', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Captain America', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Wonder Man / Simon Wil', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['She-hulk / Jennifer Wa', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Vision', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Mr. Fantastic / Reed R', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Thing / Benjamin J. Gr', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Invisible Woman / Sue', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Thor / Dr. Donald Blak', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Dr. Strange / Stephen', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Norriss, Sister Barb', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Jameson, J. Jonah', 'Ross, Gen. Thaddeus', 'Banner, Betty Ross T'],
#  ['Jarvis, Edwin',
#   'Ross, Gen. Thaddeus',
#   'Banner, Betty Ross T',
#   'Wong',
# ...
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Black Widow / Natasha',
#   'Dagger / Tandy Bowen',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast'],
#  ['Moon Knight / Marc Spe',
#   'Dagger / Tandy Bowen',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Black Cat / Felicia Ha',
#   'Dagger / Tandy Bowen',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra',
#   'Dr. Octopus / Otto Oct'],
#  ['Daredevil / Matt Murdo',
#   'Dagger / Tandy Bowen',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast'],
#  ['Dr. Doom / Victor Von',
#   'Dagger / Tandy Bowen',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi'],
#  ['Cloak / Tyrone Johnson', 'Dagger / Tandy Bowen', 'Gee / Alex Power'],
#  ['Darkhawk / Chris Powel', 'Dagger / Tandy Bowen', 'Gee / Alex Power'],
#  ['Mystique / Raven Darkh',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Blob / Fred J. Dukes',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Pyro / Allerdyce Johnn',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Avalanche / Dominic Pe',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Destiny Ii / Irene Adl',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Wolverine / Logan',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi'],
#  ['Marvel Girl / Jean Grey',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi'],
#  ['Angel / Warren Kenneth',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn'],
#  ['Jubilee / Jubilation L',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Beast / Henry &hank& P',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast'],
#  ['Cyclops / Scott Summer',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi'],
#  ['Iceman / Robert Bobby',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi'],
#  ['Tilby, Trish / Patrici',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Cannonball Ii / Sam Gu',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Richards, Franklin B', 'Leech', 'Gee / Alex Power'],
#  ['Banshee / Sean Cassidy',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Apocalypse / En Sabah',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Firefist / Rusty Colli',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Skids / Sally Blevins',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Caliban / ',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['White Queen / Emma Fro',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast'],
#  ['Boomer / Tabitha Smith',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Rictor / Julio Esteban',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Skin / Angelo Espinosa',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Wolverine / Logan', 'Hodge, Cameron', 'Leech'],
#  ['Psylocke / Elisabeth B',
#   'Hodge, Cameron',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Marvel Girl / Jean Grey', 'Hodge, Cameron', 'Leech'],
#  ['Storm / Ororo Munroe S',
#   'Hodge, Cameron',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg'],
#  ['Angel / Warren Kenneth', 'Hodge, Cameron', 'Leech'],
#  ['Jubilee / Jubilation L', 'Hodge, Cameron', 'Leech'],
#  ['Beast / Henry &hank& P', 'Hodge, Cameron', 'Leech'],
#  ['Cyclops / Scott Summer', 'Hodge, Cameron', 'Leech'],
#  ['Iceman / Robert Bobby', 'Hodge, Cameron', 'Leech'],
#  ['Havok / Alex Summers',
#   'Hodge, Cameron',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Summers, Nathan Chri',
#   'Hodge, Cameron',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Tilby, Trish / Patrici', 'Hodge, Cameron', 'Leech'],
#  ['Wolfsbane / Rahne Sinc',
#   'Hodge, Cameron',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Warlock Iii', 'Hodge, Cameron', 'Leech', 'Gee / Alex Power'],
#  ['Sunspot / Roberto Daco',
#   'Hodge, Cameron',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Cannonball Ii / Sam Gu', 'Hodge, Cameron', 'Leech'],
#  ['Banshee / Sean Cassidy', 'Hodge, Cameron', 'Leech'],
#  ['Gambit / Remy Lebeau',
#   'Hodge, Cameron',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern'],
#  ['Forge',
#   'Hodge, Cameron',
#   'Leech',
#   'Gee / Alex Power',
#   'Justice Ii / Vance Ast',
#   'Triathlon / Delroy Gar',
#   'Screaming Mimi / Melis',
#   'Fixer Ii / Paul Norber',
#   'Dugan, Timothy Aloyi',
#   'Banner, Betty Ross T',
#   'Wong',
#   'Hellstorm / Daimon Hel',
#   'Ghost Rider Ii / Johnn',
#   'Darkstar / Laynia Serg',
#   'Vanguard / Nicolai Kry',
#   "O'brien, Michael",
#   'Sersi / Sylvia',
#   'Sif',
#   'Firelord / Pyreus Kril',
#   'Pip / Prince Gofern',
#   'Colossus Ii / Peter Ra'],
#  ['Apocalypse / En Sabah', 'Hodge, Cameron', 'Leech'],
#  ['Firefist / Rusty Colli', 'Hodge, Cameron', 'Leech'],
#  ['Skids / Sally Blevins', 'Hodge, Cameron', 'Leech'],
#  ['Caliban / ', 'Hodge, Cameron', 'Leech'],
#  ['Boomer / Tabitha Smith', 'Hodge, Cameron', 'Leech'],
#  ['Rictor / Julio Esteban', 'Hodge, Cameron', 'Leech'],
#  ['Maddicks, Arthur Art', 'Hodge, Cameron', 'Leech'],
#  ['Mystique / Raven Darkh', 'Maddicks, Arthur Art', 'Leech'],
#  ['Blob / Fred J. Dukes', 'Maddicks, Arthur Art', 'Leech'],
#  ['Pyro / Allerdyce Johnn', 'Maddicks, Arthur Art', 'Leech'],
#  ['Avalanche / Dominic Pe', 'Maddicks, Arthur Art', 'Leech'],
#  ['Destiny Ii / Irene Adl', 'Maddicks, Arthur Art', 'Leech'],
#  ['Marvel Girl / Jean Grey', 'Maddicks, Arthur Art', 'Leech'],
#  ['Angel / Warren Kenneth', 'Maddicks, Arthur Art', 'Leech'],
#  ['Jubilee / Jubilation L', 'Maddicks, Arthur Art', 'Leech'],
#  ['Beast / Henry &hank& P', 'Maddicks, Arthur Art', 'Leech'],
#  ...]
