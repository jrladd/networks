# %% [markdown]
# # Metrics
#
# NetworkX includes a huge amount of algorithms and metrics. Here's a cheatsheet to the most common ones you'll need.
#
# ## Network Properties

# %%
# Import NetworkX and key data science libraries
import networkx as nx
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_theme()

# Import Marvel network data
marvel= pd.read_csv("data/marvel-unimodal-edges.csv")
M = nx.from_pandas_edgelist(marvel, source="Source", target="Target", edge_attr=True)
print(M)
# Out:
# Graph with 327 nodes and 9891 edges

# %%
M.number_of_nodes() # Number of nodes
# Out:
# 327

# %%
M.number_of_edges() # Alternative method for number of edges
# Out:
# 9891

# %%
M.is_directed() # Is the graph directed?
# Out:
# False

# %% [markdown]
# ## Paths

# %%
nx.shortest_path(M, "Black Panther / T'chal", 	"Gambit / Remy Lebeau") # Shortest path as list
# Out:
# ["Black Panther / T'chal", 'Firestar / Angelica Jo', 'Gambit / Remy Lebeau']

# %%
nx.shortest_path_length(M, "Black Panther / T'chal", "Gambit / Remy Lebeau") #Shortest path length (Distance)
# Out:
# 2

# %%
nx.average_shortest_path_length(M) # Average shortest path length (Average distance)
# Out:
# 1.873004258831917

# %%
nx.diameter(M)
# Out:
# 3

# %% [markdown]
# ## Components

# %%
nx.is_connected(M) # Is the graph connected?
# Out:
# True

# %%
nx.number_connected_components(M) # How many components are there?
# Out:
# 1

# %%
# Find the largest connected component (as a node set)
components = [G for G in nx.connected_components(M)]
largest = max(components, key=len)

# %% [markdown]
# ## Centrality
#
# Below I show just one example, but there are a range of [centrality functions](https://networkx.org/documentation/stable/reference/algorithms/centrality.html) in NetworkX.
#
# [n.b. I'll create a separate chapter on centrality soon.]

# %%
# Calculate betweenness centrality for every node
bc = nx.betweenness_centrality(M)

# %% [markdown]
# ## Triangles and Clustering

# %%
# Get number of triangles for every node
nx.triangles(M)

# n.b. Pay attention to the following note from the NetworkX docs:
# When computing triangles for the entire graph each triangle is counted three times, once at each node.
# Out:
# {"Black Panther / T'chal": 2837,
#  'Loki [asgardian]': 1055,
#  'Mantis / ? Brandt': 277,
#  'Iceman / Robert Bobby': 5320,
#  'Marvel Girl / Jean Grey': 5050,
#  'Cyclops / Scott Summer': 6474,
#  'Klaw / Ulysses Klaw': 1012,
#  'Human Torch / Johnny S': 6282,
#  'Richards, Franklin B': 2444,
#  'Wolverine / Logan': 7168,
#  'Firebird / Bonita Juar': 643,
#  'Mr. Fantastic / Reed R': 6191,
#  'Medusa / Medusalith Am': 1019,
#  'Dr. Strange / Stephen': 4522,
#  'Jack Of Hearts / Jack': 576,
#  'Mephisto': 916,
#  'Thanos': 2337,
#  'Swordsman / Jacques Du': 342,
#  'Collector / Taneleer T': 393,
#  'Lockjaw [inhuman]': 865,
#  'Sub-mariner / Namor Ma': 4197,
#  'Pharaoh Rama-tut': 2562,
#  'Ant-man Ii / Scott Har': 917,
#  'Lyja Lazerfist [skru': 399,
#  'Gorgon [inhuman]': 837,
#  'Nighthawk Ii / Kyle Ri': 422,
#  'Cage, Luke / Carl Luca': 1200,
#  'Colossus Ii / Peter Ra': 6169,
#  'Hellcat / Patsy Walker': 1278,
#  'Karnak [inhuman]': 873,
#  'Death': 756,
#  'Redwing': 214,
#  'Daredevil / Matt Murdo': 4276,
#  'Norriss, Sister Barb': 1244,
#  'Rage / Elvin Daryl Hal': 875,
#  'Starfox / Eros': 1686,
#  'Demolition Man / Denni': 349,
#  'Sersi / Sylvia': 1906,
#  'Spider-man / Peter Parker': 6533,
#  'Vision': 6672,
#  'Uatu': 2324,
#  'Binary / Carol Danvers': 2010,
#  'Gyrich, Henry Peter': 985,
#  'Nightcrawler / Kurt Wa': 3965,
#  'Angel / Warren Kenneth': 5562,
#  'Silver Surfer / Norrin': 3697,
#  'She-hulk / Jennifer Wa': 5868,
#  'Ghaur [deviant]': 155,
#  'Dr. Doom / Victor Von': 4084,
#  'Storm / Ororo Munroe S': 6220,
#  'Scarlet Witch / Wanda': 6216,
#  'Toad / Mortimer Toynbe': 537,
#  'Hulk / Dr. Robert Bruce Banner': 5984,
#  'Firestar / Angelica Jo': 2659,
#  'Wonder Man / Simon Wil': 5412,
#  'Drax / Arthur Douglas': 2307,
#  'Dugan, Timothy Aloyi': 825,
#  'Carter, Sharon': 152,
#  'Black Knight V / Dane': 4610,
#  'Sunfire / Shiro Yoshid': 953,
#  'Triton': 606,
#  'Ultron': 1099,
#  'Jones, Richard Milho': 1590,
#  'Iron Man / Tony Stark': 5983,
#  'Nelson, Franklin Fog': 425,
#  'Captain America': 7888,
#  'Jarvis, Edwin': 3437,
#  'Quasar Iii / Wendell V': 4047,
#  'Jameson, J. Jonah': 1628,
#  'Masters, Alicia Reis': 1333,
#  'Magneto / Magnus / Eric': 3138,
#  'Invisible Woman / Sue': 6242,
#  'Professor X / Charles': 6081,
#  'Iron Fist / Daniel Ran': 1049,
#  'Black Bolt / Blackanto': 849,
#  'Hawk': 5168,
#  'Sandman / William Bake': 1088,
#  'Falcon / Sam Wilson': 2034,
#  'Stingray / Dr. Walter': 575,
#  'Justice Ii / Vance Ast': 876,
#  'Hercules [greek God]': 5530,
#  'Usagent / Captain John': 2828,
#  'Captain Marvel Ii / Mo': 2628,
#  'Crystal [inhuman]': 3778,
#  'Tigra / Greer Nelson': 2055,
#  'Spider-woman Ii / Juli': 2654,
#  'Machine Man / X-51': 814,
#  'Mockingbird / Dr. Barb': 1399,
#  'Captain Marvel / Capta': 564,
#  'Wasp / Janet Van Dyne': 5937,
#  'Fury, Col. Nicholas': 2781,
#  'Thor / Dr. Donald Blak': 5939,
#  'Quicksilver / Pietro M': 5163,
#  'Captain Britain / Bria': 692,
#  'Shadowcat / Katherine': 2969,
#  'Black Widow / Natasha': 4685,
#  'Ant-man / Dr. Henry J.': 5128,
#  'Moon Knight / Marc Spe': 1736,
#  'Jocasta': 316,
#  'Moondragon / Heather D': 3402,
#  'Thing / Benjamin J. Gr': 6867,
#  'Beast / Henry &hank& P': 6660,
#  'Nova / Richard Rider': 3271,
#  'Wrecker Iii / Dirk Gar': 1027,
#  'Warlock Ii / Adam Warl': 2287,
#  'Piledriver Ii / Brian': 928,
#  'Thunderball / Dr. Elio': 1042,
#  'Dr. Octopus / Otto Oct': 998,
#  'Banner, Betty Ross T': 581,
#  'Avalanche / Dominic Pe': 571,
#  'Attuma': 243,
#  'Hela [asgardian]': 279,
#  'Doc Samson / Dr. Leona': 685,
#  'Guardian / James Macdo': 456,
#  'Northstar / Jean-paul': 2137,
#  'Dr. Druid / Anthony Lu': 2075,
#  'Watson-parker, Mary': 805,
#  'Mystique / Raven Darkh': 1067,
#  'Pyro / Allerdyce Johnn': 740,
#  'Destiny Ii / Irene Adl': 418,
#  'Mister Hyde / Calvin Z': 189,
#  'Ghost Rider Ii / Johnn': 279,
#  'Mole Man / Harvey Rupe': 544,
#  'Firelord / Pyreus Kril': 540,
#  'Leader / Sam Sterns': 136,
#  'Le Fey, Morgan': 141,
#  'Bulldozer / Henry Camp': 928,
#  'Forgotten One / Gilgam': 310,
#  'Balder [asgardian]': 358,
#  'Hogun [asgardian]': 539,
#  'Hellstorm / Daimon Hel': 341,
#  'Aurora / Jeanne-marie': 1466,
#  "O'brien, Michael": 437,
#  'Stankowicz, Fabian': 259,
#  'Screaming Mimi / Melis': 332,
#  'Moonstone Ii / Karla S': 556,
#  'Fixer Ii / Paul Norber': 399,
#  'Darkstar / Laynia Serg': 441,
#  'Vanguard / Nicolai Kry': 275,
#  'Gamora': 1577,
#  'Psylocke / Elisabeth B': 4245,
#  'Rogue  / ': 5545,
#  'Sasquatch / Walter Lan': 3138,
#  'Luna / Luna Maximoff [': 357,
#  'Whizzer Ii / Stanley S': 96,
#  'Dr. Spectrum / Joseph': 96,
#  'Kingpin / Wilson Fisk': 518,
#  'Clea': 171,
#  'Polaris / Lorna Dane': 3325,
#  'De La Fontaine, Cont': 174,
#  'Heimdall [asgardian]': 193,
#  'Red Skull / Johann Sch': 429,
#  'Thompson, Eugene Fla': 507,
#  'Wong': 412,
#  'Parker, May': 541,
#  'Green Goblin / Norman': 207,
#  'Night Thrasher / Duane': 252,
#  'Eternity / Adam Qadmon': 1623,
#  'Galactus / Galan': 3125,
#  'Triathlon / Delroy Gar': 334,
#  'Beetle / Abner Ronald': 659,
#  'Lilandra Neramani [s': 1290,
#  'Odin [asgardian]': 903,
#  'Hogan, Virginia Pepp': 113,
#  'Mad Dog / Colonel Buzz': 166,
#  'Kincaid, Dr. Jane Fo': 249,
#  'Wizard / Bentley Wittm': 309,
#  'Charcoal / Charlie Bur': 165,
#  'Blob / Fred J. Dukes': 1189,
#  'Cloak / Tyrone Johnson': 164,
#  'Thunderstrike / Eric K': 3331,
#  'Power Man / Erik Joste': 580,
#  'Human Torch Android / ': 468,
#  'Juggernaut / Cain Mark': 349,
#  'Absorbing Man / Carl C': 981,
#  'Volstagg': 466,
#  'Shaman / Michael Twoyo': 2187,
#  'Snowbird / Narya / Anne': 381,
#  'Dagger / Tandy Bowen': 273,
#  'Phoenix Iii / Rachel S': 892,
#  'Mandarin': 177,
#  'Fandral [asgardian]': 546,
#  'Ms. Marvel Ii / Sharon': 265,
#  'Pip / Prince Gofern': 1569,
#  'Enchantress / Amora / He': 1465,
#  'Jameson, Col. John': 328,
#  'Cooper, Dr. Valerie': 1411,
#  'Nova Ii / Frankie Raye': 1992,
#  'Darkhawk / Chris Powel': 1881,
#  'Nomad Iii / Jack Monro': 197,
#  'Robertson, Joe': 654,
#  'Gargoyle Ii / Isaac Ch': 549,
#  'Namorita / Nita Prenti': 2840,
#  'Iron Man Iv / James R.': 1520,
#  'Ross, Gen. Thaddeus': 384,
#  'Harkness, Agatha': 2391,
#  'Carter, Peggy': 387,
#  'Hyperion': 160,
#  'Living Lightning / Mig': 2888,
#  'Jones, Gabe': 304,
#  'Osborn, Liz Allan': 451,
#  'Leeds, Betty Brant': 508,
#  'Sif': 444,
#  'Dazzler Ii / Allison B': 970,
#  'Molecule Man / Owen Re': 731,
#  'Speedball / Robbie Bal': 2263,
#  'Lizard / Dr. Curtis Co': 778,
#  'Volcana / Marsha Rosen': 615,
#  'Lockheed': 796,
#  'Titania Ii / Mary Skee': 748,
#  'Boomer / Tabitha Smith': 1306,
#  'Summers, Nathan Chri': 1861,
#  'Summers, Madelyne Ma': 524,
#  'Mactaggert, Moira Ki': 1662,
#  'Cannonball Ii / Sam Gu': 2512,
#  'Tilby, Trish / Patrici': 423,
#  'Skids / Sally Blevins': 371,
#  'Wolfsbane / Rahne Sinc': 3135,
#  'Leech': 249,
#  'Mirage Ii / Danielle M': 907,
#  'Gambit / Remy Lebeau': 3766,
#  'Jubilee / Jubilation L': 1117,
#  'Strong Guy / Guido Car': 2793,
#  'Spiral': 328,
#  'Banshee / Sean Cassidy': 1321,
#  'Legion Ii / David Hall': 377,
#  'Havok / Alex Summers': 3894,
#  'Longshot': 450,
#  'Forge': 1666,
#  'Sabretooth / Victor Cr': 659,
#  'Maddicks, Arthur Art': 225,
#  'Warlock Iii': 1030,
#  'Rictor / Julio Esteban': 953,
#  'Sunspot / Roberto Daco': 1687,
#  'Firefist / Rusty Colli': 334,
#  'Bishop  / ': 1466,
#  'Daytripper / Amanda Se': 258,
#  'Wild Child / Kyle Gibn': 1274,
#  'Thunderbird Ii / James': 1105,
#  'Sauron / Dr. Karl Lyko': 267,
#  'Siryn / Theresa Rourke': 965,
#  'Shatterstar Ii / Gavee': 682,
#  'Marrow / Sarah': 424,
#  'Feral / Maria Callasan': 515,
#  'Callisto': 302,
#  'Mr. Sinister / Nathan': 395,
#  'Raza Longknife': 332,
#  'Spider-woman / Jessica': 371,
#  'Cypher / Doug Ramsey': 589,
#  "Deathbird [shi'ar]": 297,
#  'Hudson, Heather': 2525,
#  'Stryfe': 518,
#  'Iron Man Doppelgange': 1031,
#  'Puck / Eugene Milton J': 2347,
#  'Silhouette': 519,
#  'Cortez, Fabian': 189,
#  'Black King / Sebastian': 402,
#  'Magik / Illyana Rasput': 605,
#  'Zabu': 229,
#  'Domino Iii / Beatrice / ': 229,
#  'Caliban / ': 607,
#  'Apocalypse / En Sabah': 1043,
#  'Hunter, Stevie': 588,
#  'Corsair': 486,
#  "Ch'od": 377,
#  "Mam'selle Hepzibah": 378,
#  'Zero': 431,
#  'X-man / Nathan Grey': 403,
#  "Karma / Xi'an Coy Manh": 331,
#  'Mr. Fantastic Doppel': 1153,
#  'Beyonder': 482,
#  'Multiple Man / James A': 2008,
#  'Colossus Ii Doppelga': 325,
#  'Scanner Ii': 139,
#  'Ka-zar / Kevin Plunder': 418,
#  'White Queen / Emma Fro': 514,
#  'Magma / Amara Aquilla / ': 333,
#  'Thanos Doppelganger': 1688,
#  'Magus': 2249,
#  'Knight, Misty': 259,
#  'Wing, Colleen': 53,
#  'Puppet Master / Philli': 273,
#  'Maximus [inhuman]': 185,
#  'Punisher Ii / Frank Ca': 333,
#  'Zeus': 217,
#  'Box Iv / Madison Jeffr': 156,
#  'Thena': 159,
#  'Black Cat / Felicia Ha': 270,
#  'Gee / Alex Power': 123,
#  'Spider-man Clone / Ben': 111,
#  'Ulik': 128,
#  'Citizen V Ii / Helmut': 285,
#  'High Evolutionary / He': 439,
#  'Hobgoblin V / Jason Ph': 213,
#  'Ghost Rider Iii / Dan': 111,
#  'Cushing, Kate': 224,
#  'Katzenberg, Nick': 174,
#  'Vizier': 208,
#  'Tombstone / Lonnie Tho': 154,
#  'Mercado, Joy': 191,
#  'Hammerhead': 138,
#  'Arranger / ': 170,
#  'Osborn, Harry': 291,
#  'Cobra / Klaus Vorhees': 64,
#  'Leeds, Ned': 228,
#  'Watson, Anna': 249,
#  'Urich, Ben': 431,
#  'Robertson, Randy': 199,
#  'Page, Karen': 97,
#  'Grant, Gloria Glory': 295,
#  'Lubenski, Nate': 162,
#  'Ikaris / Ike Harris [e': 114,
#  'Rosenthal, Bernie': 133,
#  'Gladiator Ii': 214,
#  'Beta Ray Bill': 188,
#  'Bridge, George Washi': 92,
#  'Diamond Lil / Lillian': 81,
#  'Asp Ii / Cleo': 27,
#  'Black Mamba / Tanya Se': 27,
#  'Meggan': 187,
#  'Austin, Susan': 122,
#  'Diamondback Ii / Rache': 120,
#  'Makkari / Mike Khary / I': 195,
#  'Hodge, Cameron': 301,
#  'Skin / Angelo Espinosa': 72,
#  'Husk / Paige Guthrie': 93,
#  'Deadpool / Jack / Wade W': 61}

# %%
# Get clustering coefficients
# These can be added to a node dataframe as in the previous chapter
nx.clustering(M)
# Out:
# {"Black Panther / T'chal": 0.5617821782178218,
#  'Loki [asgardian]': 0.5579058699101005,
#  'Mantis / ? Brandt': 0.9233333333333333,
#  'Iceman / Robert Bobby': 0.40794417606011807,
#  'Marvel Girl / Jean Grey': 0.42312526183493926,
#  'Cyclops / Scott Summer': 0.3353361649228219,
#  'Klaw / Ulysses Klaw': 0.7071977638015374,
#  'Human Torch / Johnny S': 0.3390544041450777,
#  'Richards, Franklin B': 0.5838509316770186,
#  'Wolverine / Logan': 0.2975508509755085,
#  'Firebird / Bonita Juar': 0.914651493598862,
#  'Mr. Fantastic / Reed R': 0.3174383428190535,
#  'Medusa / Medusalith Am': 0.8318367346938775,
#  'Dr. Strange / Stephen': 0.4581560283687943,
#  'Jack Of Hearts / Jack': 0.7773279352226721,
#  'Mephisto': 0.5948051948051948,
#  'Thanos': 0.7782217782217782,
#  'Swordsman / Jacques Du': 0.9047619047619048,
#  'Collector / Taneleer T': 0.903448275862069,
#  'Lockjaw [inhuman]': 0.8737373737373737,
#  'Sub-mariner / Namor Ma': 0.41337535703732886,
#  'Pharaoh Rama-tut': 0.7176470588235294,
#  'Ant-man Ii / Scott Har': 0.7192156862745098,
#  'Lyja Lazerfist [skru': 0.8044354838709677,
#  'Gorgon [inhuman]': 0.8847780126849895,
#  'Nighthawk Ii / Kyle Ri': 0.8508064516129032,
#  'Cage, Luke / Carl Luca': 0.6345848757271285,
#  'Colossus Ii / Peter Ra': 0.3509500512003641,
#  'Hellcat / Patsy Walker': 0.6758328926493918,
#  'Karnak [inhuman]': 0.8818181818181818,
#  'Death': 0.8372093023255814,
#  'Redwing': 0.7133333333333334,
#  'Daredevil / Matt Murdo': 0.4095785440613027,
#  'Norriss, Sister Barb': 0.6797814207650273,
#  'Rage / Elvin Daryl Hal': 0.8094357076780758,
#  'Starfox / Eros': 0.6415525114155252,
#  'Demolition Man / Denni': 0.8022988505747126,
#  'Sersi / Sylvia': 0.5739235170129479,
#  'Spider-man / Peter Parker': 0.276201750306515,
#  'Vision': 0.29550890247143236,
#  'Uatu': 0.6997892201144233,
#  'Binary / Carol Danvers': 0.5499316005471956,
#  'Gyrich, Henry Peter': 0.6632996632996633,
#  'Nightcrawler / Kurt Wa': 0.39606432923783835,
#  'Angel / Warren Kenneth': 0.39180050718512255,
#  'Silver Surfer / Norrin': 0.5265631676399374,
#  'She-hulk / Jennifer Wa': 0.37250047609979053,
#  'Ghaur [deviant]': 0.8157894736842105,
#  'Dr. Doom / Victor Von': 0.5186031746031746,
#  'Storm / Ororo Munroe S': 0.3464216095795043,
#  'Scarlet Witch / Wanda': 0.33203354521660167,
#  'Toad / Mortimer Toynbe': 0.7638691322901849,
#  'Hulk / Dr. Robert Bruce Banner': 0.3633052030842086,
#  'Firestar / Angelica Jo': 0.6493284493284494,
#  'Wonder Man / Simon Wil': 0.4201863354037267,
#  'Drax / Arthur Douglas': 0.8313513513513513,
#  'Dugan, Timothy Aloyi': 0.7313829787234043,
#  'Carter, Sharon': 0.8,
#  'Black Knight V / Dane': 0.46707193515704154,
#  'Sunfire / Shiro Yoshid': 0.7474509803921568,
#  'Triton': 0.8620199146514936,
#  'Ultron': 0.8288084464555053,
#  'Jones, Richard Milho': 0.7191316146540027,
#  'Iron Man / Tony Stark': 0.2918109544944642,
#  'Nelson, Franklin Fog': 0.5448717948717948,
#  'Captain America': 0.23792718607667482,
#  'Jarvis, Edwin': 0.4098986285032797,
#  'Quasar Iii / Wendell V': 0.5221935483870968,
#  'Jameson, J. Jonah': 0.4670109007458405,
#  'Masters, Alicia Reis': 0.8064125831820932,
#  'Magneto / Magnus / Eric': 0.446944879646774,
#  'Invisible Woman / Sue': 0.33000264340470525,
#  'Professor X / Charles': 0.3572855464159812,
#  'Iron Fist / Daniel Ran': 0.6811688311688312,
#  'Black Bolt / Blackanto': 0.8974630021141649,
#  'Hawk': 0.35976331360946745,
#  'Sandman / William Bake': 0.7064935064935065,
#  'Falcon / Sam Wilson': 0.5834767641996558,
#  'Stingray / Dr. Walter': 0.817923186344239,
#  'Justice Ii / Vance Ast': 0.7448979591836735,
#  'Hercules [greek God]': 0.3804609563123495,
#  'Usagent / Captain John': 0.6610565684899485,
#  'Captain Marvel Ii / Mo': 0.5529139490847885,
#  'Crystal [inhuman]': 0.5865548827821767,
#  'Tigra / Greer Nelson': 0.6843156843156843,
#  'Spider-woman Ii / Juli': 0.6626716604244695,
#  'Machine Man / X-51': 0.9014396456256921,
#  'Mockingbird / Dr. Barb': 0.7398202009518773,
#  'Captain Marvel / Capta': 0.8468468468468469,
#  'Wasp / Janet Van Dyne': 0.33775173512344975,
#  'Fury, Col. Nicholas': 0.4903897019925939,
#  'Thor / Dr. Donald Blak': 0.284026781444285,
#  'Quicksilver / Pietro M': 0.4110341533317411,
#  'Captain Britain / Bria': 0.7315010570824524,
#  'Shadowcat / Katherine': 0.46918457648546147,
#  'Black Widow / Natasha': 0.43658559314136614,
#  'Ant-man / Dr. Henry J.': 0.38839657653563586,
#  'Moon Knight / Marc Spe': 0.7399829497016198,
#  'Jocasta': 0.9002849002849003,
#  'Moondragon / Heather D': 0.6476299257567104,
#  'Thing / Benjamin J. Gr': 0.3013031459786758,
#  'Beast / Henry &hank& P': 0.31850789096126253,
#  'Nova / Richard Rider': 0.6226917951646678,
#  'Wrecker Iii / Dirk Gar': 0.7176799440950384,
#  'Warlock Ii / Adam Warl': 0.8241441441441442,
#  'Piledriver Ii / Brian': 0.7891156462585034,
#  'Thunderball / Dr. Elio': 0.7016835016835017,
#  'Dr. Octopus / Otto Oct': 0.62531328320802,
#  'Banner, Betty Ross T': 0.8723723723723724,
#  'Avalanche / Dominic Pe': 0.7705802968960864,
#  'Attuma': 0.8804347826086957,
#  'Hela [asgardian]': 0.5284090909090909,
#  'Doc Samson / Dr. Leona': 0.8782051282051282,
#  'Guardian / James Macdo': 0.8636363636363636,
#  'Northstar / Jean-paul': 0.7911884487226953,
#  'Dr. Druid / Anthony Lu': 0.8350100603621731,
#  'Watson-parker, Mary': 0.4869933454325469,
#  'Mystique / Raven Darkh': 0.6454930429522081,
#  'Pyro / Allerdyce Johnn': 0.714975845410628,
#  'Destiny Ii / Irene Adl': 0.7916666666666666,
#  'Mister Hyde / Calvin Z': 0.6847826086956522,
#  'Ghost Rider Ii / Johnn': 0.7948717948717948,
#  'Mole Man / Harvey Rupe': 0.9142857142857143,
#  'Firelord / Pyreus Kril': 0.8571428571428571,
#  'Leader / Sam Sterns': 1.0,
#  'Le Fey, Morgan': 0.9215686274509803,
#  'Bulldozer / Henry Camp': 0.7891156462585034,
#  'Forgotten One / Gilgam': 0.8201058201058201,
#  'Balder [asgardian]': 0.678030303030303,
#  'Hogun [asgardian]': 0.5697674418604651,
#  'Hellstorm / Daimon Hel': 0.9021164021164021,
#  'Aurora / Jeanne-marie': 0.8282485875706215,
#  "O'brien, Michael": 0.7789661319073083,
#  'Stankowicz, Fabian': 0.8633333333333333,
#  'Screaming Mimi / Melis': 0.7632183908045977,
#  'Moonstone Ii / Karla S': 0.7128205128205128,
#  'Fixer Ii / Paul Norber': 0.7112299465240641,
#  'Darkstar / Laynia Serg': 0.8891129032258065,
#  'Vanguard / Nicolai Kry': 0.9166666666666666,
#  'Gamora': 0.9216832261835184,
#  'Psylocke / Elisabeth B': 0.4909784871616933,
#  'Rogue  / ': 0.3906029867568329,
#  'Sasquatch / Walter Lan': 0.7179135209334249,
#  'Luna / Luna Maximoff [': 0.8793103448275862,
#  'Whizzer Ii / Stanley S': 0.9142857142857143,
#  'Dr. Spectrum / Joseph': 0.9142857142857143,
#  'Kingpin / Wilson Fisk': 0.4592198581560284,
#  'Clea': 0.9,
#  'Polaris / Lorna Dane': 0.5446355446355446,
#  'De La Fontaine, Cont': 0.7532467532467533,
#  'Heimdall [asgardian]': 0.8354978354978355,
#  'Red Skull / Johann Sch': 0.6102418207681366,
#  'Thompson, Eugene Fla': 0.5888501742160279,
#  'Wong': 0.886021505376344,
#  'Parker, May': 0.5991140642303433,
#  'Green Goblin / Norman': 0.8181818181818182,
#  'Night Thrasher / Duane': 0.7753846153846153,
#  'Eternity / Adam Qadmon': 0.8868852459016393,
#  'Galactus / Galan': 0.6574794866400169,
#  'Triathlon / Delroy Gar': 0.8835978835978836,
#  'Beetle / Abner Ronald': 0.6656565656565656,
#  'Lilandra Neramani [s': 0.6398809523809523,
#  'Odin [asgardian]': 0.5863636363636363,
#  'Hogan, Virginia Pepp': 0.9416666666666667,
#  'Mad Dog / Colonel Buzz': 0.7904761904761904,
#  'Kincaid, Dr. Jane Fo': 0.6587301587301587,
#  'Wizard / Bentley Wittm': 0.7610837438423645,
#  'Charcoal / Charlie Bur': 0.7857142857142857,
#  'Blob / Fred J. Dukes': 0.6287678476996298,
#  'Cloak / Tyrone Johnson': 0.5942028985507246,
#  'Thunderstrike / Eric K': 0.6219193427931292,
#  'Power Man / Erik Joste': 0.6736353077816493,
#  'Human Torch Android / ': 0.7428571428571429,
#  'Juggernaut / Cain Mark': 0.8022988505747126,
#  'Absorbing Man / Carl C': 0.7398190045248869,
#  'Volstagg': 0.5682926829268292,
#  'Shaman / Michael Twoyo': 0.7881081081081082,
#  'Snowbird / Narya / Anne': 0.8758620689655172,
#  'Dagger / Tandy Bowen': 0.6724137931034483,
#  'Phoenix Iii / Rachel S': 0.623340321453529,
#  'Mandarin': 0.7662337662337663,
#  'Fandral [asgardian]': 0.5515151515151515,
#  'Ms. Marvel Ii / Sharon': 0.8153846153846154,
#  'Pip / Prince Gofern': 0.8864406779661017,
#  'Enchantress / Amora / He': 0.624467178175618,
#  'Jameson, Col. John': 0.5206349206349207,
#  'Cooper, Dr. Valerie': 0.5842650103519669,
#  'Nova Ii / Frankie Raye': 0.874451273046532,
#  'Darkhawk / Chris Powel': 0.7788819875776397,
#  'Nomad Iii / Jack Monro': 0.6061538461538462,
#  'Robertson, Joe': 0.5561224489795918,
#  'Gargoyle Ii / Isaac Ch': 0.8243243243243243,
#  'Namorita / Nita Prenti': 0.6638616175783076,
#  'Iron Man Iv / James R.': 0.7307692307692307,
#  'Ross, Gen. Thaddeus': 0.9458128078817734,
#  'Harkness, Agatha': 0.8171565276828435,
#  'Carter, Peggy': 0.6504201680672269,
#  'Hyperion': 0.8421052631578947,
#  'Living Lightning / Mig': 0.7901504787961696,
#  'Jones, Gabe': 0.8042328042328042,
#  'Osborn, Liz Allan': 0.6415362731152204,
#  'Leeds, Betty Brant': 0.6195121951219512,
#  'Sif': 0.631578947368421,
#  'Dazzler Ii / Allison B': 0.7315233785822021,
#  'Molecule Man / Owen Re': 0.9371794871794872,
#  'Speedball / Robbie Bal': 0.7734107997265892,
#  'Lizard / Dr. Curtis Co': 0.6897163120567376,
#  'Volcana / Marsha Rosen': 0.9761904761904762,
#  'Lockheed': 0.649795918367347,
#  'Titania Ii / Mary Skee': 0.8283499446290143,
#  'Boomer / Tabitha Smith': 0.6088578088578088,
#  'Summers, Nathan Chri': 0.5468704084631207,
#  'Summers, Madelyne Ma': 0.7867867867867868,
#  'Mactaggert, Moira Ki': 0.5534465534465535,
#  'Cannonball Ii / Sam Gu': 0.4190158465387823,
#  'Tilby, Trish / Patrici': 0.8011363636363636,
#  'Skids / Sally Blevins': 0.7479838709677419,
#  'Wolfsbane / Rahne Sinc': 0.4700149925037481,
#  'Leech': 0.6587301587301587,
#  'Mirage Ii / Danielle M': 0.5486993345432547,
#  'Gambit / Remy Lebeau': 0.518732782369146,
#  'Jubilee / Jubilation L': 0.6528345996493279,
#  'Strong Guy / Guido Car': 0.652875175315568,
#  'Spiral': 0.8078817733990148,
#  'Banshee / Sean Cassidy': 0.5630861040068201,
#  'Legion Ii / David Hall': 0.9285714285714286,
#  'Havok / Alex Summers': 0.5106215578284815,
#  'Longshot': 0.8522727272727273,
#  'Forge': 0.6339421613394216,
#  'Sabretooth / Victor Cr': 0.8448717948717949,
#  'Maddicks, Arthur Art': 0.6923076923076923,
#  'Warlock Iii': 0.6019871420222093,
#  'Rictor / Julio Esteban': 0.6915820029027576,
#  'Sunspot / Roberto Daco': 0.5079795242396868,
#  'Firefist / Rusty Colli': 0.6733870967741935,
#  'Bishop  / ': 0.6435469710272168,
#  'Daytripper / Amanda Se': 0.86,
#  'Wild Child / Kyle Gibn': 0.8272727272727273,
#  'Thunderbird Ii / James': 0.6458211572180012,
#  'Sauron / Dr. Karl Lyko': 0.89,
#  'Siryn / Theresa Rourke': 0.7002902757619739,
#  'Shatterstar Ii / Gavee': 0.7921022067363531,
#  'Marrow / Sarah': 0.803030303030303,
#  'Feral / Maria Callasan': 0.8174603174603174,
#  'Callisto': 0.8603988603988604,
#  'Mr. Sinister / Nathan': 0.9080459770114943,
#  'Raza Longknife': 0.8783068783068783,
#  'Spider-woman / Jessica': 0.8528735632183908,
#  'Cypher / Doug Ramsey': 0.7182926829268292,
#  "Deathbird [shi'ar]": 0.7857142857142857,
#  'Hudson, Heather': 0.7603131586871424,
#  'Stryfe': 0.9233511586452763,
#  'Iron Man Doppelgange': 0.996135265700483,
#  'Puck / Eugene Milton J': 0.7617656604998377,
#  'Silhouette': 0.8722689075630252,
#  'Cortez, Fabian': 0.9,
#  'Black King / Sebastian': 0.864516129032258,
#  'Magik / Illyana Rasput': 0.7378048780487805,
#  'Zabu': 0.7633333333333333,
#  'Domino Iii / Beatrice / ': 0.8297101449275363,
#  'Caliban / ': 0.7402439024390244,
#  'Apocalypse / En Sabah': 0.6772727272727272,
#  'Hunter, Stevie': 0.8364153627311522,
#  'Corsair': 0.8168067226890756,
#  "Ch'od": 0.8666666666666667,
#  "Mam'selle Hepzibah": 0.8689655172413793,
#  'Zero': 0.9268817204301075,
#  'X-man / Nathan Grey': 0.8666666666666667,
#  "Karma / Xi'an Coy Manh": 0.8152709359605911,
#  'Mr. Fantastic Doppel': 0.9804421768707483,
#  'Beyonder': 0.765079365079365,
#  'Multiple Man / James A': 0.7045614035087719,
#  'Colossus Ii Doppelga': 1.0,
#  'Scanner Ii': 0.8128654970760234,
#  'Ka-zar / Kevin Plunder': 0.7916666666666666,
#  'White Queen / Emma Fro': 0.658974358974359,
#  'Magma / Amara Aquilla / ': 0.8809523809523809,
#  'Thanos Doppelganger': 0.9224043715846995,
#  'Magus': 0.8798904538341158,
#  'Knight, Misty': 0.7378917378917379,
#  'Wing, Colleen': 0.803030303030303,
#  'Puppet Master / Philli': 0.91,
#  'Maximus [inhuman]': 0.9736842105263158,
#  'Punisher Ii / Frank Ca': 0.47368421052631576,
#  'Zeus': 0.7862318840579711,
#  'Box Iv / Madison Jeffr': 0.8210526315789474,
#  'Thena': 0.6883116883116883,
#  'Black Cat / Felicia Ha': 0.6650246305418719,
#  'Gee / Alex Power': 0.5324675324675324,
#  'Spider-man Clone / Ben': 0.6491228070175439,
#  'Ulik': 0.7485380116959064,
#  'Citizen V Ii / Helmut': 0.6129032258064516,
#  'High Evolutionary / He': 0.5353658536585366,
#  'Hobgoblin V / Jason Ph': 0.6553846153846153,
#  'Ghost Rider Iii / Dan': 0.6491228070175439,
#  'Cushing, Kate': 0.8853754940711462,
#  'Katzenberg, Nick': 0.9157894736842105,
#  'Vizier': 0.8221343873517787,
#  'Tombstone / Lonnie Tho': 0.7333333333333333,
#  'Mercado, Joy': 0.9095238095238095,
#  'Hammerhead': 0.8070175438596491,
#  'Arranger / ': 0.8947368421052632,
#  'Osborn, Harry': 0.7698412698412699,
#  'Cobra / Klaus Vorhees': 0.5333333333333333,
#  'Leeds, Ned': 0.8260869565217391,
#  'Watson, Anna': 0.7661538461538462,
#  'Urich, Ben': 0.6471471471471472,
#  'Robertson, Randy': 0.8614718614718615,
#  'Page, Karen': 0.8083333333333333,
#  'Grant, Gloria Glory': 0.7804232804232805,
#  'Lubenski, Nate': 0.9473684210526315,
#  'Ikaris / Ike Harris [e': 0.8382352941176471,
#  'Rosenthal, Bernie': 0.6333333333333333,
#  'Gladiator Ii': 0.8458498023715415,
#  'Beta Ray Bill': 0.6811594202898551,
#  'Bridge, George Washi': 0.39826839826839827,
#  'Diamond Lil / Lillian': 0.8901098901098901,
#  'Asp Ii / Cleo': 0.9642857142857143,
#  'Black Mamba / Tanya Se': 0.9642857142857143,
#  'Meggan': 0.8904761904761904,
#  'Austin, Susan': 0.8970588235294118,
#  'Diamondback Ii / Rache': 0.631578947368421,
#  'Makkari / Mike Khary / I': 0.6,
#  'Hodge, Cameron': 0.8575498575498576,
#  'Skin / Angelo Espinosa': 0.7912087912087912,
#  'Husk / Paige Guthrie': 0.775,
#  'Deadpool / Jack / Wade W': 0.782051282051282}

# %%
# Find the average clustering coefficient
nx.average_clustering(M)
# Out:
# 0.7047201786696375

# %% [markdown]
# ## Bridges

# %%
# List a network's bridges
list(nx.bridges(M))
# Out:
# []

# %%
# Test if a network has any bridges
nx.has_bridges(M)
# Out:
# False

# %%
# List a network's local bridges
list(nx.local_bridges(M))
# Out:
# [('Death', 'Deadpool / Jack / Wade W', 3)]

# %% [markdown]
# ## Neighbors

# %%
# Find a node's neighbors
list(nx.neighbors(M, 'Death'))
# Out:
# ["Black Panther / T'chal",
#  'Iron Man / Tony Stark',
#  'Sub-mariner / Namor Ma',
#  'Nova / Richard Rider',
#  'Hulk / Dr. Robert Bruce Banner',
#  'Spider-man / Peter Parker',
#  'Wasp / Janet Van Dyne',
#  'Galactus / Galan',
#  'Silver Surfer / Norrin',
#  'Hawk',
#  'Scarlet Witch / Wanda',
#  'Uatu',
#  'Captain America',
#  'Thunderstrike / Eric K',
#  'Wonder Man / Simon Wil',
#  'Wolverine / Logan',
#  'She-hulk / Jennifer Wa',
#  'Vision',
#  'Storm / Ororo Munroe S',
#  'Eternity / Adam Qadmon',
#  'Quasar Iii / Wendell V',
#  'Black Widow / Natasha',
#  'Firelord / Pyreus Kril',
#  'Thor / Dr. Donald Blak',
#  'Richards, Franklin B',
#  'Deadpool / Jack / Wade W',
#  'Mephisto',
#  'Dr. Doom / Victor Von',
#  'Thing / Benjamin J. Gr',
#  'Gamora',
#  'Drax / Arthur Douglas',
#  'Nova Ii / Frankie Raye',
#  'Ant-man / Dr. Henry J.',
#  'Moondragon / Heather D',
#  'Pip / Prince Gofern',
#  'Thanos',
#  'Collector / Taneleer T',
#  'Captain Marvel / Capta',
#  'Warlock Ii / Adam Warl',
#  'Dr. Strange / Stephen',
#  'Starfox / Eros',
#  'Invisible Woman / Sue',
#  'Cyclops / Scott Summer']

# %%
# Find common neighbors of a node pair
list(nx.common_neighbors(M, 'Death', 'Thanos'))
# Out:
# ["Black Panther / T'chal",
#  'Iron Man / Tony Stark',
#  'Sub-mariner / Namor Ma',
#  'Nova / Richard Rider',
#  'Hulk / Dr. Robert Bruce Banner',
#  'Spider-man / Peter Parker',
#  'Galactus / Galan',
#  'Silver Surfer / Norrin',
#  'Hawk',
#  'Scarlet Witch / Wanda',
#  'Uatu',
#  'Captain America',
#  'Thunderstrike / Eric K',
#  'Wonder Man / Simon Wil',
#  'Wolverine / Logan',
#  'She-hulk / Jennifer Wa',
#  'Vision',
#  'Storm / Ororo Munroe S',
#  'Eternity / Adam Qadmon',
#  'Quasar Iii / Wendell V',
#  'Black Widow / Natasha',
#  'Firelord / Pyreus Kril',
#  'Thor / Dr. Donald Blak',
#  'Mephisto',
#  'Dr. Doom / Victor Von',
#  'Thing / Benjamin J. Gr',
#  'Gamora',
#  'Drax / Arthur Douglas',
#  'Nova Ii / Frankie Raye',
#  'Ant-man / Dr. Henry J.',
#  'Moondragon / Heather D',
#  'Pip / Prince Gofern',
#  'Captain Marvel / Capta',
#  'Warlock Ii / Adam Warl',
#  'Dr. Strange / Stephen',
#  'Starfox / Eros',
#  'Invisible Woman / Sue',
#  'Cyclops / Scott Summer']

# %% [markdown]
# ## Cycles/Loops

# %%
# Get a list of the basis of all cycle in the graph
# All larger cycles are based on these cycles, many of which are triangles
nx.cycle_basis(M)
# Out:
# [["Black Panther / T'chal", 'Triton', 'Black Bolt / Blackanto'],
#  ['Iron Man / Tony Stark', 'Triton', 'Black Bolt / Blackanto'],
#  ['Sub-mariner / Namor Ma', 'Triton', 'Black Bolt / Blackanto'],
#  ['Hulk / Dr. Robert Bruce Banner', 'Triton', 'Black Bolt / Blackanto'],
#  ['Spider-man / Peter Parker', 'Triton', 'Black Bolt / Blackanto'],
#  ['Wasp / Janet Van Dyne', 'Triton', 'Black Bolt / Blackanto'],
#  ['Silver Surfer / Norrin', 'Triton', 'Black Bolt / Blackanto'],
#  ['Hawk', 'Triton', 'Black Bolt / Blackanto'],
#  ['Scarlet Witch / Wanda', 'Triton', 'Black Bolt / Blackanto'],
#  ['Quicksilver / Pietro M', 'Triton', 'Black Bolt / Blackanto'],
#  ['Uatu', 'Triton', 'Black Bolt / Blackanto'],
#  ['Captain America', 'Triton', 'Black Bolt / Blackanto'],
#  ['Wolverine / Logan', 'Triton', 'Black Bolt / Blackanto'],
#  ['She-hulk / Jennifer Wa', 'Triton', 'Black Bolt / Blackanto'],
#  ['Vision', 'Triton', 'Black Bolt / Blackanto'],
#  ['Mr. Fantastic / Reed R', 'Triton', 'Black Bolt / Blackanto'],
#  ['Thing / Benjamin J. Gr', 'Triton', 'Black Bolt / Blackanto'],
#  ['Invisible Woman / Sue', 'Triton', 'Black Bolt / Blackanto'],
#  ['Beast / Henry &hank& P', 'Triton', 'Black Bolt / Blackanto'],
#  ['Thor / Dr. Donald Blak', 'Triton', 'Black Bolt / Blackanto'],
#  ['Dr. Strange / Stephen', 'Triton', 'Black Bolt / Blackanto'],
#  ['Gorgon [inhuman]', 'Triton', 'Black Bolt / Blackanto'],
#  ['Lockjaw [inhuman]', 'Triton', 'Black Bolt / Blackanto'],
#  ['Crystal [inhuman]', 'Triton', 'Black Bolt / Blackanto'],
#  ['Medusa / Medusalith Am', 'Triton', 'Black Bolt / Blackanto'],
#  ['Fury, Col. Nicholas', 'Triton', 'Black Bolt / Blackanto'],
#  ['Maximus [inhuman]', 'Triton', 'Black Bolt / Blackanto'],
#  ['Karnak [inhuman]', 'Triton', 'Black Bolt / Blackanto'],
#  ['Luna / Luna Maximoff [', 'Triton', 'Black Bolt / Blackanto'],
#  ['Masters, Alicia Reis', 'Triton', 'Black Bolt / Blackanto'],
#  ['Human Torch / Johnny S', 'Triton', 'Black Bolt / Blackanto'],
#  ['Dr. Doom / Victor Von', 'Triton', 'Black Bolt / Blackanto'],
#  ['Sandman / William Bake', 'Triton', 'Black Bolt / Blackanto'],
#  ['Richards, Franklin B', 'Triton', 'Black Bolt / Blackanto'],
#  ["Black Panther / T'chal", 'Jones, Richard Milho', 'Triton'],
#  ['Iron Man / Tony Stark', 'Jones, Richard Milho', 'Triton'],
#  ['Sub-mariner / Namor Ma', 'Jones, Richard Milho', 'Triton'],
#  ['Hulk / Dr. Robert Bruce Banner', 'Jones, Richard Milho', 'Triton'],
#  ['Spider-man / Peter Parker', 'Jones, Richard Milho', 'Triton'],
#  ['Wasp / Janet Van Dyne', 'Jones, Richard Milho', 'Triton'],
#  ['Silver Surfer / Norrin', 'Jones, Richard Milho', 'Triton'],
#  ['Hawk', 'Jones, Richard Milho', 'Triton'],
#  ['Scarlet Witch / Wanda', 'Jones, Richard Milho', 'Triton'],
#  ['Quicksilver / Pietro M', 'Jones, Richard Milho', 'Triton'],
#  ['Uatu', 'Jones, Richard Milho', 'Triton'],
#  ['Captain America', 'Jones, Richard Milho', 'Triton'],
#  ['Wonder Man / Simon Wil',
#   'Jones, Richard Milho',
#   'Triton',
#   'Black Bolt / Blackanto'],
#  ['Wolverine / Logan', 'Jones, Richard Milho', 'Triton'],
#  ['She-hulk / Jennifer Wa', 'Jones, Richard Milho', 'Triton'],
#  ['Vision', 'Jones, Richard Milho', 'Triton'],
#  ['Mr. Fantastic / Reed R', 'Jones, Richard Milho', 'Triton'],
#  ['Angel / Warren Kenneth',
#   'Jones, Richard Milho',
#   'Triton',
#   'Black Bolt / Blackanto'],
#  ['Thing / Benjamin J. Gr', 'Jones, Richard Milho', 'Triton'],
#  ['Invisible Woman / Sue', 'Jones, Richard Milho', 'Triton'],
#  ['Beast / Henry &hank& P', 'Jones, Richard Milho', 'Triton'],
#  ['Cyclops / Scott Summer',
#   'Jones, Richard Milho',
#   'Triton',
#   'Black Bolt / Blackanto'],
#  ['Thor / Dr. Donald Blak', 'Jones, Richard Milho', 'Triton'],
#  ['Dr. Strange / Stephen', 'Jones, Richard Milho', 'Triton'],
#  ['Iceman / Robert Bobby',
#   'Jones, Richard Milho',
#   'Triton',
#   'Black Bolt / Blackanto'],
#  ['Human Torch / Johnny S', 'Jones, Richard Milho', 'Triton'],
#  ['Ant-man / Dr. Henry J.',
#   'Jones, Richard Milho',
#   'Triton',
#   'Black Bolt / Blackanto'],
#  ['Black Widow / Natasha',
#   'Jones, Richard Milho',
#   'Triton',
#   'Black Bolt / Blackanto'],
#  ['Daredevil / Matt Murdo',
#   'Jones, Richard Milho',
#   'Triton',
#   'Black Bolt / Blackanto'],
#  ['Fury, Col. Nicholas', 'Jones, Richard Milho', 'Triton'],
#  ['Ant-man Ii / Scott Har',
#   'Jones, Richard Milho',
#   'Triton',
#   'Black Bolt / Blackanto'],
#  ['Medusa / Medusalith Am', 'Jones, Richard Milho', 'Triton'],
#  ["Black Panther / T'chal", 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Iron Man / Tony Stark', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Sub-mariner / Namor Ma', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Black Knight V / Dane',
#   'Jones, Richard Milho'],
#  ['Spider-man / Peter Parker',
#   'Black Knight V / Dane',
#   'Jones, Richard Milho'],
#  ['Tigra / Greer Nelson', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Wasp / Janet Van Dyne', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Mockingbird / Dr. Barb', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Silver Surfer / Norrin', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Hawk', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Scarlet Witch / Wanda', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Quicksilver / Pietro M', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Uatu', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Captain America', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Wonder Man / Simon Wil', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Wolverine / Logan', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['She-hulk / Jennifer Wa', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Vision', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Marvel Girl / Jean Grey', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Mr. Fantastic / Reed R', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Angel / Warren Kenneth', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Thing / Benjamin J. Gr', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Invisible Woman / Sue', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Beast / Henry &hank& P', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Cyclops / Scott Summer', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Enchantress / Amora / He', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Thor / Dr. Donald Blak', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Dr. Strange / Stephen', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Norriss, Sister Barb', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Lockjaw [inhuman]',
#   'Black Knight V / Dane',
#   'Jones, Richard Milho',
#   'Triton'],
#  ['Crystal [inhuman]',
#   'Black Knight V / Dane',
#   'Jones, Richard Milho',
#   'Triton'],
#  ['Professor X / Charles', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Iceman / Robert Bobby', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Moondragon / Heather D', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Human Torch / Johnny S', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Colossus Ii / Peter Ra', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Jarvis, Edwin', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Ant-man / Dr. Henry J.', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Hercules [greek God]', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Black Widow / Natasha', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Drax / Arthur Douglas', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Sandman / William Bake',
#   'Black Knight V / Dane',
#   'Jones, Richard Milho',
#   'Triton'],
#  ['Richards, Franklin B',
#   'Black Knight V / Dane',
#   'Jones, Richard Milho',
#   'Triton'],
#  ['Daredevil / Matt Murdo', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Dr. Doom / Victor Von',
#   'Black Knight V / Dane',
#   'Jones, Richard Milho',
#   'Triton'],
#  ['Thanos', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Starfox / Eros', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Fury, Col. Nicholas', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Ant-man Ii / Scott Har', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Forge', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Quasar Iii / Wendell V', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Captain Marvel Ii / Mo', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['Binary / Carol Danvers', 'Black Knight V / Dane', 'Jones, Richard Milho'],
#  ['

#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy'],
#  ['Stryfe', 'Apocalypse / En Sabah', 'Bishop  / '],
#  ['Mactaggert, Moira Ki', 'Apocalypse / En Sabah', 'Bishop  / '],
#  ['X-man / Nathan Grey', 'Apocalypse / En Sabah', 'Bishop  / '],
#  ['Sunfire / Shiro Yoshid', 'Apocalypse / En Sabah', 'Bishop  / '],
#  ['Zero', 'Apocalypse / En Sabah', 'Bishop  / '],
#  ['Rictor / Julio Esteban', 'Apocalypse / En Sabah', 'Bishop  / '],
#  ['Multiple Man / James A', 'Apocalypse / En Sabah', 'Bishop  / '],
#  ['Leech', 'Apocalypse / En Sabah', 'Bishop  / ', 'Banshee / Sean Cassidy'],
#  ['Caliban / ', 'Apocalypse / En Sabah', 'Bishop  / '],
#  ['Thunderbird Ii / James', 'Apocalypse / En Sabah', 'Bishop  / '],
#  ['Boomer / Tabitha Smith', 'Apocalypse / En Sabah', 'Bishop  / '],
#  ['Siryn / Theresa Rourke', 'Apocalypse / En Sabah', 'Bishop  / '],
#  ['Maddicks, Arthur Art',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy'],
#  ['Sabretooth / Victor Cr', 'Apocalypse / En Sabah', 'Bishop  / '],
#  ['Mystique / Raven Darkh',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / '],
#  ['Marvel Girl / Jean Grey', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Angel / Warren Kenneth', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Beast / Henry &hank& P', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Cyclops / Scott Summer', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Professor X / Charles', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Iceman / Robert Bobby', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Colossus Ii / Peter Ra', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Summers, Nathan Chri', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Tilby, Trish / Patrici', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Wolfsbane / Rahne Sinc',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / '],
#  ['Warlock Iii',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy'],
#  ['Sunspot / Roberto Daco', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Magneto / Magnus / Eric', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Cannonball Ii / Sam Gu', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Mirage Ii / Danielle M',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy'],
#  ['Firefist / Rusty Colli', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Rictor / Julio Esteban', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Hodge, Cameron', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Caliban / ', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Leech', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Maddicks, Arthur Art', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Boomer / Tabitha Smith', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Thunderbird Ii / James', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Zero', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Stryfe', 'Skids / Sally Blevins', 'Apocalypse / En Sabah'],
#  ['Iron Man / Tony Stark',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah'],
#  ['Hawk',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / '],
#  ['Scarlet Witch / Wanda',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / '],
#  ['Captain America',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah'],
#  ['Mr. Fantastic / Reed R',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah'],
#  ['Invisible Woman / Sue',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah'],
#  ['Enchantress / Amora / He',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Loki [asgardian]',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Thor / Dr. Donald Blak',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah'],
#  ['Norriss, Sister Barb',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Wolfsbane / Rahne Sinc', 'Hela [asgardian]', 'Skids / Sally Blevins'],
#  ['Warlock Iii', 'Hela [asgardian]', 'Skids / Sally Blevins'],
#  ['Sunspot / Roberto Daco', 'Hela [asgardian]', 'Skids / Sally Blevins'],
#  ['Cannonball Ii / Sam Gu', 'Hela [asgardian]', 'Skids / Sally Blevins'],
#  ['Mirage Ii / Danielle M', 'Hela [asgardian]', 'Skids / Sally Blevins'],
#  ['Volstagg',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Hogun [asgardian]',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Fandral [asgardian]',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Sif',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Rictor / Julio Esteban', 'Hela [asgardian]', 'Skids / Sally Blevins'],
#  ['Kincaid, Dr. Jane Fo',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['High Evolutionary / He',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Boomer / Tabitha Smith', 'Hela [asgardian]', 'Skids / Sally Blevins'],
#  ['Firefist / Rusty Colli', 'Hela [asgardian]', 'Skids / Sally Blevins'],
#  ['Balder [asgardian]',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ["Black Panther / T'chal",
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Iron Man / Tony Stark', 'Mephisto', 'Hela [asgardian]'],
#  ['Sub-mariner / Namor Ma',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo'],
#  ['Hulk / Dr. Robert Bruce Banner', 'Mephisto', 'Hela [asgardian]'],
#  ['Spider-man / Peter Parker',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy'],
#  ['Galactus / Galan',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Mockingbird / Dr. Barb',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Silver Surfer / Norrin',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Hawk', 'Mephisto', 'Hela [asgardian]'],
#  ['Scarlet Witch / Wanda', 'Mephisto', 'Hela [asgardian]'],
#  ['Captain America', 'Mephisto', 'Hela [asgardian]'],
#  ['Thunderstrike / Eric K',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Wonder Man / Simon Wil',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie'],
#  ['Wolverine / Logan',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah'],
#  ['She-hulk / Jennifer Wa',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo'],
#  ['Vision',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah'],
#  ['Eternity / Adam Qadmon',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Mr. Fantastic / Reed R', 'Mephisto', 'Hela [asgardian]'],
#  ['Thing / Benjamin J. Gr',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah'],
#  ['Invisible Woman / Sue', 'Mephisto', 'Hela [asgardian]'],
#  ['Heimdall [asgardian]', 'Mephisto', 'Hela [asgardian]'],
#  ['Enchantress / Amora / He', 'Mephisto', 'Hela [asgardian]'],
#  ['Loki [asgardian]', 'Mephisto', 'Hela [asgardian]'],
#  ['Thor / Dr. Donald Blak', 'Mephisto', 'Hela [asgardian]'],
#  ['Dr. Strange / Stephen',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie'],
#  ['Hellcat / Patsy Walker', 'Mephisto', 'Hela [asgardian]'],
#  ['Norriss, Sister Barb', 'Mephisto', 'Hela [asgardian]'],
#  ['Gorgon [inhuman]',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane',
#   'Jones, Richard Milho',
#   'Triton'],
#  ['Karnak [inhuman]',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane',
#   'Jones, Richard Milho',
#   'Triton'],
#  ['Warlock Ii / Adam Warl',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie'],
#  ['Human Torch / Johnny S',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah'],
#  ['Drax / Arthur Douglas',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie'],
#  ['Volstagg', 'Mephisto', 'Hela [asgardian]'],
#  ['Hogun [asgardian]', 'Mephisto', 'Hela [asgardian]'],
#  ['Fandral [asgardian]', 'Mephisto', 'Hela [asgardian]'],
#  ['Vizier', 'Mephisto', 'Hela [asgardian]'],
#  ['Odin [asgardian]', 'Mephisto', 'Hela [asgardian]'],
#  ['Richards, Franklin B',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah'],
#  ['Daredevil / Matt Murdo',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie'],
#  ['Masters, Alicia Reis',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane',
#   'Jones, Richard Milho',
#   'Triton'],
#  ['Pip / Prince Gofern',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Dr. Doom / Victor Von',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie'],
#  ['Firelord / Pyreus Kril',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Thanos',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie'],
#  ['Starfox / Eros',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Sif', 'Mephisto', 'Hela [asgardian]'],
#  ['Quasar Iii / Wendell V',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo'],
#  ['Balder [asgardian]', 'Mephisto', 'Hela [asgardian]'],
#  ['Iron Man / Tony Stark', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Sub-mariner / Namor Ma', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Hulk / Dr. Robert Bruce Banner', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Spider-man / Peter Parker', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Tigra / Greer Nelson',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Mockingbird / Dr. Barb', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Silver Surfer / Norrin', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Hawk', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Scarlet Witch / Wanda', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Captain America', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Wonder Man / Simon Wil', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Vision', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Mr. Fantastic / Reed R', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Thing / Benjamin J. Gr', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Beast / Henry &hank& P',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins'],
#  ['Dr. Strange / Stephen', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Hellcat / Patsy Walker', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Nighthawk Ii / Kyle Ri', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Norriss, Sister Barb', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Gargoyle Ii / Isaac Ch',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane',
#   'Jones, Richard Milho'],
#  ['Human Torch / Johnny S', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Cage, Luke / Carl Luca',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Ant-man / Dr. Henry J.',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / '],
#  ['Wong', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Daredevil / Matt Murdo', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Iron Man / Tony Stark', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Sub-mariner / Namor Ma', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Hulk / Dr. Robert Bruce Banner', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Spider-man / Peter Parker', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Silver Surfer / Norrin', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Scarlet Witch / Wanda', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Wonder Man / Simon Wil', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Eternity / Adam Qadmon', 'Clea', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Beast / Henry &hank& P', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Dr. Strange / Stephen', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Hellcat / Patsy Walker', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Nighthawk Ii / Kyle Ri', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Norriss, Sister Barb', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Gargoyle Ii / Isaac Ch', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Cage, Luke / Carl Luca', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Ant-man / Dr. Henry J.', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Wong', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Daredevil / Matt Murdo', 'Clea', 'Hellstorm / Daimon Hel'],
#  ['Pip / Prince Gofern', 'Clea', 'Hellstorm / Daimon Hel', 'Mephisto'],
#  ['Iron Man / Tony Stark', 'Ghost Rider Ii / Johnn', 'Hellstorm / Daimon Hel'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel'],
#  ['Spider-man / Peter Parker',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel'],
#  ['Wasp / Janet Van Dyne',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / '],
#  ['Scarlet Witch / Wanda', 'Ghost Rider Ii / Johnn', 'Hellstorm / Daimon Hel'],
#  ['Captain America', 'Ghost Rider Ii / Johnn', 'Hellstorm / Daimon Hel'],
#  ['Vision', 'Ghost Rider Ii / Johnn', 'Hellstorm / Daimon Hel'],
#  ['Mr. Fantastic / Reed R',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel'],
#  ['Angel / Warren Kenneth',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins'],
#  ['Thing / Benjamin J. Gr',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel'],
#  ['Invisible Woman / Sue',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto'],
#  ['Beast / Henry &hank& P',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel'],
#  ['Ghost Rider Iii / Dan',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto'],
#  ['Thor / Dr. Donald Blak',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto'],
#  ['Dr. Strange / Stephen', 'Ghost Rider Ii / Johnn', 'Hellstorm / Daimon Hel'],
#  ['Norriss, Sister Barb', 'Ghost Rider Ii / Johnn', 'Hellstorm / Daimon Hel'],
#  ['Iceman / Robert Bobby',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins'],
#  ['Gargoyle Ii / Isaac Ch',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel'],
#  ['Human Torch / Johnny S',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel'],
#  ['Darkstar / Laynia Serg',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane',
#   'Jones, Richard Milho'],
#  ['Hercules [greek God]',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo'],
#  ['Daredevil / Matt Murdo',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel'],
#  ['Black Widow / Natasha',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo'],
#  ['Ant-man / Dr. Henry J.',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel'],
#  ['Spider-man / Peter Parker', 'Page, Karen', 'Ghost Rider Ii / Johnn'],
#  ['Captain America', 'Page, Karen', 'Ghost Rider Ii / Johnn'],
#  ['Mr. Fantastic / Reed R', 'Page, Karen', 'Ghost Rider Ii / Johnn'],
#  ['Thing / Benjamin J. Gr', 'Page, Karen', 'Ghost Rider Ii / Johnn'],
#  ['Invisible Woman / Sue', 'Page, Karen', 'Ghost Rider Ii / Johnn'],
#  ['Jameson, J. Jonah',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / '],
#  ['Human Torch / Johnny S', 'Page, Karen', 'Ghost Rider Ii / Johnn'],
#  ['Mister Hyde / Calvin Z',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Black Widow / Natasha', 'Page, Karen', 'Ghost Rider Ii / Johnn'],
#  ['Daredevil / Matt Murdo', 'Page, Karen', 'Ghost Rider Ii / Johnn'],
#  ["Black Panther / T'chal",
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto'],
#  ['Iron Man / Tony Stark',
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn'],
#  ['Sub-mariner / Namor Ma',
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel'],
#  ['Nova / Richard Rider',
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Firestar / Angelica Jo',
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
# ...
#  ['Quasar Iii / Wendell V', 'Jack Of Hearts / Jack', "O'brien, Michael"],
#  ['Captain Marvel Ii / Mo', 'Jack Of Hearts / Jack', "O'brien, Michael"],
#  ['Darkstar / Laynia Serg',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro',
#   'Beetle / Abner Ronald',
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn'],
#  ['Triathlon / Delroy Gar',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro',
#   'Beetle / Abner Ronald',
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Iron Fist / Daniel Ran',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro',
#   'Beetle / Abner Ronald'],
#  ['Doc Samson / Dr. Leona',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro',
#   'Beetle / Abner Ronald',
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Binary / Carol Danvers',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro',
#   'Beetle / Abner Ronald'],
#  ['Stingray / Dr. Walter',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro',
#   'Beetle / Abner Ronald',
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane'],
#  ['Falcon / Sam Wilson', 'Jack Of Hearts / Jack', "O'brien, Michael"],
#  ['Vanguard / Nicolai Kry', 'Jack Of Hearts / Jack', "O'brien, Michael"],
#  ['Iron Man / Tony Stark', 'Hyperion', 'Jack Of Hearts / Jack'],
#  ['Sub-mariner / Namor Ma',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael"],
#  ['Hulk / Dr. Robert Bruce Banner', 'Hyperion', 'Jack Of Hearts / Jack'],
#  ['Hawk', 'Hyperion', 'Jack Of Hearts / Jack', "O'brien, Michael"],
#  ['Scarlet Witch / Wanda', 'Hyperion', 'Jack Of Hearts / Jack'],
#  ['Captain America', 'Hyperion', 'Jack Of Hearts / Jack'],
#  ['Wonder Man / Simon Wil', 'Hyperion', 'Jack Of Hearts / Jack'],
#  ['Vision', 'Hyperion', 'Jack Of Hearts / Jack'],
#  ['Beast / Henry &hank& P',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro',
#   'Beetle / Abner Ronald',
#   'Nelson, Franklin Fog'],
#  ['Thor / Dr. Donald Blak', 'Hyperion', 'Jack Of Hearts / Jack'],
#  ['Dr. Strange / Stephen', 'Hyperion', 'Jack Of Hearts / Jack'],
#  ['Hellcat / Patsy Walker', 'Hyperion', 'Jack Of Hearts / Jack'],
#  ['Gargoyle Ii / Isaac Ch',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro',
#   'Beetle / Abner Ronald',
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn'],
#  ['Moondragon / Heather D', 'Hyperion', 'Jack Of Hearts / Jack'],
#  ['Makkari / Mike Khary / I', 'Hyperion', 'Jack Of Hearts / Jack'],
#  ['Quasar Iii / Wendell V', 'Hyperion', 'Jack Of Hearts / Jack'],
#  ['Iron Man / Tony Stark', 'Mad Dog / Colonel Buzz', 'Hyperion'],
#  ['Hulk / Dr. Robert Bruce Banner', 'Mad Dog / Colonel Buzz', 'Hyperion'],
#  ['Hawk', 'Mad Dog / Colonel Buzz', 'Hyperion'],
#  ['Scarlet Witch / Wanda', 'Mad Dog / Colonel Buzz', 'Hyperion'],
#  ['Captain America', 'Mad Dog / Colonel Buzz', 'Hyperion'],
#  ['Vision', 'Mad Dog / Colonel Buzz', 'Hyperion'],
#  ['Angel / Warren Kenneth',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro',
#   'Beetle / Abner Ronald',
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn'],
#  ['Beast / Henry &hank& P', 'Mad Dog / Colonel Buzz', 'Hyperion'],
#  ['Thor / Dr. Donald Blak', 'Mad Dog / Colonel Buzz', 'Hyperion'],
#  ['Hellcat / Patsy Walker', 'Mad Dog / Colonel Buzz', 'Hyperion'],
#  ['Norriss, Sister Barb',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack'],
#  ['Iceman / Robert Bobby',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro',
#   'Beetle / Abner Ronald',
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn'],
#  ['Gargoyle Ii / Isaac Ch', 'Mad Dog / Colonel Buzz', 'Hyperion'],
#  ['Moondragon / Heather D', 'Mad Dog / Colonel Buzz', 'Hyperion'],
#  ['Fury, Col. Nicholas',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael"],
#  ['Whizzer Ii / Stanley S', 'Mad Dog / Colonel Buzz', 'Hyperion'],
#  ['Dr. Spectrum / Joseph', 'Mad Dog / Colonel Buzz', 'Hyperion'],
#  ['Dugan, Timothy Aloyi',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro',
#   'Beetle / Abner Ronald',
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah',
#   'Bishop  / ',
#   'Banshee / Sean Cassidy',
#   'Guardian / James Macdo',
#   'Aurora / Jeanne-marie',
#   'Black Knight V / Dane',
#   'Jones, Richard Milho'],
#  ['Iron Man / Tony Stark', 'De La Fontaine, Cont', 'Mad Dog / Colonel Buzz'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'De La Fontaine, Cont',
#   'Mad Dog / Colonel Buzz'],
#  ['Spider-man / Peter Parker',
#   'De La Fontaine, Cont',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack'],
#  ['Captain America', 'De La Fontaine, Cont', 'Mad Dog / Colonel Buzz'],
#  ['Wolverine / Logan',
#   'De La Fontaine, Cont',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack'],
#  ['Vision', 'De La Fontaine, Cont', 'Mad Dog / Colonel Buzz'],
#  ['Mr. Fantastic / Reed R',
#   'De La Fontaine, Cont',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack'],
#  ['Thing / Benjamin J. Gr',
#   'De La Fontaine, Cont',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack'],
#  ['Carter, Sharon',
#   'De La Fontaine, Cont',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro'],
#  ['Thor / Dr. Donald Blak', 'De La Fontaine, Cont', 'Mad Dog / Colonel Buzz'],
#  ['Colossus Ii / Peter Ra',
#   'De La Fontaine, Cont',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack'],
#  ['Black Widow / Natasha',
#   'De La Fontaine, Cont',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael"],
#  ['Daredevil / Matt Murdo',
#   'De La Fontaine, Cont',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael"],
#  ['Red Skull / Johann Sch',
#   'De La Fontaine, Cont',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John'],
#  ['Fury, Col. Nicholas', 'De La Fontaine, Cont', 'Mad Dog / Colonel Buzz'],
#  ['Shadowcat / Katherine',
#   'De La Fontaine, Cont',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro',
#   'Beetle / Abner Ronald',
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins',
#   'Apocalypse / En Sabah'],
#  ['Dugan, Timothy Aloyi', 'De La Fontaine, Cont', 'Mad Dog / Colonel Buzz'],
#  ['Carter, Peggy',
#   'De La Fontaine, Cont',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael"],
#  ['Redwing',
#   'De La Fontaine, Cont',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro'],
#  ['Falcon / Sam Wilson',
#   'De La Fontaine, Cont',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack'],
#  ['Jones, Gabe', 'De La Fontaine, Cont', 'Mad Dog / Colonel Buzz'],
#  ['Iron Man / Tony Stark', 'Jones, Gabe', 'Mad Dog / Colonel Buzz'],
#  ['Hulk / Dr. Robert Bruce Banner', 'Jones, Gabe', 'Mad Dog / Colonel Buzz'],
#  ['Wasp / Janet Van Dyne',
#   'Jones, Gabe',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack'],
#  ['Hawk', 'Jones, Gabe', 'Mad Dog / Colonel Buzz'],
#  ['Scarlet Witch / Wanda', 'Jones, Gabe', 'Mad Dog / Colonel Buzz'],
#  ['Captain America', 'Jones, Gabe', 'Mad Dog / Colonel Buzz'],
#  ['Vision', 'Jones, Gabe', 'Mad Dog / Colonel Buzz'],
#  ['Marvel Girl / Jean Grey',
#   'Jones, Gabe',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro',
#   'Beetle / Abner Ronald',
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins'],
#  ['Angel / Warren Kenneth', 'Jones, Gabe', 'Mad Dog / Colonel Buzz'],
#  ['Thing / Benjamin J. Gr',
#   'Jones, Gabe',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack'],
#  ['Beast / Henry &hank& P', 'Jones, Gabe', 'Mad Dog / Colonel Buzz'],
#  ['Cyclops / Scott Summer',
#   'Jones, Gabe',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro',
#   'Beetle / Abner Ronald',
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins'],
#  ['Carter, Sharon',
#   'Jones, Gabe',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro'],
#  ['Thor / Dr. Donald Blak', 'Jones, Gabe', 'Mad Dog / Colonel Buzz'],
#  ['Dr. Strange / Stephen',
#   'Jones, Gabe',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion'],
#  ['Professor X / Charles',
#   'Jones, Gabe',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro',
#   'Beetle / Abner Ronald',
#   'Nelson, Franklin Fog',
#   'Page, Karen',
#   'Ghost Rider Ii / Johnn',
#   'Hellstorm / Daimon Hel',
#   'Mephisto',
#   'Hela [asgardian]',
#   'Skids / Sally Blevins'],
#  ['Iceman / Robert Bobby', 'Jones, Gabe', 'Mad Dog / Colonel Buzz'],
#  ['Human Torch / Johnny S',
#   'Jones, Gabe',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack'],
#  ['Ant-man / Dr. Henry J.',
#   'Jones, Gabe',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack'],
#  ['Daredevil / Matt Murdo',
#   'Jones, Gabe',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael"],
#  ['Red Skull / Johann Sch',
#   'Jones, Gabe',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John'],
#  ['Fury, Col. Nicholas', 'Jones, Gabe', 'Mad Dog / Colonel Buzz'],
#  ['Dugan, Timothy Aloyi', 'Jones, Gabe', 'Mad Dog / Colonel Buzz'],
#  ['Carter, Peggy',
#   'Jones, Gabe',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael"],
#  ['Falcon / Sam Wilson',
#   'Jones, Gabe',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack'],
#  ['Redwing',
#   'Jones, Gabe',
#   'Mad Dog / Colonel Buzz',
#   'Hyperion',
#   'Jack Of Hearts / Jack',
#   "O'brien, Michael",
#   'Jameson, Col. John',
#   'Spider-man Clone / Ben',
#   'Black Cat / Felicia Ha',
#   'Mercado, Joy',
#   'Katzenberg, Nick',
#   'Hammerhead',
#   'Nomad Iii / Jack Monro'],
#  ['Iron Man / Tony Stark', 'Dr. Spectrum / Joseph', 'Hyperion'],
#  ['Hawk', 'Dr. Spectrum / Joseph', 'Hyperion'],
#  ['Scarlet Witch / Wanda', 'Dr. Spectrum / Joseph', 'Hyperion'],
#  ['Captain America', 'Dr. Spectrum / Joseph', 'Hyperion'],
#  ['Vision', 'Dr. Spectrum / Joseph', 'Hyperion'],
#  ['Beast / Henry &hank& P', 'Dr. Spectrum / Joseph', 'Hyperion'],
#  ['Thor / Dr. Donald Blak', 'Dr. Spectrum / Joseph', 'Hyperion'],
#  ['Dr. Strange / Stephen', 'Dr. Spectrum / Joseph', 'Hyperion'],
#  ['Hellcat / Patsy Walker', 'Dr. Spectrum / Joseph', 'Hyperion'],
#  ['Moondragon / Heather D', 'Dr. Spectrum / Joseph', 'Hyperion'],
#  ['Makkari / Mike Khary / I', 'Dr. Spectrum / Joseph', 'Hyperion'],
#  ['Quasar Iii / Wendell V', 'Dr. Spectrum / Joseph', 'Hyperion'],
#  ['Whizzer Ii / Stanley S', 'Dr. Spectrum / Joseph', 'Hyperion'],
#  ['Iron Man / Tony Stark', 'Whizzer Ii / Stanley S', 'Hyperion'],
#  ['Hawk', 'Whizzer Ii / Stanley S', 'Hyperion'],
#  ['Scarlet Witch / Wanda', 'Whizzer Ii / Stanley S', 'Hyperion'],
#  ['Captain America', 'Whizzer Ii / Stanley S', 'Hyperion'],
#  ['Vision', 'Whizzer Ii / Stanley S', 'Hyperion'],
#  ['Beast / Henry &hank& P', 'Whizzer Ii / Stanley S', 'Hyperion'],
#  ['Thor / Dr. Donald Blak', 'Whizzer Ii / Stanley S', 'Hyperion'],
#  ['Dr. Strange / Stephen', 'Whizzer Ii / Stanley S', 'Hyperion'],
#  ['Hellcat / Patsy Walker', 'Whizzer Ii / Stanley S', 'Hyperion'],
#  ['Moondragon / Heather D', 'Whizzer Ii / Stanley S', 'Hyperion'],
#  ['Makkari / Mike Khary / I', 'Whizzer Ii / Stanley S', 'Hyperion'],
#  ['Quasar Iii / Wendell V', 'Whizzer Ii / Stanley S', 'Hyperion'],
#  ['Captain America', 'Makkari / Mike Khary / I', 'Jack Of Hearts / Jack'],
#  ['Wonder Man / Simon Wil',
#   'Makkari / Mike Khary / I',
#   'Jack Of Hearts / Jack'],
#  ['She-hulk / Jennifer Wa',
#   'Makkari / Mike Khary / I',
#   'Jack Of Hearts / Jack'],
#  ['Vision', 'Makkari / Mike Khary / I', 'Jack Of Hearts / Jack'],
#  ['Thing / Benjamin J. Gr',
#   'Makkari / Mike Khary / I',
#   'Jack Of Hearts / Jack'],
#  ...]
