# %% [markdown]
# # Metrics
#
# NetworkX includes a huge amount of algorithms and metrics. Here's a cheatsheet to the most common ones you'll need.
#
# ## Network Properties

# %%
# Import NetworkX and key data science libraries
import networkx as nx
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_theme()

# Import Marvel network data
marvel= pd.read_csv("data/marvel-unimodal-edges.csv")
M = nx.from_pandas_edgelist(marvel, source="Source", target="Target", edge_attr=True)
print(M)
# Out:
# Graph with 327 nodes and 9891 edges

# %%
M.number_of_nodes() # Number of nodes
# Out:
# 327

# %%
M.number_of_edges() # Alternative method for number of edges
# Out:
# 9891

# %%
M.is_directed() # Is the graph directed?
# Out:
# False

# %% [markdown]
# ## Paths

# %%
nx.shortest_path(M, "Black Panther / T'chal", 	"Gambit / Remy Lebeau") # Shortest path as list
# Out:
# ["Black Panther / T'chal", 'Firestar / Angelica Jo', 'Gambit / Remy Lebeau']

# %%
nx.shortest_path_length(M, "Black Panther / T'chal", "Gambit / Remy Lebeau") #Shortest path length (Distance)
# Out:
# 2

# %%
nx.average_shortest_path_length(M) # Average shortest path length (Average distance)
# Out:
# 1.873004258831917

# %%
nx.diameter(M)
# Out:
# 3

# %% [markdown]
# ## Components

# %%
nx.is_connected(M) # Is the graph connected?
# Out:
# True

# %%
nx.number_connected_components(M) # How many components are there?
# Out:
# 1

# %%
# Find the largest connected component (as a node set)
components = [G for G in nx.connected_components(M)]
largest = max(components, key=len)

# %% [markdown]
# ## Centrality
#
# Below I show just one example, but there are a range of [centrality functions](https://networkx.org/documentation/stable/reference/algorithms/centrality.html) in NetworkX.
#
# [n.b. I'll create a separate chapter on centrality soon.]

# %%
# Calculate betweenness centrality for every node
bc = nx.betweenness_centrality(M)

# %% [markdown]
# ## Triangles and Clustering

# %%
# Get number of triangles for every node
nx.triangles(M)

# n.b. Pay attention to the following note from the NetworkX docs:
# When computing triangles for the entire graph each triangle is counted three times, once at each node.
# Out:
# {"Black Panther / T'chal": 2837,
#  'Loki [asgardian]': 1055,
#  'Mantis / ? Brandt': 277,
#  'Iceman / Robert Bobby': 5320,
#  'Marvel Girl / Jean Grey': 5050,
#  'Cyclops / Scott Summer': 6474,
#  'Klaw / Ulysses Klaw': 1012,
#  'Human Torch / Johnny S': 6282,
#  'Richards, Franklin B': 2444,
#  'Wolverine / Logan': 7168,
#  'Firebird / Bonita Juar': 643,
#  'Mr. Fantastic / Reed R': 6191,
#  'Medusa / Medusalith Am': 1019,
#  'Dr. Strange / Stephen': 4522,
#  'Jack Of Hearts / Jack': 576,
#  'Mephisto': 916,
#  'Thanos': 2337,
#  'Swordsman / Jacques Du': 342,
#  'Collector / Taneleer T': 393,
#  'Lockjaw [inhuman]': 865,
#  'Sub-mariner / Namor Ma': 4197,
#  'Pharaoh Rama-tut': 2562,
#  'Ant-man Ii / Scott Har': 917,
#  'Lyja Lazerfist [skru': 399,
#  'Gorgon [inhuman]': 837,
#  'Nighthawk Ii / Kyle Ri': 422,
#  'Cage, Luke / Carl Luca': 1200,
#  'Colossus Ii / Peter Ra': 6169,
#  'Hellcat / Patsy Walker': 1278,
#  'Karnak [inhuman]': 873,
#  'Death': 756,
#  'Redwing': 214,
#  'Daredevil / Matt Murdo': 4276,
#  'Norriss, Sister Barb': 1244,
#  'Rage / Elvin Daryl Hal': 875,
#  'Starfox / Eros': 1686,
#  'Demolition Man / Denni': 349,
#  'Sersi / Sylvia': 1906,
#  'Spider-man / Peter Parker': 6533,
#  'Vision': 6672,
#  'Uatu': 2324,
#  'Binary / Carol Danvers': 2010,
#  'Gyrich, Henry Peter': 985,
#  'Nightcrawler / Kurt Wa': 3965,
#  'Angel / Warren Kenneth': 5562,
#  'Silver Surfer / Norrin': 3697,
#  'She-hulk / Jennifer Wa': 5868,
#  'Ghaur [deviant]': 155,
#  'Dr. Doom / Victor Von': 4084,
#  'Storm / Ororo Munroe S': 6220,
#  'Scarlet Witch / Wanda': 6216,
#  'Toad / Mortimer Toynbe': 537,
#  'Hulk / Dr. Robert Bruce Banner': 5984,
#  'Firestar / Angelica Jo': 2659,
#  'Wonder Man / Simon Wil': 5412,
#  'Drax / Arthur Douglas': 2307,
#  'Dugan, Timothy Aloyi': 825,
#  'Carter, Sharon': 152,
#  'Black Knight V / Dane': 4610,
#  'Sunfire / Shiro Yoshid': 953,
#  'Triton': 606,
#  'Ultron': 1099,
#  'Jones, Richard Milho': 1590,
#  'Iron Man / Tony Stark': 5983,
#  'Nelson, Franklin Fog': 425,
#  'Captain America': 7888,
#  'Jarvis, Edwin': 3437,
#  'Quasar Iii / Wendell V': 4047,
#  'Jameson, J. Jonah': 1628,
#  'Masters, Alicia Reis': 1333,
#  'Magneto / Magnus / Eric': 3138,
#  'Invisible Woman / Sue': 6242,
#  'Professor X / Charles': 6081,
#  'Iron Fist / Daniel Ran': 1049,
#  'Black Bolt / Blackanto': 849,
#  'Hawk': 5168,
#  'Sandman / William Bake': 1088,
#  'Falcon / Sam Wilson': 2034,
#  'Stingray / Dr. Walter': 575,
#  'Justice Ii / Vance Ast': 876,
#  'Hercules [greek God]': 5530,
#  'Usagent / Captain John': 2828,
#  'Captain Marvel Ii / Mo': 2628,
#  'Crystal [inhuman]': 3778,
#  'Tigra / Greer Nelson': 2055,
#  'Spider-woman Ii / Juli': 2654,
#  'Machine Man / X-51': 814,
#  'Mockingbird / Dr. Barb': 1399,
#  'Captain Marvel / Capta': 564,
#  'Wasp / Janet Van Dyne': 5937,
#  'Fury, Col. Nicholas': 2781,
#  'Thor / Dr. Donald Blak': 5939,
#  'Quicksilver / Pietro M': 5163,
#  'Captain Britain / Bria': 692,
#  'Shadowcat / Katherine': 2969,
#  'Black Widow / Natasha': 4685,
#  'Ant-man / Dr. Henry J.': 5128,
#  'Moon Knight / Marc Spe': 1736,
#  'Jocasta': 316,
#  'Moondragon / Heather D': 3402,
#  'Thing / Benjamin J. Gr': 6867,
#  'Beast / Henry &hank& P': 6660,
#  'Nova / Richard Rider': 3271,
#  'Wrecker Iii / Dirk Gar': 1027,
#  'Warlock Ii / Adam Warl': 2287,
#  'Piledriver Ii / Brian': 928,
#  'Thunderball / Dr. Elio': 1042,
#  'Dr. Octopus / Otto Oct': 998,
#  'Banner, Betty Ross T': 581,
#  'Avalanche / Dominic Pe': 571,
#  'Attuma': 243,
#  'Hela [asgardian]': 279,
#  'Doc Samson / Dr. Leona': 685,
#  'Guardian / James Macdo': 456,
#  'Northstar / Jean-paul': 2137,
#  'Dr. Druid / Anthony Lu': 2075,
#  'Watson-parker, Mary': 805,
#  'Mystique / Raven Darkh': 1067,
#  'Pyro / Allerdyce Johnn': 740,
#  'Destiny Ii / Irene Adl': 418,
#  'Mister Hyde / Calvin Z': 189,
#  'Ghost Rider Ii / Johnn': 279,
#  'Mole Man / Harvey Rupe': 544,
#  'Firelord / Pyreus Kril': 540,
#  'Leader / Sam Sterns': 136,
#  'Le Fey, Morgan': 141,
#  'Bulldozer / Henry Camp': 928,
#  'Forgotten One / Gilgam': 310,
#  'Balder [asgardian]': 358,
#  'Hogun [asgardian]': 539,
#  'Hellstorm / Daimon Hel': 341,
#  'Aurora / Jeanne-marie': 1466,
#  "O'brien, Michael": 437,
#  'Stankowicz, Fabian': 259,
#  'Screaming Mimi / Melis': 332,
#  'Moonstone Ii / Karla S': 556,
#  'Fixer Ii / Paul Norber': 399,
#  'Darkstar / Laynia Serg': 441,
#  'Vanguard / Nicolai Kry': 275,
#  'Gamora': 1577,
#  'Psylocke / Elisabeth B': 4245,
#  'Rogue  / ': 5545,
#  'Sasquatch / Walter Lan': 3138,
#  'Luna / Luna Maximoff [': 357,
#  'Whizzer Ii / Stanley S': 96,
#  'Dr. Spectrum / Joseph': 96,
#  'Kingpin / Wilson Fisk': 518,
#  'Clea': 171,
#  'Polaris / Lorna Dane': 3325,
#  'De La Fontaine, Cont': 174,
#  'Heimdall [asgardian]': 193,
#  'Red Skull / Johann Sch': 429,
#  'Thompson, Eugene Fla': 507,
#  'Wong': 412,
#  'Parker, May': 541,
#  'Green Goblin / Norman': 207,
#  'Night Thrasher / Duane': 252,
#  'Eternity / Adam Qadmon': 1623,
#  'Galactus / Galan': 3125,
#  'Triathlon / Delroy Gar': 334,
#  'Beetle / Abner Ronald': 659,
#  'Lilandra Neramani [s': 1290,
#  'Odin [asgardian]': 903,
#  'Hogan, Virginia Pepp': 113,
#  'Mad Dog / Colonel Buzz': 166,
#  'Kincaid, Dr. Jane Fo': 249,
#  'Wizard / Bentley Wittm': 309,
#  'Charcoal / Charlie Bur': 165,
#  'Blob / Fred J. Dukes': 1189,
#  'Cloak / Tyrone Johnson': 164,
#  'Thunderstrike / Eric K': 3331,
#  'Power Man / Erik Joste': 580,
#  'Human Torch Android / ': 468,
#  'Juggernaut / Cain Mark': 349,
#  'Absorbing Man / Carl C': 981,
#  'Volstagg': 466,
#  'Shaman / Michael Twoyo': 2187,
#  'Snowbird / Narya / Anne': 381,
#  'Dagger / Tandy Bowen': 273,
#  'Phoenix Iii / Rachel S': 892,
#  'Mandarin': 177,
#  'Fandral [asgardian]': 546,
#  'Ms. Marvel Ii / Sharon': 265,
#  'Pip / Prince Gofern': 1569,
#  'Enchantress / Amora / He': 1465,
#  'Jameson, Col. John': 328,
#  'Cooper, Dr. Valerie': 1411,
#  'Nova Ii / Frankie Raye': 1992,
#  'Darkhawk / Chris Powel': 1881,
#  'Nomad Iii / Jack Monro': 197,
#  'Robertson, Joe': 654,
#  'Gargoyle Ii / Isaac Ch': 549,
#  'Namorita / Nita Prenti': 2840,
#  'Iron Man Iv / James R.': 1520,
#  'Ross, Gen. Thaddeus': 384,
#  'Harkness, Agatha': 2391,
#  'Carter, Peggy': 387,
#  'Hyperion': 160,
#  'Living Lightning / Mig': 2888,
#  'Jones, Gabe': 304,
#  'Osborn, Liz Allan': 451,
#  'Leeds, Betty Brant': 508,
#  'Sif': 444,
#  'Dazzler Ii / Allison B': 970,
#  'Molecule Man / Owen Re': 731,
#  'Speedball / Robbie Bal': 2263,
#  'Lizard / Dr. Curtis Co': 778,
#  'Volcana / Marsha Rosen': 615,
#  'Lockheed': 796,
#  'Titania Ii / Mary Skee': 748,
#  'Boomer / Tabitha Smith': 1306,
#  'Summers, Nathan Chri': 1861,
#  'Summers, Madelyne Ma': 524,
#  'Mactaggert, Moira Ki': 1662,
#  'Cannonball Ii / Sam Gu': 2512,
#  'Tilby, Trish / Patrici': 423,
#  'Skids / Sally Blevins': 371,
#  'Wolfsbane / Rahne Sinc': 3135,
#  'Leech': 249,
#  'Mirage Ii / Danielle M': 907,
#  'Gambit / Remy Lebeau': 3766,
#  'Jubilee / Jubilation L': 1117,
#  'Strong Guy / Guido Car': 2793,
#  'Spiral': 328,
#  'Banshee / Sean Cassidy': 1321,
#  'Legion Ii / David Hall': 377,
#  'Havok / Alex Summers': 3894,
#  'Longshot': 450,
#  'Forge': 1666,
#  'Sabretooth / Victor Cr': 659,
#  'Maddicks, Arthur Art': 225,
#  'Warlock Iii': 1030,
#  'Rictor / Julio Esteban': 953,
#  'Sunspot / Roberto Daco': 1687,
#  'Firefist / Rusty Colli': 334,
#  'Bishop  / ': 1466,
#  'Daytripper / Amanda Se': 258,
#  'Wild Child / Kyle Gibn': 1274,
#  'Thunderbird Ii / James': 1105,
#  'Sauron / Dr. Karl Lyko': 267,
#  'Siryn / Theresa Rourke': 965,
#  'Shatterstar Ii / Gavee': 682,
#  'Marrow / Sarah': 424,
#  'Feral / Maria Callasan': 515,
#  'Callisto': 302,
#  'Mr. Sinister / Nathan': 395,
#  'Raza Longknife': 332,
#  'Spider-woman / Jessica': 371,
#  'Cypher / Doug Ramsey': 589,
#  "Deathbird [shi'ar]": 297,
#  'Hudson, Heather': 2525,
#  'Stryfe': 518,
#  'Iron Man Doppelgange': 1031,
#  'Puck / Eugene Milton J': 2347,
#  'Silhouette': 519,
#  'Cortez, Fabian': 189,
#  'Black King / Sebastian': 402,
#  'Magik / Illyana Rasput': 605,
#  'Zabu': 229,
#  'Domino Iii / Beatrice / ': 229,
#  'Caliban / ': 607,
#  'Apocalypse / En Sabah': 1043,
#  'Hunter, Stevie': 588,
#  'Corsair': 486,
#  "Ch'od": 377,
#  "Mam'selle Hepzibah": 378,
#  'Zero': 431,
#  'X-man / Nathan Grey': 403,
#  "Karma / Xi'an Coy Manh": 331,
#  'Mr. Fantastic Doppel': 1153,
#  'Beyonder': 482,
#  'Multiple Man / James A': 2008,
#  'Colossus Ii Doppelga': 325,
#  'Scanner Ii': 139,
#  'Ka-zar / Kevin Plunder': 418,
#  'White Queen / Emma Fro': 514,
#  'Magma / Amara Aquilla / ': 333,
#  'Thanos Doppelganger': 1688,
#  'Magus': 2249,
#  'Knight, Misty': 259,
#  'Wing, Colleen': 53,
#  'Puppet Master / Philli': 273,
#  'Maximus [inhuman]': 185,
#  'Punisher Ii / Frank Ca': 333,
#  'Zeus': 217,
#  'Box Iv / Madison Jeffr': 156,
#  'Thena': 159,
#  'Black Cat / Felicia Ha': 270,
#  'Gee / Alex Power': 123,
#  'Spider-man Clone / Ben': 111,
#  'Ulik': 128,
#  'Citizen V Ii / Helmut': 285,
#  'High Evolutionary / He': 439,
#  'Hobgoblin V / Jason Ph': 213,
#  'Ghost Rider Iii / Dan': 111,
#  'Cushing, Kate': 224,
#  'Katzenberg, Nick': 174,
#  'Vizier': 208,
#  'Tombstone / Lonnie Tho': 154,
#  'Mercado, Joy': 191,
#  'Hammerhead': 138,
#  'Arranger / ': 170,
#  'Osborn, Harry': 291,
#  'Cobra / Klaus Vorhees': 64,
#  'Leeds, Ned': 228,
#  'Watson, Anna': 249,
#  'Urich, Ben': 431,
#  'Robertson, Randy': 199,
#  'Page, Karen': 97,
#  'Grant, Gloria Glory': 295,
#  'Lubenski, Nate': 162,
#  'Ikaris / Ike Harris [e': 114,
#  'Rosenthal, Bernie': 133,
#  'Gladiator Ii': 214,
#  'Beta Ray Bill': 188,
#  'Bridge, George Washi': 92,
#  'Diamond Lil / Lillian': 81,
#  'Asp Ii / Cleo': 27,
#  'Black Mamba / Tanya Se': 27,
#  'Meggan': 187,
#  'Austin, Susan': 122,
#  'Diamondback Ii / Rache': 120,
#  'Makkari / Mike Khary / I': 195,
#  'Hodge, Cameron': 301,
#  'Skin / Angelo Espinosa': 72,
#  'Husk / Paige Guthrie': 93,
#  'Deadpool / Jack / Wade W': 61}

# %%
# Get clustering coefficients
# These can be added to a node dataframe as in the previous chapter
nx.clustering(M)
# Out:
# {"Black Panther / T'chal": 0.5617821782178218,
#  'Loki [asgardian]': 0.5579058699101005,
#  'Mantis / ? Brandt': 0.9233333333333333,
#  'Iceman / Robert Bobby': 0.40794417606011807,
#  'Marvel Girl / Jean Grey': 0.42312526183493926,
#  'Cyclops / Scott Summer': 0.3353361649228219,
#  'Klaw / Ulysses Klaw': 0.7071977638015374,
#  'Human Torch / Johnny S': 0.3390544041450777,
#  'Richards, Franklin B': 0.5838509316770186,
#  'Wolverine / Logan': 0.2975508509755085,
#  'Firebird / Bonita Juar': 0.914651493598862,
#  'Mr. Fantastic / Reed R': 0.3174383428190535,
#  'Medusa / Medusalith Am': 0.8318367346938775,
#  'Dr. Strange / Stephen': 0.4581560283687943,
#  'Jack Of Hearts / Jack': 0.7773279352226721,
#  'Mephisto': 0.5948051948051948,
#  'Thanos': 0.7782217782217782,
#  'Swordsman / Jacques Du': 0.9047619047619048,
#  'Collector / Taneleer T': 0.903448275862069,
#  'Lockjaw [inhuman]': 0.8737373737373737,
#  'Sub-mariner / Namor Ma': 0.41337535703732886,
#  'Pharaoh Rama-tut': 0.7176470588235294,
#  'Ant-man Ii / Scott Har': 0.7192156862745098,
#  'Lyja Lazerfist [skru': 0.8044354838709677,
#  'Gorgon [inhuman]': 0.8847780126849895,
#  'Nighthawk Ii / Kyle Ri': 0.8508064516129032,
#  'Cage, Luke / Carl Luca': 0.6345848757271285,
#  'Colossus Ii / Peter Ra': 0.3509500512003641,
#  'Hellcat / Patsy Walker': 0.6758328926493918,
#  'Karnak [inhuman]': 0.8818181818181818,
#  'Death': 0.8372093023255814,
#  'Redwing': 0.7133333333333334,
#  'Daredevil / Matt Murdo': 0.4095785440613027,
#  'Norriss, Sister Barb': 0.6797814207650273,
#  'Rage / Elvin Daryl Hal': 0.8094357076780758,
#  'Starfox / Eros': 0.6415525114155252,
#  'Demolition Man / Denni': 0.8022988505747126,
#  'Sersi / Sylvia': 0.5739235170129479,
#  'Spider-man / Peter Parker': 0.276201750306515,
#  'Vision': 0.29550890247143236,
#  'Uatu': 0.6997892201144233,
#  'Binary / Carol Danvers': 0.5499316005471956,
#  'Gyrich, Henry Peter': 0.6632996632996633,
#  'Nightcrawler / Kurt Wa': 0.39606432923783835,
#  'Angel / Warren Kenneth': 0.39180050718512255,
#  'Silver Surfer / Norrin': 0.5265631676399374,
#  'She-hulk / Jennifer Wa': 0.37250047609979053,
#  'Ghaur [deviant]': 0.8157894736842105,
#  'Dr. Doom / Victor Von': 0.5186031746031746,
#  'Storm / Ororo Munroe S': 0.3464216095795043,
#  'Scarlet Witch / Wanda': 0.33203354521660167,
#  'Toad / Mortimer Toynbe': 0.7638691322901849,
#  'Hulk / Dr. Robert Bruce Banner': 0.3633052030842086,
#  'Firestar / Angelica Jo': 0.6493284493284494,
#  'Wonder Man / Simon Wil': 0.4201863354037267,
#  'Drax / Arthur Douglas': 0.8313513513513513,
#  'Dugan, Timothy Aloyi': 0.7313829787234043,
#  'Carter, Sharon': 0.8,
#  'Black Knight V / Dane': 0.46707193515704154,
#  'Sunfire / Shiro Yoshid': 0.7474509803921568,
#  'Triton': 0.8620199146514936,
#  'Ultron': 0.8288084464555053,
#  'Jones, Richard Milho': 0.7191316146540027,
#  'Iron Man / Tony Stark': 0.2918109544944642,
#  'Nelson, Franklin Fog': 0.5448717948717948,
#  'Captain America': 0.23792718607667482,
#  'Jarvis, Edwin': 0.4098986285032797,
#  'Quasar Iii / Wendell V': 0.5221935483870968,
#  'Jameson, J. Jonah': 0.4670109007458405,
#  'Masters, Alicia Reis': 0.8064125831820932,
#  'Magneto / Magnus / Eric': 0.446944879646774,
#  'Invisible Woman / Sue': 0.33000264340470525,
#  'Professor X / Charles': 0.3572855464159812,
#  'Iron Fist / Daniel Ran': 0.6811688311688312,
#  'Black Bolt / Blackanto': 0.8974630021141649,
#  'Hawk': 0.35976331360946745,
#  'Sandman / William Bake': 0.7064935064935065,
#  'Falcon / Sam Wilson': 0.5834767641996558,
#  'Stingray / Dr. Walter': 0.817923186344239,
#  'Justice Ii / Vance Ast': 0.7448979591836735,
#  'Hercules [greek God]': 0.3804609563123495,
#  'Usagent / Captain John': 0.6610565684899485,
#  'Captain Marvel Ii / Mo': 0.5529139490847885,
#  'Crystal [inhuman]': 0.5865548827821767,
#  'Tigra / Greer Nelson': 0.6843156843156843,
#  'Spider-woman Ii / Juli': 0.6626716604244695,
#  'Machine Man / X-51': 0.9014396456256921,
#  'Mockingbird / Dr. Barb': 0.7398202009518773,
#  'Captain Marvel / Capta': 0.8468468468468469,
#  'Wasp / Janet Van Dyne': 0.33775173512344975,
#  'Fury, Col. Nicholas': 0.4903897019925939,
#  'Thor / Dr. Donald Blak': 0.284026781444285,
#  'Quicksilver / Pietro M': 0.4110341533317411,
#  'Captain Britain / Bria': 0.7315010570824524,
#  'Shadowcat / Katherine': 0.46918457648546147,
#  'Black Widow / Natasha': 0.43658559314136614,
#  'Ant-man / Dr. Henry J.': 0.38839657653563586,
#  'Moon Knight / Marc Spe': 0.7399829497016198,
#  'Jocasta': 0.9002849002849003,
#  'Moondragon / Heather D': 0.6476299257567104,
#  'Thing / Benjamin J. Gr': 0.3013031459786758,
#  'Beast / Henry &hank& P': 0.31850789096126253,
#  'Nova / Richard Rider': 0.6226917951646678,
#  'Wrecker Iii / Dirk Gar': 0.7176799440950384,
#  'Warlock Ii / Adam Warl': 0.8241441441441442,
#  'Piledriver Ii / Brian': 0.7891156462585034,
#  'Thunderball / Dr. Elio': 0.7016835016835017,
#  'Dr. Octopus / Otto Oct': 0.62531328320802,
#  'Banner, Betty Ross T': 0.8723723723723724,
#  'Avalanche / Dominic Pe': 0.7705802968960864,
#  'Attuma': 0.8804347826086957,
#  'Hela [asgardian]': 0.5284090909090909,
#  'Doc Samson / Dr. Leona': 0.8782051282051282,
#  'Guardian / James Macdo': 0.8636363636363636,
#  'Northstar / Jean-paul': 0.7911884487226953,
#  'Dr. Druid / Anthony Lu': 0.8350100603621731,
#  'Watson-parker, Mary': 0.4869933454325469,
#  'Mystique / Raven Darkh': 0.6454930429522081,
#  'Pyro / Allerdyce Johnn': 0.714975845410628,
#  'Destiny Ii / Irene Adl': 0.7916666666666666,
#  'Mister Hyde / Calvin Z': 0.6847826086956522,
#  'Ghost Rider Ii / Johnn': 0.7948717948717948,
#  'Mole Man / Harvey Rupe': 0.9142857142857143,
#  'Firelord / Pyreus Kril': 0.8571428571428571,
#  'Leader / Sam Sterns': 1.0,
#  'Le Fey, Morgan': 0.9215686274509803,
#  'Bulldozer / Henry Camp': 0.7891156462585034,
#  'Forgotten One / Gilgam': 0.8201058201058201,
#  'Balder [asgardian]': 0.678030303030303,
#  'Hogun [asgardian]': 0.5697674418604651,
#  'Hellstorm / Daimon Hel': 0.9021164021164021,
#  'Aurora / Jeanne-marie': 0.8282485875706215,
#  "O'brien, Michael": 0.7789661319073083,
#  'Stankowicz, Fabian': 0.8633333333333333,
#  'Screaming Mimi / Melis': 0.7632183908045977,
#  'Moonstone Ii / Karla S': 0.7128205128205128,
#  'Fixer Ii / Paul Norber': 0.7112299465240641,
#  'Darkstar / Laynia Serg': 0.8891129032258065,
#  'Vanguard / Nicolai Kry': 0.9166666666666666,
#  'Gamora': 0.9216832261835184,
#  'Psylocke / Elisabeth B': 0.4909784871616933,
#  'Rogue  / ': 0.3906029867568329,
#  'Sasquatch / Walter Lan': 0.7179135209334249,
#  'Luna / Luna Maximoff [': 0.8793103448275862,
#  'Whizzer Ii / Stanley S': 0.9142857142857143,
#  'Dr. Spectrum / Joseph': 0.9142857142857143,
#  'Kingpin / Wilson Fisk': 0.4592198581560284,
#  'Clea': 0.9,
#  'Polaris / Lorna Dane': 0.5446355446355446,
#  'De La Fontaine, Cont': 0.7532467532467533,
#  'Heimdall [asgardian]': 0.8354978354978355,
#  'Red Skull / Johann Sch': 0.6102418207681366,
#  'Thompson, Eugene Fla': 0.5888501742160279,
#  'Wong': 0.886021505376344,
#  'Parker, May': 0.5991140642303433,
#  'Green Goblin / Norman': 0.8181818181818182,
#  'Night Thrasher / Duane': 0.7753846153846153,
#  'Eternity / Adam Qadmon': 0.8868852459016393,
#  'Galactus / Galan': 0.6574794866400169,
#  'Triathlon / Delroy Gar': 0.8835978835978836,
#  'Beetle / Abner Ronald': 0.6656565656565656,
#  'Lilandra Neramani [s': 0.6398809523809523,
#  'Odin [asgardian]': 0.5863636363636363,
#  'Hogan, Virginia Pepp': 0.9416666666666667,
#  'Mad Dog / Colonel Buzz': 0.7904761904761904,
#  'Kincaid, Dr. Jane Fo': 0.6587301587301587,
#  'Wizard / Bentley Wittm': 0.7610837438423645,
#  'Charcoal / Charlie Bur': 0.7857142857142857,
#  'Blob / Fred J. Dukes': 0.6287678476996298,
#  'Cloak / Tyrone Johnson': 0.5942028985507246,
#  'Thunderstrike / Eric K': 0.6219193427931292,
#  'Power Man / Erik Joste': 0.6736353077816493,
#  'Human Torch Android / ': 0.7428571428571429,
#  'Juggernaut / Cain Mark': 0.8022988505747126,
#  'Absorbing Man / Carl C': 0.7398190045248869,
#  'Volstagg': 0.5682926829268292,
#  'Shaman / Michael Twoyo': 0.7881081081081082,
#  'Snowbird / Narya / Anne': 0.8758620689655172,
#  'Dagger / Tandy Bowen': 0.6724137931034483,
#  'Phoenix Iii / Rachel S': 0.623340321453529,
#  'Mandarin': 0.7662337662337663,
#  'Fandral [asgardian]': 0.5515151515151515,
#  'Ms. Marvel Ii / Sharon': 0.8153846153846154,
#  'Pip / Prince Gofern': 0.8864406779661017,
#  'Enchantress / Amora / He': 0.624467178175618,
#  'Jameson, Col. John': 0.5206349206349207,
#  'Cooper, Dr. Valerie': 0.5842650103519669,
#  'Nova Ii / Frankie Raye': 0.874451273046532,
#  'Darkhawk / Chris Powel': 0.7788819875776397,
#  'Nomad Iii / Jack Monro': 0.6061538461538462,
#  'Robertson, Joe': 0.5561224489795918,
#  'Gargoyle Ii / Isaac Ch': 0.8243243243243243,
#  'Namorita / Nita Prenti': 0.6638616175783076,
#  'Iron Man Iv / James R.': 0.7307692307692307,
#  'Ross, Gen. Thaddeus': 0.9458128078817734,
#  'Harkness, Agatha': 0.8171565276828435,
#  'Carter, Peggy': 0.6504201680672269,
#  'Hyperion': 0.8421052631578947,
#  'Living Lightning / Mig': 0.7901504787961696,
#  'Jones, Gabe': 0.8042328042328042,
#  'Osborn, Liz Allan': 0.6415362731152204,
#  'Leeds, Betty Brant': 0.6195121951219512,
#  'Sif': 0.631578947368421,
#  'Dazzler Ii / Allison B': 0.7315233785822021,
#  'Molecule Man / Owen Re': 0.9371794871794872,
#  'Speedball / Robbie Bal': 0.7734107997265892,
#  'Lizard / Dr. Curtis Co': 0.6897163120567376,
#  'Volcana / Marsha Rosen': 0.9761904761904762,
#  'Lockheed': 0.649795918367347,
#  'Titania Ii / Mary Skee': 0.8283499446290143,
#  'Boomer / Tabitha Smith': 0.6088578088578088,
#  'Summers, Nathan Chri': 0.5468704084631207,
#  'Summers, Madelyne Ma': 0.7867867867867868,
#  'Mactaggert, Moira Ki': 0.5534465534465535,
#  'Cannonball Ii / Sam Gu': 0.4190158465387823,
#  'Tilby, Trish / Patrici': 0.8011363636363636,
#  'Skids / Sally Blevins': 0.7479838709677419,
#  'Wolfsbane / Rahne Sinc': 0.4700149925037481,
#  'Leech': 0.6587301587301587,
#  'Mirage Ii / Danielle M': 0.5486993345432547,
#  'Gambit / Remy Lebeau': 0.518732782369146,
#  'Jubilee / Jubilation L': 0.6528345996493279,
#  'Strong Guy / Guido Car': 0.652875175315568,
#  'Spiral': 0.8078817733990148,
#  'Banshee / Sean Cassidy': 0.5630861040068201,
#  'Legion Ii / David Hall': 0.9285714285714286,
#  'Havok / Alex Summers': 0.5106215578284815,
#  'Longshot': 0.8522727272727273,
#  'Forge': 0.6339421613394216,
#  'Sabretooth / Victor Cr': 0.8448717948717949,
#  'Maddicks, Arthur Art': 0.6923076923076923,
#  'Warlock Iii': 0.6019871420222093,
#  'Rictor / Julio Esteban': 0.6915820029027576,
#  'Sunspot / Roberto Daco': 0.5079795242396868,
#  'Firefist / Rusty Colli': 0.6733870967741935,
#  'Bishop  / ': 0.6435469710272168,
#  'Daytripper / Amanda Se': 0.86,
#  'Wild Child / Kyle Gibn': 0.8272727272727273,
#  'Thunderbird Ii / James': 0.6458211572180012,
#  'Sauron / Dr. Karl Lyko': 0.89,
#  'Siryn / Theresa Rourke': 0.7002902757619739,
#  'Shatterstar Ii / Gavee': 0.7921022067363531,
#  'Marrow / Sarah': 0.803030303030303,
#  'Feral / Maria Callasan': 0.8174603174603174,
#  'Callisto': 0.8603988603988604,
#  'Mr. Sinister / Nathan': 0.9080459770114943,
#  'Raza Longknife': 0.8783068783068783,
#  'Spider-woman / Jessica': 0.8528735632183908,
#  'Cypher / Doug Ramsey': 0.7182926829268292,
#  "Deathbird [shi'ar]": 0.7857142857142857,
#  'Hudson, Heather': 0.7603131586871424,
#  'Stryfe': 0.9233511586452763,
#  'Iron Man Doppelgange': 0.996135265700483,
#  'Puck / Eugene Milton J': 0.7617656604998377,
#  'Silhouette': 0.8722689075630252,
#  'Cortez, Fabian': 0.9,
#  'Black King / Sebastian': 0.864516129032258,
#  'Magik / Illyana Rasput': 0.7378048780487805,
#  'Zabu': 0.7633333333333333,
#  'Domino Iii / Beatrice / ': 0.8297101449275363,
#  'Caliban / ': 0.7402439024390244,
#  'Apocalypse / En Sabah': 0.6772727272727272,
#  'Hunter, Stevie': 0.8364153627311522,
#  'Corsair': 0.8168067226890756,
#  "Ch'od": 0.8666666666666667,
#  "Mam'selle Hepzibah": 0.8689655172413793,
#  'Zero': 0.9268817204301075,
#  'X-man / Nathan Grey': 0.8666666666666667,
#  "Karma / Xi'an Coy Manh": 0.8152709359605911,
#  'Mr. Fantastic Doppel': 0.9804421768707483,
#  'Beyonder': 0.765079365079365,
#  'Multiple Man / James A': 0.7045614035087719,
#  'Colossus Ii Doppelga': 1.0,
#  'Scanner Ii': 0.8128654970760234,
#  'Ka-zar / Kevin Plunder': 0.7916666666666666,
#  'White Queen / Emma Fro': 0.658974358974359,
#  'Magma / Amara Aquilla / ': 0.8809523809523809,
#  'Thanos Doppelganger': 0.9224043715846995,
#  'Magus': 0.8798904538341158,
#  'Knight, Misty': 0.7378917378917379,
#  'Wing, Colleen': 0.803030303030303,
#  'Puppet Master / Philli': 0.91,
#  'Maximus [inhuman]': 0.9736842105263158,
#  'Punisher Ii / Frank Ca': 0.47368421052631576,
#  'Zeus': 0.7862318840579711,
#  'Box Iv / Madison Jeffr': 0.8210526315789474,
#  'Thena': 0.6883116883116883,
#  'Black Cat / Felicia Ha': 0.6650246305418719,
#  'Gee / Alex Power': 0.5324675324675324,
#  'Spider-man Clone / Ben': 0.6491228070175439,
#  'Ulik': 0.7485380116959064,
#  'Citizen V Ii / Helmut': 0.6129032258064516,
#  'High Evolutionary / He': 0.5353658536585366,
#  'Hobgoblin V / Jason Ph': 0.6553846153846153,
#  'Ghost Rider Iii / Dan': 0.6491228070175439,
#  'Cushing, Kate': 0.8853754940711462,
#  'Katzenberg, Nick': 0.9157894736842105,
#  'Vizier': 0.8221343873517787,
#  'Tombstone / Lonnie Tho': 0.7333333333333333,
#  'Mercado, Joy': 0.9095238095238095,
#  'Hammerhead': 0.8070175438596491,
#  'Arranger / ': 0.8947368421052632,
#  'Osborn, Harry': 0.7698412698412699,
#  'Cobra / Klaus Vorhees': 0.5333333333333333,
#  'Leeds, Ned': 0.8260869565217391,
#  'Watson, Anna': 0.7661538461538462,
#  'Urich, Ben': 0.6471471471471472,
#  'Robertson, Randy': 0.8614718614718615,
#  'Page, Karen': 0.8083333333333333,
#  'Grant, Gloria Glory': 0.7804232804232805,
#  'Lubenski, Nate': 0.9473684210526315,
#  'Ikaris / Ike Harris [e': 0.8382352941176471,
#  'Rosenthal, Bernie': 0.6333333333333333,
#  'Gladiator Ii': 0.8458498023715415,
#  'Beta Ray Bill': 0.6811594202898551,
#  'Bridge, George Washi': 0.39826839826839827,
#  'Diamond Lil / Lillian': 0.8901098901098901,
#  'Asp Ii / Cleo': 0.9642857142857143,
#  'Black Mamba / Tanya Se': 0.9642857142857143,
#  'Meggan': 0.8904761904761904,
#  'Austin, Susan': 0.8970588235294118,
#  'Diamondback Ii / Rache': 0.631578947368421,
#  'Makkari / Mike Khary / I': 0.6,
#  'Hodge, Cameron': 0.8575498575498576,
#  'Skin / Angelo Espinosa': 0.7912087912087912,
#  'Husk / Paige Guthrie': 0.775,
#  'Deadpool / Jack / Wade W': 0.782051282051282}

# %%
# Find the average clustering coefficient
nx.average_clustering(M)
# Out:
# 0.7047201786696375

# %% [markdown]
# ## Bridges

# %%
# List a network's bridges
list(nx.bridges(M))
# Out:
# []

# %%
# Test if a network has any bridges
nx.has_bridges(M)
# Out:
# False

# %%
# List a network's local bridges
list(nx.local_bridges(M))
# Out:
# [('Death', 'Deadpool / Jack / Wade W', 3)]

# %% [markdown]
# ## Neighbors

# %%
# Find a node's neighbors
list(nx.neighbors(M, 'Death'))
# Out:
# ["Black Panther / T'chal",
#  'Iron Man / Tony Stark',
#  'Sub-mariner / Namor Ma',
#  'Nova / Richard Rider',
#  'Hulk / Dr. Robert Bruce Banner',
#  'Spider-man / Peter Parker',
#  'Wasp / Janet Van Dyne',
#  'Galactus / Galan',
#  'Silver Surfer / Norrin',
#  'Hawk',
#  'Scarlet Witch / Wanda',
#  'Uatu',
#  'Captain America',
#  'Thunderstrike / Eric K',
#  'Wonder Man / Simon Wil',
#  'Wolverine / Logan',
#  'She-hulk / Jennifer Wa',
#  'Vision',
#  'Storm / Ororo Munroe S',
#  'Eternity / Adam Qadmon',
#  'Quasar Iii / Wendell V',
#  'Black Widow / Natasha',
#  'Firelord / Pyreus Kril',
#  'Thor / Dr. Donald Blak',
#  'Richards, Franklin B',
#  'Deadpool / Jack / Wade W',
#  'Mephisto',
#  'Dr. Doom / Victor Von',
#  'Thing / Benjamin J. Gr',
#  'Gamora',
#  'Drax / Arthur Douglas',
#  'Nova Ii / Frankie Raye',
#  'Ant-man / Dr. Henry J.',
#  'Moondragon / Heather D',
#  'Pip / Prince Gofern',
#  'Thanos',
#  'Collector / Taneleer T',
#  'Captain Marvel / Capta',
#  'Warlock Ii / Adam Warl',
#  'Dr. Strange / Stephen',
#  'Starfox / Eros',
#  'Invisible Woman / Sue',
#  'Cyclops / Scott Summer']

# %%
# Find common neighbors of a node pair
list(nx.common_neighbors(M, 'Death', 'Thanos'))
# Out:
# ["Black Panther / T'chal",
#  'Iron Man / Tony Stark',
#  'Sub-mariner / Namor Ma',
#  'Nova / Richard Rider',
#  'Hulk / Dr. Robert Bruce Banner',
#  'Spider-man / Peter Parker',
#  'Galactus / Galan',
#  'Silver Surfer / Norrin',
#  'Hawk',
#  'Scarlet Witch / Wanda',
#  'Uatu',
#  'Captain America',
#  'Thunderstrike / Eric K',
#  'Wonder Man / Simon Wil',
#  'Wolverine / Logan',
#  'She-hulk / Jennifer Wa',
#  'Vision',
#  'Storm / Ororo Munroe S',
#  'Eternity / Adam Qadmon',
#  'Quasar Iii / Wendell V',
#  'Black Widow / Natasha',
#  'Firelord / Pyreus Kril',
#  'Thor / Dr. Donald Blak',
#  'Mephisto',
#  'Dr. Doom / Victor Von',
#  'Thing / Benjamin J. Gr',
#  'Gamora',
#  'Drax / Arthur Douglas',
#  'Nova Ii / Frankie Raye',
#  'Ant-man / Dr. Henry J.',
#  'Moondragon / Heather D',
#  'Pip / Prince Gofern',
#  'Captain Marvel / Capta',
#  'Warlock Ii / Adam Warl',
#  'Dr. Strange / Stephen',
#  'Starfox / Eros',
#  'Invisible Woman / Sue',
#  'Cyclops / Scott Summer']

# %% [markdown]
# ## Cycles/Loops

# %%
# Get a list of the basis of all cycle in the graph
# All larger cycles are based on these cycles, many of which are triangles
nx.cycle_basis(M)
# Out:
# [['Iron Man / Tony Stark', 'Ms. Marvel Ii / Sharon', 'Mole Man / Harvey Rupe'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Spider-man / Peter Parker',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Captain America', 'Ms. Marvel Ii / Sharon', 'Mole Man / Harvey Rupe'],
#  ['Wonder Man / Simon Wil',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Wolverine / Logan', 'Ms. Marvel Ii / Sharon', 'Mole Man / Harvey Rupe'],
#  ['She-hulk / Jennifer Wa',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Marvel Girl / Jean Grey',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Mr. Fantastic / Reed R',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Thing / Benjamin J. Gr',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Invisible Woman / Sue', 'Ms. Marvel Ii / Sharon', 'Mole Man / Harvey Rupe'],
#  ['Beast / Henry &hank& P',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Thor / Dr. Donald Blak',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Crystal [inhuman]', 'Ms. Marvel Ii / Sharon', 'Mole Man / Harvey Rupe'],
#  ['Human Torch / Johnny S',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Ant-man / Dr. Henry J.',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Richards, Franklin B', 'Ms. Marvel Ii / Sharon', 'Mole Man / Harvey Rupe'],
#  ['Lyja Lazerfist [skru', 'Ms. Marvel Ii / Sharon', 'Mole Man / Harvey Rupe'],
#  ['Iron Man / Tony Stark', 'Wizard / Bentley Wittm', 'Ms. Marvel Ii / Sharon'],
#  ['Spider-man / Peter Parker',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon'],
#  ['Wasp / Janet Van Dyne',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Scarlet Witch / Wanda',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Captain America', 'Wizard / Bentley Wittm', 'Ms. Marvel Ii / Sharon'],
#  ['She-hulk / Jennifer Wa',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon'],
#  ['Vision',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Mr. Fantastic / Reed R',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon'],
#  ['Thing / Benjamin J. Gr',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon'],
#  ['Invisible Woman / Sue', 'Wizard / Bentley Wittm', 'Ms. Marvel Ii / Sharon'],
#  ['Thor / Dr. Donald Blak',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon'],
#  ['Crystal [inhuman]', 'Wizard / Bentley Wittm', 'Ms. Marvel Ii / Sharon'],
#  ['Human Torch / Johnny S',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon'],
#  ['Ant-man / Dr. Henry J.',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon'],
#  ['Richards, Franklin B', 'Wizard / Bentley Wittm', 'Ms. Marvel Ii / Sharon'],
#  ['Dr. Doom / Victor Von', 'Wizard / Bentley Wittm', 'Ms. Marvel Ii / Sharon'],
#  ['Klaw / Ulysses Klaw', 'Wizard / Bentley Wittm', 'Ms. Marvel Ii / Sharon'],
#  ['Lyja Lazerfist [skru', 'Wizard / Bentley Wittm', 'Ms. Marvel Ii / Sharon'],
#  ['Titania Ii / Mary Skee',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon'],
#  ['Iron Man / Tony Stark', 'Medusa / Medusalith Am', 'Wizard / Bentley Wittm'],
#  ['Sub-mariner / Namor Ma',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon'],
#  ['Spider-man / Peter Parker',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm'],
#  ['Wasp / Janet Van Dyne', 'Medusa / Medusalith Am', 'Wizard / Bentley Wittm'],
#  ['Silver Surfer / Norrin',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Hawk',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Scarlet Witch / Wanda', 'Medusa / Medusalith Am', 'Wizard / Bentley Wittm'],
#  ['Quicksilver / Pietro M',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Captain America', 'Medusa / Medusalith Am', 'Wizard / Bentley Wittm'],
#  ['Wolverine / Logan',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon'],
#  ['She-hulk / Jennifer Wa',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm'],
#  ['Vision', 'Medusa / Medusalith Am', 'Wizard / Bentley Wittm'],
#  ['Mr. Fantastic / Reed R',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm'],
#  ['Angel / Warren Kenneth',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Thing / Benjamin J. Gr',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm'],
#  ['Invisible Woman / Sue', 'Medusa / Medusalith Am', 'Wizard / Bentley Wittm'],
#  ['Beast / Henry &hank& P',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon'],
#  ['Cyclops / Scott Summer',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Thor / Dr. Donald Blak',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm'],
#  ['Crystal [inhuman]', 'Medusa / Medusalith Am', 'Wizard / Bentley Wittm'],
#  ['Professor X / Charles',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Iceman / Robert Bobby',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Human Torch / Johnny S',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm'],
#  ['Ant-man / Dr. Henry J.',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm'],
#  ['Black Widow / Natasha',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Sandman / William Bake',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm'],
#  ['Richards, Franklin B', 'Medusa / Medusalith Am', 'Wizard / Bentley Wittm'],
#  ['Masters, Alicia Reis',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Dr. Doom / Victor Von', 'Medusa / Medusalith Am', 'Wizard / Bentley Wittm'],
#  ['Lyja Lazerfist [skru', 'Medusa / Medusalith Am', 'Wizard / Bentley Wittm'],
#  ['Jones, Richard Milho',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Iron Man / Tony Stark', 'Luna / Luna Maximoff [', 'Medusa / Medusalith Am'],
#  ['Wasp / Janet Van Dyne', 'Luna / Luna Maximoff [', 'Medusa / Medusalith Am'],
#  ['Hawk', 'Luna / Luna Maximoff [', 'Medusa / Medusalith Am'],
#  ['Scarlet Witch / Wanda', 'Luna / Luna Maximoff [', 'Medusa / Medusalith Am'],
#  ['Quicksilver / Pietro M',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Uatu', 'Luna / Luna Maximoff [', 'Medusa / Medusalith Am'],
#  ['Captain America', 'Luna / Luna Maximoff [', 'Medusa / Medusalith Am'],
#  ['She-hulk / Jennifer Wa',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Vision', 'Luna / Luna Maximoff [', 'Medusa / Medusalith Am'],
#  ['Mr. Fantastic / Reed R',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Thing / Benjamin J. Gr',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Invisible Woman / Sue', 'Luna / Luna Maximoff [', 'Medusa / Medusalith Am'],
#  ['Thor / Dr. Donald Blak',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Gorgon [inhuman]', 'Luna / Luna Maximoff [', 'Medusa / Medusalith Am'],
#  ['Lockjaw [inhuman]', 'Luna / Luna Maximoff [', 'Medusa / Medusalith Am'],
#  ['Crystal [inhuman]', 'Luna / Luna Maximoff [', 'Medusa / Medusalith Am'],
#  ['Black Bolt / Blackanto',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Triton', 'Luna / Luna Maximoff [', 'Medusa / Medusalith Am'],
#  ['Karnak [inhuman]', 'Luna / Luna Maximoff [', 'Medusa / Medusalith Am'],
#  ['Human Torch / Johnny S',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Ant-man / Dr. Henry J.',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Hercules [greek God]',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Black Widow / Natasha', 'Luna / Luna Maximoff [', 'Medusa / Medusalith Am'],
#  ['Maximus [inhuman]', 'Luna / Luna Maximoff [', 'Medusa / Medusalith Am'],
#  ["Black Panther / T'chal",
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Iron Man / Tony Stark', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Sub-mariner / Namor Ma',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Namorita / Nita Prenti',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Spider-man / Peter Parker',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Wasp / Janet Van Dyne', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Hawk', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Scarlet Witch / Wanda', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Quicksilver / Pietro M', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Uatu', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Captain America', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Wonder Man / Simon Wil',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon'],
#  ['Wolverine / Logan',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['She-hulk / Jennifer Wa', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Vision', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Marvel Girl / Jean Grey',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon'],
#  ['Storm / Ororo Munroe S',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon'],
#  ['Mr. Fantastic / Reed R', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Thing / Benjamin J. Gr', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Invisible Woman / Sue', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Beast / Henry &hank& P',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Cyclops / Scott Summer',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Thor / Dr. Donald Blak', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Dr. Strange / Stephen',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Lockjaw [inhuman]', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Crystal [inhuman]', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Human Torch / Johnny S', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Cage, Luke / Carl Luca',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Jarvis, Edwin', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Ant-man / Dr. Henry J.', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Hercules [greek God]', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Black Widow / Natasha', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Sandman / William Bake',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Black Knight V / Dane', 'Sersi / Sylvia', 'Luna / Luna Maximoff ['],
#  ['Demolition Man / Denni',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon'],
#  ['Sub-mariner / Namor Ma', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Captain America', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Wolverine / Logan', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['She-hulk / Jennifer Wa', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Vision', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Hercules [greek God]', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Quasar Iii / Wendell V', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Shaman / Michael Twoyo', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Hudson, Heather', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Sasquatch / Walter Lan', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Stingray / Dr. Walter', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Diamond Lil / Lillian', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Northstar / Jean-paul', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Puck / Eugene Milton J', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Iron Man / Tony Stark',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Sub-mariner / Namor Ma', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Spider-man / Peter Parker',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Wasp / Janet Van Dyne',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Hawk', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr', 'Sersi / Sylvia'],
#  ['Scarlet Witch / Wanda',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Quicksilver / Pietro M',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Captain America', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr'],
#  ['Wonder Man / Simon Wil',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Wolverine / Logan', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr'],
#  ['She-hulk / Jennifer Wa', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr'],
#  ['Vision', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr'],
#  ['Marvel Girl / Jean Grey',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Storm / Ororo Munroe S',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Mr. Fantastic / Reed R',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Angel / Warren Kenneth',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Thing / Benjamin J. Gr',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Invisible Woman / Sue',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Beast / Henry &hank& P',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Cyclops / Scott Summer',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Dr. Strange / Stephen',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Crystal [inhuman]',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Professor X / Charles',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Iceman / Robert Bobby',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Moondragon / Heather D',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Human Torch / Johnny S',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Havok / Alex Summers',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Polaris / Lorna Dane',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm',
#   'Ms. Marvel Ii / Sharon',
#   'Mole Man / Harvey Rupe'],
#  ['Hercules [greek God]', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr'],
#  ['Black Widow / Natasha',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Daredevil / Matt Murdo',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Dr. Doom / Victor Von',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Quasar Iii / Wendell V', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr'],
#  ['Black Knight V / Dane',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Shaman / Michael Twoyo', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr'],
#  ['Hudson, Heather', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr'],
#  ['Sasquatch / Walter Lan', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr'],
#  ['Diamond Lil / Lillian', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr'],
#  ['Northstar / Jean-paul', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr'],
#  ['Snowbird / Narya / Anne',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr'],
#  ['Attuma', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr'],
#  ['Wild Child / Kyle Gibn', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr'],
#  ['Puck / Eugene Milton J', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr'],
#  ['Guardian / James Macdo', 'Aurora / Jeanne-marie', 'Box Iv / Madison Jeffr'],
#  ['Rogue  / ', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Firestar / Angelica Jo',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Namorita / Nita Prenti',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Hulk / Dr. Robert Bruce Banner', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Wasp / Janet Van Dyne', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Galactus / Galan',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Silver Surfer / Norrin',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Scarlet Witch / Wanda', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Quicksilver / Pietro M', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Captain America', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Thunderstrike / Eric K',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Wonder Man / Simon Wil', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Wolverine / Logan', 'Magus', 'Aurora / Jeanne-marie'],
#  ['She-hulk / Jennifer Wa', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Vision', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Psylocke / Elisabeth B', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Marvel Girl / Jean Grey', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Storm / Ororo Munroe S', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Mr. Fantastic / Reed R', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Angel / Warren Kenneth', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Thing / Benjamin J. Gr', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Invisible Woman / Sue', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Beast / Henry &hank& P', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Cyclops / Scott Summer', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Dr. Strange / Stephen', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Crystal [inhuman]', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Warlock Ii / Adam Warl', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Professor X / Charles', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Iceman / Robert Bobby', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Moondragon / Heather D', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Human Torch / Johnny S', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Havok / Alex Summers', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Colossus Ii / Peter Ra', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Polaris / Lorna Dane', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Wolfsbane / Rahne Sinc', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Ant-man / Dr. Henry J.',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Hercules [greek God]', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Black Widow / Natasha', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Drax / Arthur Douglas', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Richards, Franklin B',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Daredevil / Matt Murdo', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Dr. Druid / Anthony Lu',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Gamora', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Dr. Doom / Victor Von', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Thanos', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Quasar Iii / Wendell V', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Usagent / Captain John',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Nova Ii / Frankie Raye',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Black Knight V / Dane', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Pharaoh Rama-tut',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Shaman / Michael Twoyo', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Strong Guy / Guido Car', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Hudson, Heather', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Sasquatch / Walter Lan', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Harkness, Agatha',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Wild Child / Kyle Gibn', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Puck / Eugene Milton J', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Living Lightning / Mig',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Northstar / Jean-paul', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Rogue  / ', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Nova / Richard Rider', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Firestar / Angelica Jo', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Namorita / Nita Prenti', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Speedball / Robbie Bal', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Hulk / Dr. Robert Bruce Banner', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Wasp / Janet Van Dyne', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Scarlet Witch / Wanda', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Quicksilver / Pietro M', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Captain America', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Thunderstrike / Eric K', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Wonder Man / Simon Wil', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Wolverine / Logan', 'Mr. Fantastic Doppel', 'Magus'],
#  ['She-hulk / Jennifer Wa', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Vision', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Psylocke / Elisabeth B', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Marvel Girl / Jean Grey', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Storm / Ororo Munroe S', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Angel / Warren Kenneth', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Thing / Benjamin J. Gr', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Invisible Woman / Sue', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Beast / Henry &hank& P', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Cyclops / Scott Summer', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Spider-woman Ii / Juli',
#   'Mr. Fantastic Doppel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Iceman / Robert Bobby', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Human Torch / Johnny S', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Havok / Alex Summers', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Colossus Ii / Peter Ra', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Wolfsbane / Rahne Sinc', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Ant-man / Dr. Henry J.', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Hercules [greek God]', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Black Widow / Natasha', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Daredevil / Matt Murdo', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Gambit / Remy Lebeau', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Quasar Iii / Wendell V', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Usagent / Captain John', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Black Knight V / Dane', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Strong Guy / Guido Car', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Hudson, Heather', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Sasquatch / Walter Lan', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Thanos Doppelganger', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Multiple Man / James A', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Darkhawk / Chris Powel', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Living Lightning / Mig', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Puck / Eugene Milton J', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Northstar / Jean-paul', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Wild Child / Kyle Gibn', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Iron Man Doppelgange', 'Mr. Fantastic Doppel', 'Magus'],
#  ['Rogue  / ', 'Iron Man Doppelgange', 'Magus'],
#  ['Nova / Richard Rider', 'Iron Man Doppelgange', 'Magus'],
#  ['Firestar / Angelica Jo', 'Iron Man Doppelgange', 'Magus'],
#  ['Namorita / Nita Prenti', 'Iron Man Doppelgange', 'Magus'],
#  ['Speedball / Robbie Bal', 'Iron Man Doppelgange', 'Magus'],
#  ['Hulk / Dr. Robert Bruce Banner', 'Iron Man Doppelgange', 'Magus'],
#  ['Wasp / Janet Van Dyne', 'Iron Man Doppelgange', 'Magus'],
#  ['Scarlet Witch / Wanda', 'Iron Man Doppelgange', 'Magus'],
#  ['Quicksilver / Pietro M', 'Iron Man Doppelgange', 'Magus'],
#  ['Captain America', 'Iron Man Doppelgange', 'Magus'],
#  ['Thunderstrike / Eric K', 'Iron Man Doppelgange', 'Magus'],
#  ['Wonder Man / Simon Wil', 'Iron Man Doppelgange', 'Magus'],
#  ['Wolverine / Logan', 'Iron Man Doppelgange', 'Magus'],
#  ['She-hulk / Jennifer Wa', 'Iron Man Doppelgange', 'Magus'],
#  ['Vision', 'Iron Man Doppelgange', 'Magus'],
#  ['Psylocke / Elisabeth B', 'Iron Man Doppelgange', 'Magus'],
#  ['Marvel Girl / Jean Grey', 'Iron Man Doppelgange', 'Magus'],
#  ['Storm / Ororo Munroe S', 'Iron Man Doppelgange', 'Magus'],
#  ['Angel / Warren Kenneth', 'Iron Man Doppelgange', 'Magus'],
#  ['Thing / Benjamin J. Gr', 'Iron Man Doppelgange', 'Magus'],
#  ['Invisible Woman / Sue', 'Iron Man Doppelgange', 'Magus'],
#  ['Beast / Henry &hank& P', 'Iron Man Doppelgange', 'Magus'],
#  ['Cyclops / Scott Summer', 'Iron Man Doppelgange', 'Magus'],
#  ['Iceman / Robert Bobby', 'Iron Man Doppelgange', 'Magus'],
#  ['Human Torch / Johnny S', 'Iron Man Doppelgange', 'Magus'],
#  ['Havok / Alex Summers', 'Iron Man Doppelgange', 'Magus'],
#  ['Colossus Ii / Peter Ra', 'Iron Man Doppelgange', 'Magus'],
#  ['Wolfsbane / Rahne Sinc', 'Iron Man Doppelgange', 'Magus'],
#  ['Ant-man / Dr. Henry J.', 'Iron Man Doppelgange', 'Magus'],
#  ['Hercules [greek God]', 'Iron Man Doppelgange', 'Magus'],
#  ['Black Widow / Natasha', 'Iron Man Doppelgange', 'Magus'],
#  ['Daredevil / Matt Murdo', 'Iron Man Doppelgange', 'Magus'],
#  ['Gambit / Remy Lebeau', 'Iron Man Doppelgange', 'Magus'],
#  ['Quasar Iii / Wendell V', 'Iron Man Doppelgange', 'Magus'],
#  ['Usagent / Captain John', 'Iron Man Doppelgange', 'Magus'],
#  ['Black Knight V / Dane', 'Iron Man Doppelgange', 'Magus'],
#  ['Strong Guy / Guido Car', 'Iron Man Doppelgange', 'Magus'],
#  ['Hudson, Heather', 'Iron Man Doppelgange', 'Magus'],
#  ['Sasquatch / Walter Lan', 'Iron Man Doppelgange', 'Magus'],
#  ['Thanos Doppelganger', 'Iron Man Doppelgange', 'Magus'],
#  ['Multiple Man / James A', 'Iron Man Doppelgange', 'Magus'],
#  ['Darkhawk / Chris Powel', 'Iron Man Doppelgange', 'Magus'],
#  ['Living Lightning / Mig', 'Iron Man Doppelgange', 'Magus'],
#  ['Puck / Eugene Milton J', 'Iron Man Doppelgange', 'Magus'],
#  ['Iron Man / Tony Stark',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie'],
#  ['Rogue  / ', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Sub-mariner / Namor Ma',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie'],
#  ['Nova / Richard Rider', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Firestar / Angelica Jo', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Namorita / Nita Prenti', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Speedball / Robbie Bal', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Hulk / Dr. Robert Bruce Banner', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Spider-man / Peter Parker',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie'],
#  ['Wasp / Janet Van Dyne', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Hawk', 'Darkhawk / Chris Powel', 'Magus', 'Aurora / Jeanne-marie'],
#  ['Scarlet Witch / Wanda', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Quicksilver / Pietro M', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Captain America', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Thunderstrike / Eric K', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Wonder Man / Simon Wil', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Wolverine / Logan', 'Darkhawk / Chris Powel', 'Magus'],
#  ['She-hulk / Jennifer Wa', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Vision', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Psylocke / Elisabeth B', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Marvel Girl / Jean Grey', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Storm / Ororo Munroe S', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Angel / Warren Kenneth', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Thing / Benjamin J. Gr', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Invisible Woman / Sue', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Beast / Henry &hank& P', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Cyclops / Scott Summer', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Spider-woman Ii / Juli',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Dr. Strange / Stephen', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Crystal [inhuman]', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Warlock Ii / Adam Warl', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Professor X / Charles', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Iceman / Robert Bobby', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Moondragon / Heather D', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Human Torch / Johnny S', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Havok / Alex Summers', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Colossus Ii / Peter Ra', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Wolfsbane / Rahne Sinc', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Ant-man / Dr. Henry J.', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Hercules [greek God]', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Black Widow / Natasha', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Moon Knight / Marc Spe', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Daredevil / Matt Murdo', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Dr. Druid / Anthony Lu', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Gambit / Remy Lebeau', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Quasar Iii / Wendell V', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Usagent / Captain John', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Binary / Carol Danvers',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Black Knight V / Dane', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Falcon / Sam Wilson',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Strong Guy / Guido Car', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Hudson, Heather', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Sasquatch / Walter Lan', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Harkness, Agatha', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Thanos Doppelganger', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Multiple Man / James A', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Wild Child / Kyle Gibn', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Puck / Eugene Milton J', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Rage / Elvin Daryl Hal',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Living Lightning / Mig', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Rogue  / ', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Nova / Richard Rider', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Firestar / Angelica Jo', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Namorita / Nita Prenti', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Speedball / Robbie Bal', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Night Thrasher / Duane', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Spider-man / Peter Parker', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Justice Ii / Vance Ast', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Captain America', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Wonder Man / Simon Wil', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Wolverine / Logan', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Vision', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Psylocke / Elisabeth B', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Marvel Girl / Jean Grey', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Storm / Ororo Munroe S', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Angel / Warren Kenneth', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Thing / Benjamin J. Gr', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Invisible Woman / Sue', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Beast / Henry &hank& P', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Cyclops / Scott Summer', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Iceman / Robert Bobby', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Human Torch / Johnny S', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Havok / Alex Summers', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Colossus Ii / Peter Ra', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Polaris / Lorna Dane', 'Silhouette', 'Darkhawk / Chris Powel', 'Magus'],
#  ['Hercules [greek God]', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Black Widow / Natasha', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Black Knight V / Dane', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Strong Guy / Guido Car', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Sasquatch / Walter Lan', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Multiple Man / James A', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Rage / Elvin Daryl Hal', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ['Puck / Eugene Milton J', 'Silhouette', 'Darkhawk / Chris Powel'],
#  ["Black Panther / T'chal",
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Iron Man / Tony Stark',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Sub-mariner / Namor Ma',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Nova / Richard Rider', 'Nelson, Franklin Fog', 'Silhouette'],
#  ['Firestar / Angelica Jo', 'Nelson, Franklin Fog', 'Silhouette'],
#  ['Namorita / Nita Prenti', 'Nelson, Franklin Fog', 'Silhouette'],
#  ['Speedball / Robbie Bal', 'Nelson, Franklin Fog', 'Silhouette'],
#  ['Night Thrasher / Duane', 'Nelson, Franklin Fog', 'Silhouette'],
#  ['Spider-man / Peter Parker', 'Nelson, Franklin Fog', 'Silhouette'],
#  ['Captain America', 'Nelson, Franklin Fog', 'Silhouette'],
#  ['Mr. Fantastic / Reed R',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus'],
#  ['Thing / Benjamin J. Gr', 'Nelson, Franklin Fog', 'Silhouette'],
#  ['Invisible Woman / Sue', 'Nelson, Franklin Fog', 'Silhouette'],
#  ['Punisher Ii / Frank Ca',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Beast / Henry &hank& P', 'Nelson, Franklin Fog', 'Silhouette'],
#  ['Thor / Dr. Donald Blak',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Kingpin / Wilson Fisk',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm'],
#  ['Watson-parker, Mary',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm'],
#  ['Human Torch / Johnny S', 'Nelson, Franklin Fog', 'Silhouette'],
#  ['Cage, Luke / Carl Luca',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Black Widow / Natasha', 'Nelson, Franklin Fog', 'Silhouette'],
#  ['Daredevil / Matt Murdo',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Fury, Col. Nicholas',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am'],
#  ['Iron Fist / Daniel Ran',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Sub-mariner / Namor Ma', 'Knight, Misty', 'Nelson, Franklin Fog'],
#  ['Namorita / Nita Prenti', 'Knight, Misty', 'Nelson, Franklin Fog'],
#  ['Spider-man / Peter Parker', 'Knight, Misty', 'Nelson, Franklin Fog'],
#  ['Captain America', 'Knight, Misty', 'Nelson, Franklin Fog'],
#  ['Wolverine / Logan', 'Knight, Misty', 'Nelson, Franklin Fog', 'Silhouette'],
#  ['She-hulk / Jennifer Wa',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Storm / Ororo Munroe S',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette'],
#  ['Mr. Fantastic / Reed R', 'Knight, Misty', 'Nelson, Franklin Fog'],
#  ['Thing / Benjamin J. Gr', 'Knight, Misty', 'Nelson, Franklin Fog'],
#  ['Invisible Woman / Sue', 'Knight, Misty', 'Nelson, Franklin Fog'],
#  ['Punisher Ii / Frank Ca', 'Knight, Misty', 'Nelson, Franklin Fog'],
#  ['Cyclops / Scott Summer',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette'],
#  ['Professor X / Charles',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Human Torch / Johnny S', 'Knight, Misty', 'Nelson, Franklin Fog'],
#  ['Colossus Ii / Peter Ra',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette'],
#  ['Cage, Luke / Carl Luca', 'Knight, Misty', 'Nelson, Franklin Fog'],
#  ['Daredevil / Matt Murdo', 'Knight, Misty', 'Nelson, Franklin Fog'],
#  ['Human Torch Android / ',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Nightcrawler / Kurt Wa',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie'],
#  ['Black Knight V / Dane',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette'],
#  ['Sunfire / Shiro Yoshid',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie'],
#  ['Iron Fist / Daniel Ran', 'Knight, Misty', 'Nelson, Franklin Fog'],
#  ['Sub-mariner / Namor Ma', 'Wing, Colleen', 'Knight, Misty'],
#  ['Namorita / Nita Prenti', 'Wing, Colleen', 'Knight, Misty'],
#  ['Wolverine / Logan', 'Wing, Colleen', 'Knight, Misty'],
#  ['Storm / Ororo Munroe S', 'Wing, Colleen', 'Knight, Misty'],
#  ['Cyclops / Scott Summer', 'Wing, Colleen', 'Knight, Misty'],
#  ['Colossus Ii / Peter Ra', 'Wing, Colleen', 'Knight, Misty'],
#  ['Cage, Luke / Carl Luca', 'Wing, Colleen', 'Knight, Misty'],
#  ['Banshee / Sean Cassidy', 'Wing, Colleen', 'Knight, Misty'],
#  ['Human Torch Android / ', 'Wing, Colleen', 'Knight, Misty'],
#  ['Nightcrawler / Kurt Wa', 'Wing, Colleen', 'Knight, Misty'],
#  ['Iron Fist / Daniel Ran', 'Wing, Colleen', 'Knight, Misty'],
#  ['Iron Man / Tony Stark',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog'],
#  ['Rogue  / ',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette'],
#  ['Wasp / Janet Van Dyne',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Silver Surfer / Norrin',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus'],
#  ['Scarlet Witch / Wanda',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Uatu',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Captain America', 'Lilandra Neramani [s', 'Knight, Misty'],
#  ['Thunderstrike / Eric K',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Wonder Man / Simon Wil',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette'],
#  ['Wolverine / Logan', 'Lilandra Neramani [s', 'Knight, Misty'],
#  ['Vision',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette'],
#  ['Psylocke / Elisabeth B',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette'],
#  ['Marvel Girl / Jean Grey',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette'],
#  ['Storm / Ororo Munroe S', 'Lilandra Neramani [s', 'Knight, Misty'],
#  ['Mr. Fantastic / Reed R', 'Lilandra Neramani [s', 'Knight, Misty'],
#  ['Angel / Warren Kenneth',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette'],
#  ['Thing / Benjamin J. Gr', 'Lilandra Neramani [s', 'Knight, Misty'],
#  ['Invisible Woman / Sue', 'Lilandra Neramani [s', 'Knight, Misty'],
#  ['Beast / Henry &hank& P',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog'],
#  ['Cyclops / Scott Summer', 'Lilandra Neramani [s', 'Knight, Misty'],
#  ['Thor / Dr. Donald Blak',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog'],
#  ['Crystal [inhuman]',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Professor X / Charles', 'Lilandra Neramani [s', 'Knight, Misty'],
#  ['Iceman / Robert Bobby',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette'],
#  ['Human Torch / Johnny S', 'Lilandra Neramani [s', 'Knight, Misty'],
#  ['Havok / Alex Summers',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette'],
#  ['Colossus Ii / Peter Ra', 'Lilandra Neramani [s', 'Knight, Misty'],
#  ['Polaris / Lorna Dane',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette'],
#  ['Wolfsbane / Rahne Sinc',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Magneto / Magnus / Eric',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia',
#   'Luna / Luna Maximoff [',
#   'Medusa / Medusalith Am',
#   'Wizard / Bentley Wittm'],
#  ['Ant-man / Dr. Henry J.',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Hercules [greek God]',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette'],
#  ['Banshee / Sean Cassidy', 'Lilandra Neramani [s', 'Knight, Misty'],
#  ['Starfox / Eros',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Nightcrawler / Kurt Wa', 'Lilandra Neramani [s', 'Knight, Misty'],
#  ['Gambit / Remy Lebeau',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Quasar Iii / Wendell V',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Captain Marvel Ii / Mo',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Shadowcat / Katherine',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie'],
#  ['Binary / Carol Danvers',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Mactaggert, Moira Ki', 'Lilandra Neramani [s', 'Knight, Misty'],
#  ['Living Lightning / Mig',
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Rogue  / ', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Wolverine / Logan', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Storm / Ororo Munroe S', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Professor X / Charles', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Colossus Ii / Peter Ra', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Wolfsbane / Rahne Sinc', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Sunspot / Roberto Daco', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Magik / Illyana Rasput', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Magneto / Magnus / Eric', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Cannonball Ii / Sam Gu', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Mirage Ii / Danielle M', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Nightcrawler / Kurt Wa', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Phoenix Iii / Rachel S', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Shadowcat / Katherine', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Mactaggert, Moira Ki', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Magma / Amara Aquilla / ',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Hunter, Stevie', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Cypher / Doug Ramsey', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Corsair', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ["Mam'selle Hepzibah", "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ["Ch'od", "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Raza Longknife', "Karma / Xi'an Coy Manh", 'Lilandra Neramani [s'],
#  ['Rogue  / ', 'Spider-woman / Jessica', "Karma / Xi'an Coy Manh"],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Spider-woman / Jessica',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Spider-man / Peter Parker',
#   'Spider-woman / Jessica',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty'],
#  ['Tigra / Greer Nelson',
#   'Spider-woman / Jessica',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Wasp / Janet Van Dyne',
#   'Spider-woman / Jessica',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Hawk',
#   'Spider-woman / Jessica',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Scarlet Witch / Wanda',
#   'Spider-woman / Jessica',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Captain America',
#   'Spider-woman / Jessica',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Wonder Man / Simon Wil',
#   'Spider-woman / Jessica',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Wolverine / Logan', 'Spider-woman / Jessica', "Karma / Xi'an Coy Manh"],
#  ['She-hulk / Jennifer Wa',
#   'Spider-woman / Jessica',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty'],
#  ['Vision',
#   'Spider-woman / Jessica',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Storm / Ororo Munroe S',
#   'Spider-woman / Jessica',
#   "Karma / Xi'an Coy Manh"],
#  ['Angel / Warren Kenneth',
#   'Spider-woman / Jessica',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Thing / Benjamin J. Gr',
#   'Spider-woman / Jessica',
# ...
#  ['Marvel Girl / Jean Grey', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Storm / Ororo Munroe S', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Angel / Warren Kenneth', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Beast / Henry &hank& P', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Cyclops / Scott Summer', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Cooper, Dr. Valerie', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Professor X / Charles', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Iceman / Robert Bobby', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Havok / Alex Summers', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Colossus Ii / Peter Ra', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Summers, Nathan Chri', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Polaris / Lorna Dane', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Wolfsbane / Rahne Sinc', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Sunspot / Roberto Daco', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Cannonball Ii / Sam Gu', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Gambit / Remy Lebeau', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Bishop  / ', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Apocalypse / En Sabah', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Strong Guy / Guido Car', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Mactaggert, Moira Ki', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Multiple Man / James A', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Firefist / Rusty Colli', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Skids / Sally Blevins', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Zero', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Boomer / Tabitha Smith', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Siryn / Theresa Rourke', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Thunderbird Ii / James', 'Stryfe', 'Rictor / Julio Esteban'],
#  ['Rogue  / ', 'Zero', 'Rictor / Julio Esteban'],
#  ['Quicksilver / Pietro M', 'Zero', 'Rictor / Julio Esteban'],
#  ['Wolverine / Logan', 'Zero', 'Rictor / Julio Esteban'],
#  ['Marvel Girl / Jean Grey', 'Zero', 'Rictor / Julio Esteban'],
#  ['Storm / Ororo Munroe S', 'Zero', 'Rictor / Julio Esteban'],
#  ['Angel / Warren Kenneth', 'Zero', 'Rictor / Julio Esteban'],
#  ['Beast / Henry &hank& P', 'Zero', 'Rictor / Julio Esteban'],
#  ['Cyclops / Scott Summer', 'Zero', 'Rictor / Julio Esteban'],
#  ['Cooper, Dr. Valerie', 'Zero', 'Rictor / Julio Esteban'],
#  ['Professor X / Charles', 'Zero', 'Rictor / Julio Esteban'],
#  ['Iceman / Robert Bobby', 'Zero', 'Rictor / Julio Esteban'],
#  ['Havok / Alex Summers', 'Zero', 'Rictor / Julio Esteban'],
#  ['Summers, Nathan Chri', 'Zero', 'Rictor / Julio Esteban'],
#  ['Polaris / Lorna Dane', 'Zero', 'Rictor / Julio Esteban'],
#  ['Wolfsbane / Rahne Sinc', 'Zero', 'Rictor / Julio Esteban'],
#  ['Sunspot / Roberto Daco', 'Zero', 'Rictor / Julio Esteban'],
#  ['Cannonball Ii / Sam Gu', 'Zero', 'Rictor / Julio Esteban'],
#  ['Gambit / Remy Lebeau', 'Zero', 'Rictor / Julio Esteban'],
#  ['Bishop  / ', 'Zero', 'Rictor / Julio Esteban'],
#  ['Apocalypse / En Sabah', 'Zero', 'Rictor / Julio Esteban'],
#  ['Strong Guy / Guido Car', 'Zero', 'Rictor / Julio Esteban'],
#  ['Mactaggert, Moira Ki', 'Zero', 'Rictor / Julio Esteban'],
#  ['Firefist / Rusty Colli', 'Zero', 'Rictor / Julio Esteban'],
#  ['Skids / Sally Blevins', 'Zero', 'Rictor / Julio Esteban'],
#  ['Boomer / Tabitha Smith', 'Zero', 'Rictor / Julio Esteban'],
#  ['Siryn / Theresa Rourke', 'Zero', 'Rictor / Julio Esteban'],
#  ['Thunderbird Ii / James', 'Zero', 'Rictor / Julio Esteban'],
#  ['Summers, Nathan Chri',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban'],
#  ['Sunspot / Roberto Daco',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban'],
#  ['Cannonball Ii / Sam Gu',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban'],
#  ['Domino Iii / Beatrice / ',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban'],
#  ['Bridge, George Washi',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban'],
#  ['Thunderbird Ii / James',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban'],
#  ['Siryn / Theresa Rourke',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban'],
#  ['Boomer / Tabitha Smith',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban'],
#  ["Black Panther / T'chal",
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog'],
#  ['Iron Man / Tony Stark',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Sub-mariner / Namor Ma',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty'],
#  ['Nova / Richard Rider',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro'],
#  ['Hulk / Dr. Robert Bruce Banner',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Spider-man / Peter Parker',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty'],
#  ['Wasp / Janet Van Dyne',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Galactus / Galan',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus'],
#  ['Silver Surfer / Norrin',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Hawk',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Scarlet Witch / Wanda',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Uatu',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Captain America',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Thunderstrike / Eric K',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Wonder Man / Simon Wil',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Wolverine / Logan',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban'],
#  ['She-hulk / Jennifer Wa',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty'],
#  ['Vision',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Storm / Ororo Munroe S',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban'],
#  ['Eternity / Adam Qadmon',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus'],
#  ['Quasar Iii / Wendell V',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Black Widow / Natasha',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog'],
#  ['Thor / Dr. Donald Blak',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Richards, Franklin B',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art'],
#  ['Dr. Doom / Victor Von',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus'],
#  ['Thing / Benjamin J. Gr',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Gamora',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus'],
#  ['Drax / Arthur Douglas',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus'],
#  ['Nova Ii / Frankie Raye',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus'],
#  ['Ant-man / Dr. Henry J.',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Moondragon / Heather D',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Pip / Prince Gofern',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus'],
#  ['Thanos',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus'],
#  ['Collector / Taneleer T',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Warlock Ii / Adam Warl',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Dr. Strange / Stephen',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel'],
#  ['Starfox / Eros',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Invisible Woman / Sue',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Cyclops / Scott Summer',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban'],
#  ["Black Panther / T'chal", 'Captain Marvel / Capta', 'Death'],
#  ['Iron Man / Tony Stark', 'Captain Marvel / Capta', 'Death'],
#  ['Hulk / Dr. Robert Bruce Banner', 'Captain Marvel / Capta', 'Death'],
#  ['Spider-man / Peter Parker', 'Captain Marvel / Capta', 'Death'],
#  ['Wasp / Janet Van Dyne', 'Captain Marvel / Capta', 'Death'],
#  ['Hawk', 'Captain Marvel / Capta', 'Death'],
#  ['Scarlet Witch / Wanda', 'Captain Marvel / Capta', 'Death'],
#  ['Quicksilver / Pietro M',
#   'Captain Marvel / Capta',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban'],
#  ['Uatu', 'Captain Marvel / Capta', 'Death'],
#  ['Captain America', 'Captain Marvel / Capta', 'Death'],
#  ['Wonder Man / Simon Wil', 'Captain Marvel / Capta', 'Death'],
#  ['Vision', 'Captain Marvel / Capta', 'Death'],
#  ['Mr. Fantastic / Reed R',
#   'Captain Marvel / Capta',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Thing / Benjamin J. Gr', 'Captain Marvel / Capta', 'Death'],
#  ['Invisible Woman / Sue', 'Captain Marvel / Capta', 'Death'],
#  ['Beast / Henry &hank& P',
#   'Captain Marvel / Capta',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban'],
#  ['Thor / Dr. Donald Blak', 'Captain Marvel / Capta', 'Death'],
#  ['Warlock Ii / Adam Warl', 'Captain Marvel / Capta', 'Death'],
#  ['Moondragon / Heather D', 'Captain Marvel / Capta', 'Death'],
#  ['Human Torch / Johnny S',
#   'Captain Marvel / Capta',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Jarvis, Edwin',
#   'Captain Marvel / Capta',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty',
#   'Nelson, Franklin Fog',
#   'Silhouette',
#   'Darkhawk / Chris Powel',
#   'Magus',
#   'Aurora / Jeanne-marie',
#   'Box Iv / Madison Jeffr',
#   'Sersi / Sylvia'],
#  ['Ant-man / Dr. Henry J.', 'Captain Marvel / Capta', 'Death'],
#  ['Hercules [greek God]',
#   'Captain Marvel / Capta',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s'],
#  ['Black Widow / Natasha', 'Captain Marvel / Capta', 'Death'],
#  ['Drax / Arthur Douglas', 'Captain Marvel / Capta', 'Death'],
#  ['Daredevil / Matt Murdo',
#   'Captain Marvel / Capta',
#   'Death',
#   'Deadpool / Jack / Wade W',
#   'Rictor / Julio Esteban',
#   'Maddicks, Arthur Art',
#   'White Queen / Emma Fro',
#   "Karma / Xi'an Coy Manh",
#   'Lilandra Neramani [s',
#   'Knight, Misty'],
#  ['Gamora', 'Captain Marvel / Capta', 'Death'],
#  ['Thanos', 'Captain Marvel / Capta', 'Death'],
#  ...]
