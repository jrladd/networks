# %% [markdown]
# # 08: Affiliation and History
#
# This week we'll explore the two special kinds of networks we discussed in class: multipartite networks, which are for more than one kind of node, and multilayer networks, which are for more than one kind of edge.
#
# **This is a group assignment! Refer to Github for your groups.**
#
# In a short Jupyter notebook report, complete the following tasks. Don't simply calculate the answers: make sure you're fully explaining (in writing) the metrics and visualizations that you generate. Consider the [Criteria for Good Reports](https://jrladd.com/CIS397-networks/criteria/) as a guide. You can create markdown cells with section headers to separate the different sections of the report. Rather than number the report as if you're answering distinct questions, use the questions as a guide to do some data storytelling, i.e. explain this network's data in an organized way.
#
# ## Part 1: Bipartite Network
#
# 1. Download an [Affiliation network](http://konect.cc/categories/Affiliation/) of your choice from the KONECT project datasets. (If you're unable to unzip these files, download one of the ones available under Sakai Resources.) Load the data into NetworkX and calculate at least 3 kinds of *bipartite* centrality on this network. Visualize your bipartite network in `networkx`, using a bipartite layout and using one of your centrality measures as the size of the nodes. What do you learn about the nodes in your network with high centrality?
#
# > *n.b. Loading this data will require some adjustment of the original data that you downloaded. Refer to our discussion of this from class, and reach out if you have any questions.*
#
# 2.  Export the data from step 1 to a `.gml` file with all the centrality measures you calculated included. Load this data into Gephi and visualize the network using Gephi as well. Recalculate the same 3 kinds of centrality and compare those values to the ones you got in Python. There's a key difference between these measures, and it illustrates a limitation of Gephi. Explain the difference, and in your Gephi visualization use at least 2 *Python-calculated* centrality values.
#
# 3. Using the same dataset, project your network in a *unipartite* graph, onto the nodeset of *people* in your network and then onto the nodset of *groups*. Visualize these two new networks in `networkx`. What information is gained by presenting the network in these ways, and how does it help you understand the people and groups in your network? What information is lost?
#
#
#
#
# ## Part 2: Temporal Network
#
# 4. Download the `quaker_edgelist.csv` data from the textbook datasets page. This is a historical dynamic/temporal network that shows changing relationships over time. Using [this tutorial](https://seinecle.github.io/gephi-tutorials/generated-html/converting-a-network-with-dates-into-dynamic.html), create a timeline for this network in Gephi and create a visualization showing changes in the network over time. Include two or three screenshots showing key moments in the network's history (include the timeline at the bottom of the Gephi window in your screenshots). During what period in time were most of the relationships in this network active? How do you know this?
#
# 5. In NetworkX, load the same data set as a standard Graph object. In order to have access to the names of all the people, you'll also need to add all the node attributes from `quaker_nodelist.csv`. Once the data is loaded, create a function, using the start and end years of each relationship, to find all time-respecting paths in the network. Then calculate the shortest distance and fastest distance for each path. What is the longest time-respecting path in this network and which two people does it connect? What is the slowest time-respecting path in this network and which two people does it connect? What does this tell you about the network and these individuals?
#
# 6. Using the time-respecting paths in the previous step, develop a measure for temporal betweenness centrality. There are several ways to approach this, and you should discuss different options with your group. Consider the advice from [this paper on Temporal Networks](https://arxiv.org/pdf/1108.1780):
#
# ![](../temporal-betweenness.png){width=50%}
#
# Once you've calculated temporal betweenness, create two histograms to compare the distribution of temporal betweenness to the distribution of static (i.e. normal) betweenness. Also create two side-by-side node-link diagrams showing node-size as the two types of betweenness. How are these measures similar and different? Do they highlight different people in the network?
#
# 7. Let's look at this network a different way. Using the start and end year of each relationship, create 20-year time intervals and assign edges to the appropriate intervals. Add this information to a `MultiGraph` object, so that it has an `interval` attribute for each edge and an edge `key` that matches the interval. Which interval has the most edges, i.e. the most relationship activity of any 20-year period?
#
# 8. Visualize each layer of the `MultiGraph` as a separate node-link diagram in a grid. It's very important that the node positions stay exactly the same in each plot, so that you can track changes visually. Your final plot should look something like this:
#
# ![](../temporal-interval.png){width=50%}
#
# Interpret this visualization fully. What does it tell you about how the network changes over time? Does dealing with this graph in intervals give you a different sense of it than you got from the Gephi visualization?
#
# **When you're finished, remove these instructions from the top of the file, leaving only your own writing and code. Push the notebook to the repo to submit to Github Classroom by the deadline on the schedule.**
